# %% [markdown]
# # ASSOCIATION RULES FOR THE FIRST DATASET
# Express how product/services relate to each other, and tend to group together.

# %% [markdown]
# Library import

# %%
#vanno importate pandas e numpy e matplot per fare i grafici
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split  
from pandas import DataFrame

# %%
df = pd.read_csv(r'C:\Users\jigok\OneDrive\Desktop\UniPISA\1semestre1Anno\Data Mining\Progetto\Dataset AR\All_values_Train_HR_Employee_Attrition.csv')

# %%
df.head(5) #fammi vedere le prime 10 righe
# Out:
#     Age Attrition     BusinessTravel  DistanceFromHome  Education  Gender  \
# 0  52.0        No      Travel_Rarely                 9          4    Male
# 1  36.0        No      Travel_Rarely                 1          1    Male
# 2  25.0        No  Travel_Frequently                16          3    Male
# 3  33.0        No      Travel_Rarely                 5          4    Male
# 4  31.0        No      Travel_Rarely                 9          2  Female
#
#    JobLevel                JobRole  MonthlyIncome  NumCompaniesWorked  \
# 0         3      Research Director         8446.0                   9
# 1         5                Manager         4834.0                   1
# 2         2        Sales Executive         4768.0                   1
# 3         1     Research Scientist         2799.0                   2
# 4         1  Laboratory Technician         6319.0                   1
#
#   OverTime  PercentSalaryHike  StockOptionLevel  TrainingTimesLastYear  \
# 0       No                 17                 0                    2.0
# 1      Yes                 14                 1                    3.0
# 2      Yes                 25                 1                    4.0
# 3       No                 14                 0                    1.0
# 4       No                 12                 0                    2.0
#
#    YearsAtCompany  YearsInCurrentRole  MonthlyHours   TaxRate  \
# 0             8.0                   7    156.613636  0.387172
# 1             1.0                   8    157.942308  0.411421
# 2             1.0                   5    448.055556  0.704402
# 3             3.0                   7    271.907692  0.841632
# 4            10.0                   2    106.373333  0.207947
#
#    OverallSatisfaction
# 0                  2.6
# 1                  2.8
# 2                  3.2
# 3                  2.4
# 4                  3.2

# %%
#discretizzo OverallSatisfaction
def labels(x):
    if  1.0 <= x <= 1.5:
        return(1)
    elif 1.6 <= x <= 2.5:
        return(2)
    elif 2.6 <= x <= 3.5:
        return(3)
    elif 3.6 <= x <= 4.5:
        return(4)
    else:
        return(4)

df['OverallSatisfaction'] = df['OverallSatisfaction'].apply(lambda x: labels(x))
#arrotondo le medie
df.head(5)
# Out:
#     Age Attrition     BusinessTravel  DistanceFromHome  Education  Gender  \
# 0  52.0        No      Travel_Rarely                 9          4    Male
# 1  36.0        No      Travel_Rarely                 1          1    Male
# 2  25.0        No  Travel_Frequently                16          3    Male
# 3  33.0        No      Travel_Rarely                 5          4    Male
# 4  31.0        No      Travel_Rarely                 9          2  Female
#
#    JobLevel                JobRole  MonthlyIncome  NumCompaniesWorked  \
# 0         3      Research Director         8446.0                   9
# 1         5                Manager         4834.0                   1
# 2         2        Sales Executive         4768.0                   1
# 3         1     Research Scientist         2799.0                   2
# 4         1  Laboratory Technician         6319.0                   1
#
#   OverTime  PercentSalaryHike  StockOptionLevel  TrainingTimesLastYear  \
# 0       No                 17                 0                    2.0
# 1      Yes                 14                 1                    3.0
# 2      Yes                 25                 1                    4.0
# 3       No                 14                 0                    1.0
# 4       No                 12                 0                    2.0
#
#    YearsAtCompany  YearsInCurrentRole  MonthlyHours   TaxRate  \
# 0             8.0                   7    156.613636  0.387172
# 1             1.0                   8    157.942308  0.411421
# 2             1.0                   5    448.055556  0.704402
# 3             3.0                   7    271.907692  0.841632
# 4            10.0                   2    106.373333  0.207947
#
#    OverallSatisfaction
# 0                    3
# 1                    3
# 2                    3
# 3                    2
# 4                    3

# %%
df.describe()
# Out:
#               Age  DistanceFromHome   Education    JobLevel  MonthlyIncome  \
# count  883.000000        883.000000  883.000000  883.000000     883.000000
# mean    36.554926          9.201586    2.886750    1.919592    6932.335221
# std      8.266129          8.241818    1.008285    1.007506    5453.370217
# min     18.000000          1.000000    1.000000    1.000000    1009.000000
# 25%     30.000000          2.000000    2.000000    1.000000    3072.000000
# 50%     35.000000          7.000000    3.000000    2.000000    5079.000000
# 75%     42.000000         14.000000    4.000000    2.000000    8840.500000
# max     60.000000         29.000000    5.000000    5.000000   26997.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count          883.000000         883.000000        883.000000
# mean             2.836920          15.207248          0.793884
# std              2.484993           3.589332          0.865362
# min              0.000000          11.000000          0.000000
# 25%              1.000000          12.000000          0.000000
# 50%              2.000000          14.000000          1.000000
# 75%              4.000000          18.000000          1.000000
# max              9.000000          25.000000          3.000000
#
#        TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole  \
# count             883.000000      883.000000          883.000000
# mean                2.665912        6.326161            3.919592
# std                 1.187828        4.523567            3.435392
# min                 0.000000        0.000000            0.000000
# 25%                 2.000000        3.000000            2.000000
# 50%                 2.000000        5.000000            3.000000
# 75%                 3.000000        9.000000            7.000000
# max                 6.000000       20.000000           16.000000
#
#        MonthlyHours     TaxRate  OverallSatisfaction
# count    883.000000  883.000000           883.000000
# mean     234.245826    0.463811             2.725934
# std      130.196628    0.320030             0.523459
# min       26.043478    0.000000             1.000000
# 25%      130.630208    0.129730             2.000000
# 50%      212.279070    0.528359             3.000000
# 75%      309.906250    0.762560             3.000000
# max      590.976744    0.951396             4.000000

# %%
#numero bin con la distribuzione istogrammi variabili
#Apply binning to continuous features

df['AgeBin'] = pd.cut(df['Age'].astype(int), 6, right=False)
df['DistanceFromHomeBin'] = pd.cut(df['DistanceFromHome'].astype(int), 10, right=False)
df['PercentSalaryHikeBin'] = pd.cut(df['PercentSalaryHike'].astype(int), 5, right=False)
df['MonthlyIncomeBin'] = pd.cut(df['MonthlyIncome'].astype(int), 10, right=False)
df['MonthlyHoursBin'] = pd.cut(df['MonthlyHours'].astype(int), 10, right=False)



df.drop(['Age', 'MonthlyIncome', 'MonthlyHours','DistanceFromHome','PercentSalaryHike'], axis=1, inplace=True)

df.head()
# Out:
#   Attrition     BusinessTravel  Education  Gender  JobLevel  \
# 0        No      Travel_Rarely          4    Male         3
# 1        No      Travel_Rarely          1    Male         5
# 2        No  Travel_Frequently          3    Male         2
# 3        No      Travel_Rarely          4    Male         1
# 4        No      Travel_Rarely          2  Female         1
#
#                  JobRole  NumCompaniesWorked OverTime  StockOptionLevel  \
# 0      Research Director                   9       No                 0
# 1                Manager                   1      Yes                 1
# 2        Sales Executive                   1      Yes                 1
# 3     Research Scientist                   2       No                 0
# 4  Laboratory Technician                   1       No                 0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsInCurrentRole   TaxRate  \
# 0                    2.0             8.0                   7  0.387172
# 1                    3.0             1.0                   8  0.411421
# 2                    4.0             1.0                   5  0.704402
# 3                    1.0             3.0                   7  0.841632
# 4                    2.0            10.0                   2  0.207947
#
#    OverallSatisfaction        AgeBin DistanceFromHomeBin PercentSalaryHikeBin  \
# 0                    3  [46.0, 53.0)          [6.6, 9.4)         [16.6, 19.4)
# 1                    3  [32.0, 39.0)          [1.0, 3.8)         [13.8, 16.6)
# 2                    3  [25.0, 32.0)        [15.0, 17.8)       [22.2, 25.014)
# 3                    2  [32.0, 39.0)          [3.8, 6.6)         [13.8, 16.6)
# 4                    3  [25.0, 32.0)          [6.6, 9.4)         [11.0, 13.8)
#
#    MonthlyIncomeBin MonthlyHoursBin
# 0  [6206.6, 8805.4)  [138.8, 195.2)
# 1  [3607.8, 6206.6)  [138.8, 195.2)
# 2  [3607.8, 6206.6)  [420.8, 477.2)
# 3  [1009.0, 3607.8)  [251.6, 308.0)
# 4  [6206.6, 8805.4)   [82.4, 138.8)

# %% [markdown]
# Mapping

# %%
df['Education'] = df['Education'].map(
    {1: 'Below College', 2: 'College', 3:'Bachelor', 4:'Master', 5:'Doctor'}).astype(str)
df['OverallSatisfaction'] = df['OverallSatisfaction'].map(
    {1: 'Low', 2: 'Medium', 3:'High', 4:'Very High'}).astype(str)+'_Overall'
df['JobLevel'] = df['JobLevel'].map(
    {1: 'EntryLevel', 2: 'MidLevel', 3:'SeniorLevel', 4:'Manager', 5:'Director'}).astype(str)


df['AgeBin'] = df['AgeBin'].astype(str) + '_Age'
df['MonthlyIncomeBin'] = df['MonthlyIncomeBin'].astype(str) + '_Income'
df['MonthlyHoursBin'] = df['MonthlyHoursBin'].astype(str) + '_Hours'
df['DistanceFromHomeBin'] = df['DistanceFromHomeBin'].astype(str) + '_Distance'
df['YearsAtCompany'] = df['YearsAtCompany'].astype(str) + '_YearsAtCompany'
df['PercentSalaryHikeBin'] = df['PercentSalaryHikeBin'].astype(str) + '_%'

df['NumCompaniesWorked'] = df['NumCompaniesWorked'].astype(str) + '_companies'
df['StockOptionLevel'] = df['StockOptionLevel'].astype(str) + '_stockOption'
df['TrainingTimesLastYear'] = df['TrainingTimesLastYear'].astype(str) + '_Time'
df['YearsInCurrentRole'] = df['YearsInCurrentRole'].astype(str) + '_YearsInCurrentRole'
df['TaxRate'] = df['TaxRate'].astype(str) + '_TaxRate'
df['OverTime'] = df['OverTime'].astype(str) + '_OverTime'
df['Attrition'] = df['Attrition'].astype(str) + '_Attrition'


df.head(5)
# Out:
#       Attrition     BusinessTravel      Education  Gender     JobLevel  \
# 0  No_Attrition      Travel_Rarely         Master    Male  SeniorLevel
# 1  No_Attrition      Travel_Rarely  Below College    Male     Director
# 2  No_Attrition  Travel_Frequently       Bachelor    Male     MidLevel
# 3  No_Attrition      Travel_Rarely         Master    Male   EntryLevel
# 4  No_Attrition      Travel_Rarely        College  Female   EntryLevel
#
#                  JobRole NumCompaniesWorked      OverTime StockOptionLevel  \
# 0      Research Director        9_companies   No_OverTime    0_stockOption
# 1                Manager        1_companies  Yes_OverTime    1_stockOption
# 2        Sales Executive        1_companies  Yes_OverTime    1_stockOption
# 3     Research Scientist        2_companies   No_OverTime    0_stockOption
# 4  Laboratory Technician        1_companies   No_OverTime    0_stockOption
#
#   TrainingTimesLastYear       YearsAtCompany    YearsInCurrentRole  \
# 0              2.0_Time   8.0_YearsAtCompany  7_YearsInCurrentRole
# 1              3.0_Time   1.0_YearsAtCompany  8_YearsInCurrentRole
# 2              4.0_Time   1.0_YearsAtCompany  5_YearsInCurrentRole
# 3              1.0_Time   3.0_YearsAtCompany  7_YearsInCurrentRole
# 4              2.0_Time  10.0_YearsAtCompany  2_YearsInCurrentRole
#
#                        TaxRate OverallSatisfaction            AgeBin  \
# 0   0.3871716731969235_TaxRate        High_Overall  [46.0, 53.0)_Age
# 1   0.4114209180567393_TaxRate        High_Overall  [32.0, 39.0)_Age
# 2   0.7044017358958462_TaxRate        High_Overall  [25.0, 32.0)_Age
# 3   0.8416317754894195_TaxRate      Medium_Overall  [32.0, 39.0)_Age
# 4  0.20794685384808226_TaxRate        High_Overall  [25.0, 32.0)_Age
#
#      DistanceFromHomeBin PercentSalaryHikeBin         MonthlyIncomeBin  \
# 0    [6.6, 9.4)_Distance       [16.6, 19.4)_%  [6206.6, 8805.4)_Income
# 1    [1.0, 3.8)_Distance       [13.8, 16.6)_%  [3607.8, 6206.6)_Income
# 2  [15.0, 17.8)_Distance     [22.2, 25.014)_%  [3607.8, 6206.6)_Income
# 3    [3.8, 6.6)_Distance       [13.8, 16.6)_%  [1009.0, 3607.8)_Income
# 4    [6.6, 9.4)_Distance       [11.0, 13.8)_%  [6206.6, 8805.4)_Income
#
#         MonthlyHoursBin
# 0  [138.8, 195.2)_Hours
# 1  [138.8, 195.2)_Hours
# 2  [420.8, 477.2)_Hours
# 3  [251.6, 308.0)_Hours
# 4   [82.4, 138.8)_Hours

# %% [markdown]
# # Creo i baskets

# %%
baskets = df.values.tolist()

# %%
baskets[0]
# Out:
# ['No_Attrition',
#  'Travel_Rarely',
#  'Master',
#  'Male',
#  'SeniorLevel',
#  'Research Director',
#  '9_companies',
#  'No_OverTime',
#  '0_stockOption',
#  '2.0_Time',
#  '8.0_YearsAtCompany',
#  '7_YearsInCurrentRole',
#  '0.3871716731969235_TaxRate',
#  'High_Overall',
#  '[46.0, 53.0)_Age',
#  '[6.6, 9.4)_Distance',
#  '[16.6, 19.4)_%',
#  '[6206.6, 8805.4)_Income',
#  '[138.8, 195.2)_Hours']

# %% [markdown]
# # Apriori Algorithm

# %%
from fim import apriori

# %%
help(apriori)
# Out:
# Help on built-in function apriori in module fim:
#
# apriori(...)
#     apriori (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#              eval='x', agg='x', thresh=10, prune=None, algo='b', mode='',
#              border=None)
#     Find frequent item sets with the Apriori algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
#             r     rules      association rules
#     supp    minimum support of an item set         (default: 10)
#             (positive: percentage, negative: absolute number)
#     conf    minimum confidence of an assoc. rule   (default: 80%)
#     zmin    minimum number of items per item set   (default: 1)
#     zmax    maximum number of items per item set   (default: no limit)
#     report  values to report with an item set      (default: a)
#             a     absolute item set support (number of transactions)
#             s     relative item set support as a fraction
#             S     relative item set support as a percentage
#             e     value of item set evaluation measure
#             E     value of item set evaluation measure as a percentage
#             (     combine values in a tuple (must be first character)
#             [     combine values in a list  (must be first character)
#             #     pattern spectrum as a dictionary  (no patterns)
#             =     pattern spectrum as a list        (no patterns)
#             |     pattern spectrum as three columns (no patterns)
#             for target 'r' (association rules) also available:
#             b     absolute body set  support (number of transactions)
#             x     relative body set  support as a fraction
#             X     relative body set  support as a percentage
#             h     absolute head item support (number of transactions)
#             y     relative head item support as a fraction
#             Y     relative head item support as a percentage
#             c     rule confidence as a fraction
#             C     rule confidence as a percentage
#             l     lift value of a rule (confidence/prior)
#             L     lift value of a rule as a percentage
#             Q     support of the empty set (total number of transactions)
#     eval    measure for item set evaluation        (default: x)
#             x     none       no measure / zero (default)
#             b     ldratio    binary logarithm of support quotient       (+)
#             c     conf       rule confidence                            (+)
#             d     confdiff   absolute confidence difference to prior    (+)
#             l     lift       lift value (confidence divided by prior)   (+)
#             a     liftdiff   absolute difference of lift value to 1     (+)
#             q     liftquot   difference of lift quotient to 1           (+)
#             v     cvct       conviction (inverse lift negated head)     (+)
#             e     cvctdiff   absolute difference of conviction to 1     (+)
#             r     cvctquot   difference of conviction quotient to 1     (+)
#             k     cprob      conditional probability ratio              (+)
#             j     import     importance (binary log. of prob. ratio)    (+)
#             z     cert       certainty factor (relative conf. change)   (+)
#             n     chi2       normalized chi^2 measure                   (+)
#             p     chi2pval   p-value f/ (unnormalized) chi^2 measure    (-)
#             y     yates      normalized chi^2 with Yates' correction    (+)
#             t     yatespval  p-value f/ Yates-corrected chi^2 measure   (-)
#             i     info       information difference to prior            (+)
#             g     infopval   p-value f/ G statistic/info. difference    (-)
#             f     fetprob    Fisher's exact test (table probability)    (-)
#             h     fetchi2    Fisher's exact test (chi^2 measure)        (-)
#             m     fetinfo    Fisher's exact test (mutual information)   (-)
#             s     fetsupp    Fisher's exact test (support)              (-)
#             Measures marked with (+) must meet or exceed the threshold,
#             measures marked with (-) must not exceed the threshold
#             in order for the item set to be reported.
#     agg     evaluation measure aggregation mode    (default: x)
#             x     none       no aggregation (use first value)
#             m     min        minimum of individual measure values
#             n     max        maximum of individual measure values
#             a     avg        average of individual measure values
#     thresh  threshold for evaluation measure       (default: 10%)
#     prune   min. size for evaluation filtering     (default: no pruning)
#             = 0   backward filtering       (no subset check)
#             < 0   weak   forward filtering (one subset  must qualify)
#             > 0   strong forward filtering (all subsets must qualify)
#     algo    algorithm variant to use               (default: a)
#             b     basic      standard algorithm (only choice)
#     mode    operation mode indicators/flags        (default: None)
#             x     do not use perfect extension pruning
#             t/T   do not organize transactions as a prefix tree
#             y     a-posteriori pruning of infrequent item sets
#             z     invalidate evaluation below expected support
#             o     use original rule support definition (body & head)
#     border  support border for filtering item sets (default: None)
#             Must be a list or tuple of (absolute) minimum support values
#             per item set size (by which the list/tuple is indexed).
#     appear  dictionary mapping items to item appearance indicators,
#             with the key None referring to the default item appearance.
#             (If None does not occur as a key or no dictionary is given,
#             the default item appearance indicator is 'both'.)
#             This parameter is only used if the target type is rules.
#             * item may not appear anywhere in a rule:
#               '-', 'n', 'none', 'neither', 'ignore'
#             * item may appear only in rule body/antecedent:
#               'i', 'in', 'inp', 'input', 'b', 'body',
#               'a', 'ante', 'antecedent'
#             * item may appear only in rule head/consequent:
#               'o', 'out',      'output', 'h', 'head',
#               'c', 'cons', 'consequent'
#             * item may appear anywhere in a rule:
#               'io', 'i&o', 'inout', 'in&out', 'bh', 'b&h', 'both'
#     returns if report is not in ['#','=','|']:
#               if the target is association rules:
#                 a list of rules (i.e. tuples with two or more elements),
#                 each consisting of a head/consequent item, a tuple with
#                 a body/antecedent item set, and the values selected by
#                 the parameter 'report', which may be combined into a
#                 tuple or a list if report[0] is '(' or '[', respectively.
#               if the target is a type of item sets:
#                 a list of patterns (i.e. tuples with one or more elements),
#                 each consisting of a tuple with a found frequent item set
#                 and the values selected by the parameter 'report', which
#                 may be combined into a tuple or list if report[0] is '('
#                 or '[', respectively
#             if report in ['#','=','|']:
#               a pattern spectrum as a dictionary mapping pattern sizes
#               to the corresponding occurrence support ranges, as a list
#               of triplets (size, min. support, max. support) or as three
#               columns for sizes and minimum and maximum support values

# %% [markdown]
# # Description of the Value

# %% [markdown]
# We have decide to do some proves with different characterized value of support. This value are 2,10,20,30,40,50,60,70,80,90.
# After that we have to do some proves with different type of target , a for frequent itemset, m for maximal itemset e c for closed itemset.
#
# For choosing the best combination we try to create the frequent itemset with different min value from the range 0-19.

# %% [markdown]
# # Support = 20%

# %% [markdown]
#  Frequent Itemsets with different min value

# %%
x = 0
for x in range (19):
    items = apriori(baskets, supp=20, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 195
# Number of itemsets for zimin 1 : 194
# Number of itemsets for zimin 2 : 167
# Number of itemsets for zimin 3 : 78
# Number of itemsets for zimin 4 : 7
# Number of itemsets for zimin 5 : 0
# Number of itemsets for zimin 6 : 0
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0

# %%
itemsets = apriori(baskets, supp=20, report ='s', target='a',zmin = 2)
print('Number of itemsets:', len(itemsets))
itemsets
# Out:
# Number of itemsets: 167
# [(('[25.0, 32.0)_Age', 'No_Attrition'), 0.20498301245753114),
#  (('Master', 'No_Attrition'), 0.21970554926387317),
#  (('[13.8, 16.6)_%', 'No_Attrition'), 0.2129105322763307),
#  (('2_YearsInCurrentRole', 'Travel_Rarely'), 0.20271800679501698),
#  (('2_YearsInCurrentRole', 'No_Attrition'), 0.22650056625141562),
#  (('Yes_OverTime', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No_OverTime'), 0.21517553793884484),
#  (('3.0_Time', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No_Attrition'), 0.23895809739524349),
#  (('Medium_Overall', 'No_OverTime'), 0.22650056625141562),
#  (('Medium_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('Medium_Overall', 'No_Attrition'), 0.21517553793884484),
#  (('[3607.8, 6206.6)_Income', 'High_Overall'), 0.20045300113250283),
#  (('[3607.8, 6206.6)_Income', 'No_OverTime'), 0.22310305775764439),
#  (('[3607.8, 6206.6)_Income', 'Travel_Rarely'), 0.20838052095130238),
#  (('[3607.8, 6206.6)_Income', 'No_Attrition'), 0.24688561721404303),
#  (('[1009.0, 3607.8)_Income', 'Male'), 0.21177802944507362),
#  (('[1009.0, 3607.8)_Income', 'High_Overall'), 0.2072480181200453),
#  (('[1009.0, 3607.8)_Income', 'No_OverTime'), 0.2287655719139298),
#  (('[1009.0, 3607.8)_Income', 'No_OverTime', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1009.0, 3607.8)_Income', 'Travel_Rarely'), 0.232163080407701),
#  (('[1009.0, 3607.8)_Income', 'No_Attrition'), 0.2718006795016987),
#  (('[1.0, 3.8)_Distance', 'Male'), 0.21404303510758776),
#  (('[1.0, 3.8)_Distance', 'High_Overall'), 0.24575311438278596),
#  (('[1.0, 3.8)_Distance', 'High_Overall', 'No_Attrition'),
#   0.21517553793884484),
#  (('[1.0, 3.8)_Distance', 'No_OverTime'), 0.25028312570781425),
#  (('[1.0, 3.8)_Distance', 'No_OverTime', 'No_Attrition'), 0.22310305775764439),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely'), 0.24575311438278596),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1.0, 3.8)_Distance', 'No_Attrition'), 0.29784824462061155),
#  (('[32.0, 39.0)_Age', 'Male'), 0.21177802944507362),
#  (('[32.0, 39.0)_Age', 'High_Overall'), 0.2491506228765572),
#  (('[32.0, 39.0)_Age', 'High_Overall', 'No_Attrition'), 0.21970554926387317),
#  (('[32.0, 39.0)_Age', 'No_OverTime'), 0.2536806342015855),
#  (('[32.0, 39.0)_Age', 'No_OverTime', 'No_Attrition'), 0.22650056625141562),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely'), 0.2536806342015855),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No_Attrition'), 0.21517553793884484),
#  (('[32.0, 39.0)_Age', 'No_Attrition'), 0.29898074745186864),
#  (('MidLevel', 'Male'), 0.22650056625141562),
#  (('MidLevel', 'Male', 'No_Attrition'), 0.20498301245753114),
#  (('MidLevel', 'High_Overall'), 0.23895809739524349),
#  (('MidLevel', 'High_Overall', 'No_Attrition'), 0.2276330690826727),
#  (('MidLevel', 'No_OverTime'), 0.26160815402038506),
#  (('MidLevel', 'No_OverTime', 'No_Attrition'), 0.24462061155152887),
#  (('MidLevel', 'Travel_Rarely'), 0.26840317100792754),
#  (('MidLevel', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('MidLevel', 'No_Attrition'), 0.3363533408833522),
#  (('1_companies', 'EntryLevel'), 0.2072480181200453),
#  (('1_companies', 'Male'), 0.24122310305775765),
#  (('1_companies', 'High_Overall'), 0.2650056625141563),
#  (('1_companies', 'High_Overall', 'Travel_Rarely'), 0.2015855039637599),
#  (('1_companies', 'High_Overall', 'No_Attrition'), 0.21857304643261607),
#  (('1_companies', 'No_OverTime'), 0.2729331823329558),
#  (('1_companies', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('1_companies', 'No_OverTime', 'No_Attrition'), 0.23895809739524349),
#  (('1_companies', 'Travel_Rarely'), 0.29331823329558326),
#  (('1_companies', 'Travel_Rarely', 'No_Attrition'), 0.23556058890147225),
#  (('1_companies', 'No_Attrition'), 0.3103057757644394),
#  (('Female', 'High_Overall'), 0.2695356738391846),
#  (('Female', 'High_Overall', 'Travel_Rarely'), 0.20271800679501698),
#  (('Female', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('Female', 'No_OverTime'), 0.27519818799546997),
#  (('Female', 'No_OverTime', 'Travel_Rarely'), 0.20045300113250283),
#  (('Female', 'No_OverTime', 'No_Attrition'), 0.2480181200453001),
#  (('Female', 'Travel_Rarely'), 0.2876557191392978),
#  (('Female', 'Travel_Rarely', 'No_Attrition'), 0.24009060022650056),
#  (('Female', 'No_Attrition'), 0.3261608154020385),
#  (('1_stockOption', 'Male'), 0.2276330690826727),
#  (('1_stockOption', 'Male', 'No_Attrition'), 0.20611551528878821),
#  (('1_stockOption', 'High_Overall'), 0.26840317100792754),
#  (('1_stockOption', 'High_Overall', 'No_Attrition'), 0.24688561721404303),
#  (('1_stockOption', 'No_OverTime'), 0.2887882219705549),
#  (('1_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.2072480181200453),
#  (('1_stockOption', 'No_OverTime', 'No_Attrition'), 0.2706681766704417),
#  (('1_stockOption', 'Travel_Rarely'), 0.2808607021517554),
#  (('1_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.2536806342015855),
#  (('1_stockOption', 'No_Attrition'), 0.34994337485843713),
#  (('Bachelor', 'Male'), 0.25141562853907135),
#  (('Bachelor', 'Male', 'No_Attrition'), 0.20271800679501698),
#  (('Bachelor', 'High_Overall'), 0.2638731596828992),
#  (('Bachelor', 'High_Overall', 'Travel_Rarely'), 0.2072480181200453),
#  (('Bachelor', 'High_Overall', 'No_Attrition'), 0.22536806342015855),
#  (('Bachelor', 'No_OverTime'), 0.3012457531143828),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely'), 0.23895809739524349),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('Bachelor', 'No_OverTime', 'No_Attrition'), 0.2638731596828992),
#  (('Bachelor', 'Travel_Rarely'), 0.3171007927519819),
#  (('Bachelor', 'Travel_Rarely', 'No_Attrition'), 0.25141562853907135),
#  (('Bachelor', 'No_Attrition'), 0.3261608154020385),
#  (('EntryLevel', '2.0_Time'), 0.20271800679501698),
#  (('EntryLevel', 'Male'), 0.24462061155152887),
#  (('EntryLevel', 'High_Overall'), 0.27746319365798416),
#  (('EntryLevel', 'High_Overall', 'No_OverTime'), 0.2015855039637599),
#  (('EntryLevel', 'High_Overall', 'No_Attrition'), 0.217440543601359),
#  (('EntryLevel', 'No_OverTime'), 0.3035107587768969),
#  (('EntryLevel', 'No_OverTime', 'Travel_Rarely'), 0.21857304643261607),
#  (('EntryLevel', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('EntryLevel', 'Travel_Rarely'), 0.3001132502831257),
#  (('EntryLevel', 'Travel_Rarely', 'No_Attrition'), 0.21064552661381652),
#  (('EntryLevel', 'No_Attrition'), 0.29784824462061155),
#  (('[11.0, 13.8)_%', '2.0_Time'), 0.20951302378255945),
#  (('[11.0, 13.8)_%', 'Male'), 0.26727066817667045),
#  (('[11.0, 13.8)_%', 'Male', 'No_Attrition'), 0.21630804077010193),
#  (('[11.0, 13.8)_%', 'High_Overall'), 0.2695356738391846),
#  (('[11.0, 13.8)_%', 'High_Overall', 'Travel_Rarely'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'High_Overall', 'No_Attrition'), 0.23103057757644394),
#  (('[11.0, 13.8)_%', 'No_OverTime'), 0.2842582106455266),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'No_Attrition'), 0.2491506228765572),
#  (('[11.0, 13.8)_%', 'Travel_Rarely'), 0.3035107587768969),
#  (('[11.0, 13.8)_%', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('[11.0, 13.8)_%', 'No_Attrition'), 0.33748584371460927),
#  (('0_stockOption', '2.0_Time'), 0.21630804077010193),
#  (('0_stockOption', 'Male'), 0.28312570781426954),
#  (('0_stockOption', 'Male', 'No_OverTime'), 0.20045300113250283),
#  (('0_stockOption', 'Male', 'Travel_Rarely'), 0.20498301245753114),
#  (('0_stockOption', 'Male', 'No_Attrition'), 0.2072480181200453),
#  (('0_stockOption', 'High_Overall'), 0.29218573046432617),
#  (('0_stockOption', 'High_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('0_stockOption', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('0_stockOption', 'No_OverTime'), 0.3091732729331823),
#  (('0_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.22310305775764439),
#  (('0_stockOption', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('0_stockOption', 'Travel_Rarely'), 0.3159682899207248),
#  (('0_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.22989807474518686),
#  (('0_stockOption', 'No_Attrition'), 0.32389580973952437),
#  (('2.0_Time', 'Male'), 0.30804077010192527),
#  (('2.0_Time', 'Male', 'High_Overall'), 0.20385050962627407),
#  (('2.0_Time', 'Male', 'No_OverTime'), 0.21064552661381652),
#  (('2.0_Time', 'Male', 'Travel_Rarely'), 0.22650056625141562),
#  (('2.0_Time', 'Male', 'No_Attrition'), 0.24235560588901472),
#  (('2.0_Time', 'High_Overall'), 0.32389580973952437),
#  (('2.0_Time', 'High_Overall', 'No_OverTime'), 0.21404303510758776),
#  (('2.0_Time', 'High_Overall', 'Travel_Rarely'), 0.23895809739524349),
#  (('2.0_Time', 'High_Overall', 'No_Attrition'), 0.2706681766704417),
#  (('2.0_Time', 'No_OverTime'), 0.32276330690826727),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely'), 0.23669309173272934),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('2.0_Time', 'No_OverTime', 'No_Attrition'), 0.2785956964892412),
#  (('2.0_Time', 'Travel_Rarely'), 0.3510758776896942),
#  (('2.0_Time', 'Travel_Rarely', 'No_Attrition'), 0.2785956964892412),
#  (('2.0_Time', 'No_Attrition'), 0.3827859569648924),
#  (('Male', 'High_Overall'), 0.3952434881087203),
#  (('Male', 'High_Overall', 'No_OverTime'), 0.27746319365798416),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely'), 0.29218573046432617),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'High_Overall', 'No_Attrition'), 0.3431483578708947),
#  (('Male', 'No_OverTime'), 0.44733861834654587),
#  (('Male', 'No_OverTime', 'Travel_Rarely'), 0.32955832389580975),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('Male', 'No_OverTime', 'No_Attrition'), 0.39184597961494905),
#  (('Male', 'Travel_Rarely'), 0.44620611551528877),
#  (('Male', 'Travel_Rarely', 'No_Attrition'), 0.3646659116647792),
#  (('Male', 'No_Attrition'), 0.5005662514156285),
#  (('High_Overall', 'No_OverTime'), 0.4654586636466591),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely'), 0.3431483578708947),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248),
#  (('High_Overall', 'No_OverTime', 'No_Attrition'), 0.42808607021517553),
#  (('High_Overall', 'Travel_Rarely'), 0.49490373725934317),
#  (('High_Overall', 'Travel_Rarely', 'No_Attrition'), 0.4258210645526614),
#  (('High_Overall', 'No_Attrition'), 0.5764439411098528),
#  (('No_OverTime', 'Travel_Rarely'), 0.5300113250283126),
#  (('No_OverTime', 'Travel_Rarely', 'No_Attrition'), 0.46885617214043035),
#  (('No_OverTime', 'No_Attrition'), 0.6398640996602492),
#  (('Travel_Rarely', 'No_Attrition'), 0.6047565118912798)]

# %%
itemsets1 = apriori(baskets, supp=20, report ='s', target='a',zmin = 3)
print('Number of itemsets:', len(itemsets1))
itemsets1
# Out:
# Number of itemsets: 78
# [(('[1009.0, 3607.8)_Income', 'No_OverTime', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1.0, 3.8)_Distance', 'High_Overall', 'No_Attrition'),
#   0.21517553793884484),
#  (('[1.0, 3.8)_Distance', 'No_OverTime', 'No_Attrition'), 0.22310305775764439),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No_Attrition'),
#   0.20498301245753114),
#  (('[32.0, 39.0)_Age', 'High_Overall', 'No_Attrition'), 0.21970554926387317),
#  (('[32.0, 39.0)_Age', 'No_OverTime', 'No_Attrition'), 0.22650056625141562),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No_Attrition'), 0.21517553793884484),
#  (('MidLevel', 'Male', 'No_Attrition'), 0.20498301245753114),
#  (('MidLevel', 'High_Overall', 'No_Attrition'), 0.2276330690826727),
#  (('MidLevel', 'No_OverTime', 'No_Attrition'), 0.24462061155152887),
#  (('MidLevel', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('1_companies', 'High_Overall', 'Travel_Rarely'), 0.2015855039637599),
#  (('1_companies', 'High_Overall', 'No_Attrition'), 0.21857304643261607),
#  (('1_companies', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('1_companies', 'No_OverTime', 'No_Attrition'), 0.23895809739524349),
#  (('1_companies', 'Travel_Rarely', 'No_Attrition'), 0.23556058890147225),
#  (('Female', 'High_Overall', 'Travel_Rarely'), 0.20271800679501698),
#  (('Female', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('Female', 'No_OverTime', 'Travel_Rarely'), 0.20045300113250283),
#  (('Female', 'No_OverTime', 'No_Attrition'), 0.2480181200453001),
#  (('Female', 'Travel_Rarely', 'No_Attrition'), 0.24009060022650056),
#  (('1_stockOption', 'Male', 'No_Attrition'), 0.20611551528878821),
#  (('1_stockOption', 'High_Overall', 'No_Attrition'), 0.24688561721404303),
#  (('1_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.2072480181200453),
#  (('1_stockOption', 'No_OverTime', 'No_Attrition'), 0.2706681766704417),
#  (('1_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.2536806342015855),
#  (('Bachelor', 'Male', 'No_Attrition'), 0.20271800679501698),
#  (('Bachelor', 'High_Overall', 'Travel_Rarely'), 0.2072480181200453),
#  (('Bachelor', 'High_Overall', 'No_Attrition'), 0.22536806342015855),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely'), 0.23895809739524349),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('Bachelor', 'No_OverTime', 'No_Attrition'), 0.2638731596828992),
#  (('Bachelor', 'Travel_Rarely', 'No_Attrition'), 0.25141562853907135),
#  (('EntryLevel', 'High_Overall', 'No_OverTime'), 0.2015855039637599),
#  (('EntryLevel', 'High_Overall', 'No_Attrition'), 0.217440543601359),
#  (('EntryLevel', 'No_OverTime', 'Travel_Rarely'), 0.21857304643261607),
#  (('EntryLevel', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('EntryLevel', 'Travel_Rarely', 'No_Attrition'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'Male', 'No_Attrition'), 0.21630804077010193),
#  (('[11.0, 13.8)_%', 'High_Overall', 'Travel_Rarely'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'High_Overall', 'No_Attrition'), 0.23103057757644394),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'No_Attrition'), 0.2491506228765572),
#  (('[11.0, 13.8)_%', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('0_stockOption', 'Male', 'No_OverTime'), 0.20045300113250283),
#  (('0_stockOption', 'Male', 'Travel_Rarely'), 0.20498301245753114),
#  (('0_stockOption', 'Male', 'No_Attrition'), 0.2072480181200453),
#  (('0_stockOption', 'High_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('0_stockOption', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('0_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.22310305775764439),
#  (('0_stockOption', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('0_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.22989807474518686),
#  (('2.0_Time', 'Male', 'High_Overall'), 0.20385050962627407),
#  (('2.0_Time', 'Male', 'No_OverTime'), 0.21064552661381652),
#  (('2.0_Time', 'Male', 'Travel_Rarely'), 0.22650056625141562),
#  (('2.0_Time', 'Male', 'No_Attrition'), 0.24235560588901472),
#  (('2.0_Time', 'High_Overall', 'No_OverTime'), 0.21404303510758776),
#  (('2.0_Time', 'High_Overall', 'Travel_Rarely'), 0.23895809739524349),
#  (('2.0_Time', 'High_Overall', 'No_Attrition'), 0.2706681766704417),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely'), 0.23669309173272934),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('2.0_Time', 'No_OverTime', 'No_Attrition'), 0.2785956964892412),
#  (('2.0_Time', 'Travel_Rarely', 'No_Attrition'), 0.2785956964892412),
#  (('Male', 'High_Overall', 'No_OverTime'), 0.27746319365798416),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely'), 0.29218573046432617),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'High_Overall', 'No_Attrition'), 0.3431483578708947),
#  (('Male', 'No_OverTime', 'Travel_Rarely'), 0.32955832389580975),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('Male', 'No_OverTime', 'No_Attrition'), 0.39184597961494905),
#  (('Male', 'Travel_Rarely', 'No_Attrition'), 0.3646659116647792),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely'), 0.3431483578708947),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248),
#  (('High_Overall', 'No_OverTime', 'No_Attrition'), 0.42808607021517553),
#  (('High_Overall', 'Travel_Rarely', 'No_Attrition'), 0.4258210645526614),
#  (('No_OverTime', 'Travel_Rarely', 'No_Attrition'), 0.46885617214043035)]

# %%
itemsets2 = apriori(baskets, supp=20, report ='s', target='a',zmin = 4)
print('Number of itemsets:', len(itemsets2))
itemsets2
# Out:
# Number of itemsets: 7
# [(('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248)]

# %% [markdown]
# Maximal Itemset with min value range 0-19

# %%
x = 0
for x in range (19):
    items1 = apriori(baskets, supp=20, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items1))
# Out:
# Number of itemsets for zimin 0 : 91
# Number of itemsets for zimin 1 : 91
# Number of itemsets for zimin 2 : 89
# Number of itemsets for zimin 3 : 62
# Number of itemsets for zimin 4 : 7
# Number of itemsets for zimin 5 : 0
# Number of itemsets for zimin 6 : 0
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0

# %%
itemsets3 = apriori(baskets, supp=20, report ='s', target='m',zmin = 2)
print('Number of itemsets:', len(itemsets3))
itemsets3
# Out:
# Number of itemsets: 89
# [(('[25.0, 32.0)_Age', 'No_Attrition'), 0.20498301245753114),
#  (('Master', 'No_Attrition'), 0.21970554926387317),
#  (('[13.8, 16.6)_%', 'No_Attrition'), 0.2129105322763307),
#  (('2_YearsInCurrentRole', 'Travel_Rarely'), 0.20271800679501698),
#  (('2_YearsInCurrentRole', 'No_Attrition'), 0.22650056625141562),
#  (('Yes_OverTime', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No_OverTime'), 0.21517553793884484),
#  (('3.0_Time', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No_Attrition'), 0.23895809739524349),
#  (('Medium_Overall', 'No_OverTime'), 0.22650056625141562),
#  (('Medium_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('Medium_Overall', 'No_Attrition'), 0.21517553793884484),
#  (('[3607.8, 6206.6)_Income', 'High_Overall'), 0.20045300113250283),
#  (('[3607.8, 6206.6)_Income', 'No_OverTime'), 0.22310305775764439),
#  (('[3607.8, 6206.6)_Income', 'Travel_Rarely'), 0.20838052095130238),
#  (('[3607.8, 6206.6)_Income', 'No_Attrition'), 0.24688561721404303),
#  (('[1009.0, 3607.8)_Income', 'Male'), 0.21177802944507362),
#  (('[1009.0, 3607.8)_Income', 'High_Overall'), 0.2072480181200453),
#  (('[1009.0, 3607.8)_Income', 'No_OverTime', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1009.0, 3607.8)_Income', 'Travel_Rarely'), 0.232163080407701),
#  (('[1.0, 3.8)_Distance', 'Male'), 0.21404303510758776),
#  (('[1.0, 3.8)_Distance', 'High_Overall', 'No_Attrition'),
#   0.21517553793884484),
#  (('[1.0, 3.8)_Distance', 'No_OverTime', 'No_Attrition'), 0.22310305775764439),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No_Attrition'),
#   0.20498301245753114),
#  (('[32.0, 39.0)_Age', 'Male'), 0.21177802944507362),
#  (('[32.0, 39.0)_Age', 'High_Overall', 'No_Attrition'), 0.21970554926387317),
#  (('[32.0, 39.0)_Age', 'No_OverTime', 'No_Attrition'), 0.22650056625141562),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No_Attrition'), 0.21517553793884484),
#  (('MidLevel', 'Male', 'No_Attrition'), 0.20498301245753114),
#  (('MidLevel', 'High_Overall', 'No_Attrition'), 0.2276330690826727),
#  (('MidLevel', 'No_OverTime', 'No_Attrition'), 0.24462061155152887),
#  (('MidLevel', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('1_companies', 'EntryLevel'), 0.2072480181200453),
#  (('1_companies', 'Male'), 0.24122310305775765),
#  (('1_companies', 'High_Overall', 'Travel_Rarely'), 0.2015855039637599),
#  (('1_companies', 'High_Overall', 'No_Attrition'), 0.21857304643261607),
#  (('1_companies', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('1_companies', 'No_OverTime', 'No_Attrition'), 0.23895809739524349),
#  (('1_companies', 'Travel_Rarely', 'No_Attrition'), 0.23556058890147225),
#  (('Female', 'High_Overall', 'Travel_Rarely'), 0.20271800679501698),
#  (('Female', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('Female', 'No_OverTime', 'Travel_Rarely'), 0.20045300113250283),
#  (('Female', 'No_OverTime', 'No_Attrition'), 0.2480181200453001),
#  (('Female', 'Travel_Rarely', 'No_Attrition'), 0.24009060022650056),
#  (('1_stockOption', 'Male', 'No_Attrition'), 0.20611551528878821),
#  (('1_stockOption', 'High_Overall', 'No_Attrition'), 0.24688561721404303),
#  (('1_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.2072480181200453),
#  (('1_stockOption', 'No_OverTime', 'No_Attrition'), 0.2706681766704417),
#  (('1_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.2536806342015855),
#  (('Bachelor', 'Male', 'No_Attrition'), 0.20271800679501698),
#  (('Bachelor', 'High_Overall', 'Travel_Rarely'), 0.2072480181200453),
#  (('Bachelor', 'High_Overall', 'No_Attrition'), 0.22536806342015855),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('EntryLevel', '2.0_Time'), 0.20271800679501698),
#  (('EntryLevel', 'Male'), 0.24462061155152887),
#  (('EntryLevel', 'High_Overall', 'No_OverTime'), 0.2015855039637599),
#  (('EntryLevel', 'High_Overall', 'No_Attrition'), 0.217440543601359),
#  (('EntryLevel', 'No_OverTime', 'Travel_Rarely'), 0.21857304643261607),
#  (('EntryLevel', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('EntryLevel', 'Travel_Rarely', 'No_Attrition'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', '2.0_Time'), 0.20951302378255945),
#  (('[11.0, 13.8)_%', 'Male', 'No_Attrition'), 0.21630804077010193),
#  (('[11.0, 13.8)_%', 'High_Overall', 'Travel_Rarely'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'High_Overall', 'No_Attrition'), 0.23103057757644394),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'No_Attrition'), 0.2491506228765572),
#  (('[11.0, 13.8)_%', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('0_stockOption', '2.0_Time'), 0.21630804077010193),
#  (('0_stockOption', 'Male', 'No_OverTime'), 0.20045300113250283),
#  (('0_stockOption', 'Male', 'Travel_Rarely'), 0.20498301245753114),
#  (('0_stockOption', 'Male', 'No_Attrition'), 0.2072480181200453),
#  (('0_stockOption', 'High_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('0_stockOption', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('0_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.22310305775764439),
#  (('0_stockOption', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('0_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.22989807474518686),
#  (('2.0_Time', 'Male', 'High_Overall'), 0.20385050962627407),
#  (('2.0_Time', 'Male', 'No_OverTime'), 0.21064552661381652),
#  (('2.0_Time', 'Male', 'Travel_Rarely'), 0.22650056625141562),
#  (('2.0_Time', 'Male', 'No_Attrition'), 0.24235560588901472),
#  (('2.0_Time', 'High_Overall', 'No_OverTime'), 0.21404303510758776),
#  (('2.0_Time', 'High_Overall', 'Travel_Rarely'), 0.23895809739524349),
#  (('2.0_Time', 'High_Overall', 'No_Attrition'), 0.2706681766704417),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248)]

# %%
itemsets4 = apriori(baskets, supp=20, report ='s', target='m',zmin = 3)
print('Number of itemsets:', len(itemsets4))
itemsets4
# Out:
# Number of itemsets: 62
# [(('[1009.0, 3607.8)_Income', 'No_OverTime', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1.0, 3.8)_Distance', 'High_Overall', 'No_Attrition'),
#   0.21517553793884484),
#  (('[1.0, 3.8)_Distance', 'No_OverTime', 'No_Attrition'), 0.22310305775764439),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No_Attrition'),
#   0.20498301245753114),
#  (('[32.0, 39.0)_Age', 'High_Overall', 'No_Attrition'), 0.21970554926387317),
#  (('[32.0, 39.0)_Age', 'No_OverTime', 'No_Attrition'), 0.22650056625141562),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No_Attrition'), 0.21517553793884484),
#  (('MidLevel', 'Male', 'No_Attrition'), 0.20498301245753114),
#  (('MidLevel', 'High_Overall', 'No_Attrition'), 0.2276330690826727),
#  (('MidLevel', 'No_OverTime', 'No_Attrition'), 0.24462061155152887),
#  (('MidLevel', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('1_companies', 'High_Overall', 'Travel_Rarely'), 0.2015855039637599),
#  (('1_companies', 'High_Overall', 'No_Attrition'), 0.21857304643261607),
#  (('1_companies', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('1_companies', 'No_OverTime', 'No_Attrition'), 0.23895809739524349),
#  (('1_companies', 'Travel_Rarely', 'No_Attrition'), 0.23556058890147225),
#  (('Female', 'High_Overall', 'Travel_Rarely'), 0.20271800679501698),
#  (('Female', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('Female', 'No_OverTime', 'Travel_Rarely'), 0.20045300113250283),
#  (('Female', 'No_OverTime', 'No_Attrition'), 0.2480181200453001),
#  (('Female', 'Travel_Rarely', 'No_Attrition'), 0.24009060022650056),
#  (('1_stockOption', 'Male', 'No_Attrition'), 0.20611551528878821),
#  (('1_stockOption', 'High_Overall', 'No_Attrition'), 0.24688561721404303),
#  (('1_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.2072480181200453),
#  (('1_stockOption', 'No_OverTime', 'No_Attrition'), 0.2706681766704417),
#  (('1_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.2536806342015855),
#  (('Bachelor', 'Male', 'No_Attrition'), 0.20271800679501698),
#  (('Bachelor', 'High_Overall', 'Travel_Rarely'), 0.2072480181200453),
#  (('Bachelor', 'High_Overall', 'No_Attrition'), 0.22536806342015855),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('EntryLevel', 'High_Overall', 'No_OverTime'), 0.2015855039637599),
#  (('EntryLevel', 'High_Overall', 'No_Attrition'), 0.217440543601359),
#  (('EntryLevel', 'No_OverTime', 'Travel_Rarely'), 0.21857304643261607),
#  (('EntryLevel', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('EntryLevel', 'Travel_Rarely', 'No_Attrition'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'Male', 'No_Attrition'), 0.21630804077010193),
#  (('[11.0, 13.8)_%', 'High_Overall', 'Travel_Rarely'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'High_Overall', 'No_Attrition'), 0.23103057757644394),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'No_Attrition'), 0.2491506228765572),
#  (('[11.0, 13.8)_%', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('0_stockOption', 'Male', 'No_OverTime'), 0.20045300113250283),
#  (('0_stockOption', 'Male', 'Travel_Rarely'), 0.20498301245753114),
#  (('0_stockOption', 'Male', 'No_Attrition'), 0.2072480181200453),
#  (('0_stockOption', 'High_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('0_stockOption', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('0_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.22310305775764439),
#  (('0_stockOption', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('0_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.22989807474518686),
#  (('2.0_Time', 'Male', 'High_Overall'), 0.20385050962627407),
#  (('2.0_Time', 'Male', 'No_OverTime'), 0.21064552661381652),
#  (('2.0_Time', 'Male', 'Travel_Rarely'), 0.22650056625141562),
#  (('2.0_Time', 'Male', 'No_Attrition'), 0.24235560588901472),
#  (('2.0_Time', 'High_Overall', 'No_OverTime'), 0.21404303510758776),
#  (('2.0_Time', 'High_Overall', 'Travel_Rarely'), 0.23895809739524349),
#  (('2.0_Time', 'High_Overall', 'No_Attrition'), 0.2706681766704417),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248)]

# %%
itemsets5 = apriori(baskets, supp=20, report ='s', target='m',zmin = 4)
print('Number of itemsets:', len(itemsets5))
itemsets5
# Out:
# Number of itemsets: 7
# [(('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248)]

# %% [markdown]
# Closed Itemset with min value range 0-19

# %%
x = 0
for x in range (19):
    items2 = apriori(baskets, supp=20, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items2))
# Out:
# Number of itemsets for zimin 0 : 195
# Number of itemsets for zimin 1 : 194
# Number of itemsets for zimin 2 : 167
# Number of itemsets for zimin 3 : 78
# Number of itemsets for zimin 4 : 7
# Number of itemsets for zimin 5 : 0
# Number of itemsets for zimin 6 : 0
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0

# %%
itemsets6 = apriori(baskets, supp=20, report ='s', target='c',zmin = 2)
print('Number of itemsets:', len(itemsets6))
itemsets6
# Out:
# Number of itemsets: 167
# [(('[25.0, 32.0)_Age', 'No_Attrition'), 0.20498301245753114),
#  (('Master', 'No_Attrition'), 0.21970554926387317),
#  (('[13.8, 16.6)_%', 'No_Attrition'), 0.2129105322763307),
#  (('2_YearsInCurrentRole', 'Travel_Rarely'), 0.20271800679501698),
#  (('2_YearsInCurrentRole', 'No_Attrition'), 0.22650056625141562),
#  (('Yes_OverTime', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No_OverTime'), 0.21517553793884484),
#  (('3.0_Time', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No_Attrition'), 0.23895809739524349),
#  (('Medium_Overall', 'No_OverTime'), 0.22650056625141562),
#  (('Medium_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('Medium_Overall', 'No_Attrition'), 0.21517553793884484),
#  (('[3607.8, 6206.6)_Income', 'High_Overall'), 0.20045300113250283),
#  (('[3607.8, 6206.6)_Income', 'No_OverTime'), 0.22310305775764439),
#  (('[3607.8, 6206.6)_Income', 'Travel_Rarely'), 0.20838052095130238),
#  (('[3607.8, 6206.6)_Income', 'No_Attrition'), 0.24688561721404303),
#  (('[1009.0, 3607.8)_Income', 'Male'), 0.21177802944507362),
#  (('[1009.0, 3607.8)_Income', 'High_Overall'), 0.2072480181200453),
#  (('[1009.0, 3607.8)_Income', 'No_OverTime'), 0.2287655719139298),
#  (('[1009.0, 3607.8)_Income', 'No_OverTime', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1009.0, 3607.8)_Income', 'Travel_Rarely'), 0.232163080407701),
#  (('[1009.0, 3607.8)_Income', 'No_Attrition'), 0.2718006795016987),
#  (('[1.0, 3.8)_Distance', 'Male'), 0.21404303510758776),
#  (('[1.0, 3.8)_Distance', 'High_Overall'), 0.24575311438278596),
#  (('[1.0, 3.8)_Distance', 'High_Overall', 'No_Attrition'),
#   0.21517553793884484),
#  (('[1.0, 3.8)_Distance', 'No_OverTime'), 0.25028312570781425),
#  (('[1.0, 3.8)_Distance', 'No_OverTime', 'No_Attrition'), 0.22310305775764439),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely'), 0.24575311438278596),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1.0, 3.8)_Distance', 'No_Attrition'), 0.29784824462061155),
#  (('[32.0, 39.0)_Age', 'Male'), 0.21177802944507362),
#  (('[32.0, 39.0)_Age', 'High_Overall'), 0.2491506228765572),
#  (('[32.0, 39.0)_Age', 'High_Overall', 'No_Attrition'), 0.21970554926387317),
#  (('[32.0, 39.0)_Age', 'No_OverTime'), 0.2536806342015855),
#  (('[32.0, 39.0)_Age', 'No_OverTime', 'No_Attrition'), 0.22650056625141562),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely'), 0.2536806342015855),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No_Attrition'), 0.21517553793884484),
#  (('[32.0, 39.0)_Age', 'No_Attrition'), 0.29898074745186864),
#  (('MidLevel', 'Male'), 0.22650056625141562),
#  (('MidLevel', 'Male', 'No_Attrition'), 0.20498301245753114),
#  (('MidLevel', 'High_Overall'), 0.23895809739524349),
#  (('MidLevel', 'High_Overall', 'No_Attrition'), 0.2276330690826727),
#  (('MidLevel', 'No_OverTime'), 0.26160815402038506),
#  (('MidLevel', 'No_OverTime', 'No_Attrition'), 0.24462061155152887),
#  (('MidLevel', 'Travel_Rarely'), 0.26840317100792754),
#  (('MidLevel', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('MidLevel', 'No_Attrition'), 0.3363533408833522),
#  (('1_companies', 'EntryLevel'), 0.2072480181200453),
#  (('1_companies', 'Male'), 0.24122310305775765),
#  (('1_companies', 'High_Overall'), 0.2650056625141563),
#  (('1_companies', 'High_Overall', 'Travel_Rarely'), 0.2015855039637599),
#  (('1_companies', 'High_Overall', 'No_Attrition'), 0.21857304643261607),
#  (('1_companies', 'No_OverTime'), 0.2729331823329558),
#  (('1_companies', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('1_companies', 'No_OverTime', 'No_Attrition'), 0.23895809739524349),
#  (('1_companies', 'Travel_Rarely'), 0.29331823329558326),
#  (('1_companies', 'Travel_Rarely', 'No_Attrition'), 0.23556058890147225),
#  (('1_companies', 'No_Attrition'), 0.3103057757644394),
#  (('Female', 'High_Overall'), 0.2695356738391846),
#  (('Female', 'High_Overall', 'Travel_Rarely'), 0.20271800679501698),
#  (('Female', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('Female', 'No_OverTime'), 0.27519818799546997),
#  (('Female', 'No_OverTime', 'Travel_Rarely'), 0.20045300113250283),
#  (('Female', 'No_OverTime', 'No_Attrition'), 0.2480181200453001),
#  (('Female', 'Travel_Rarely'), 0.2876557191392978),
#  (('Female', 'Travel_Rarely', 'No_Attrition'), 0.24009060022650056),
#  (('Female', 'No_Attrition'), 0.3261608154020385),
#  (('1_stockOption', 'Male'), 0.2276330690826727),
#  (('1_stockOption', 'Male', 'No_Attrition'), 0.20611551528878821),
#  (('1_stockOption', 'High_Overall'), 0.26840317100792754),
#  (('1_stockOption', 'High_Overall', 'No_Attrition'), 0.24688561721404303),
#  (('1_stockOption', 'No_OverTime'), 0.2887882219705549),
#  (('1_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.2072480181200453),
#  (('1_stockOption', 'No_OverTime', 'No_Attrition'), 0.2706681766704417),
#  (('1_stockOption', 'Travel_Rarely'), 0.2808607021517554),
#  (('1_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.2536806342015855),
#  (('1_stockOption', 'No_Attrition'), 0.34994337485843713),
#  (('Bachelor', 'Male'), 0.25141562853907135),
#  (('Bachelor', 'Male', 'No_Attrition'), 0.20271800679501698),
#  (('Bachelor', 'High_Overall'), 0.2638731596828992),
#  (('Bachelor', 'High_Overall', 'Travel_Rarely'), 0.2072480181200453),
#  (('Bachelor', 'High_Overall', 'No_Attrition'), 0.22536806342015855),
#  (('Bachelor', 'No_OverTime'), 0.3012457531143828),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely'), 0.23895809739524349),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('Bachelor', 'No_OverTime', 'No_Attrition'), 0.2638731596828992),
#  (('Bachelor', 'Travel_Rarely'), 0.3171007927519819),
#  (('Bachelor', 'Travel_Rarely', 'No_Attrition'), 0.25141562853907135),
#  (('Bachelor', 'No_Attrition'), 0.3261608154020385),
#  (('EntryLevel', '2.0_Time'), 0.20271800679501698),
#  (('EntryLevel', 'Male'), 0.24462061155152887),
#  (('EntryLevel', 'High_Overall'), 0.27746319365798416),
#  (('EntryLevel', 'High_Overall', 'No_OverTime'), 0.2015855039637599),
#  (('EntryLevel', 'High_Overall', 'No_Attrition'), 0.217440543601359),
#  (('EntryLevel', 'No_OverTime'), 0.3035107587768969),
#  (('EntryLevel', 'No_OverTime', 'Travel_Rarely'), 0.21857304643261607),
#  (('EntryLevel', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('EntryLevel', 'Travel_Rarely'), 0.3001132502831257),
#  (('EntryLevel', 'Travel_Rarely', 'No_Attrition'), 0.21064552661381652),
#  (('EntryLevel', 'No_Attrition'), 0.29784824462061155),
#  (('[11.0, 13.8)_%', '2.0_Time'), 0.20951302378255945),
#  (('[11.0, 13.8)_%', 'Male'), 0.26727066817667045),
#  (('[11.0, 13.8)_%', 'Male', 'No_Attrition'), 0.21630804077010193),
#  (('[11.0, 13.8)_%', 'High_Overall'), 0.2695356738391846),
#  (('[11.0, 13.8)_%', 'High_Overall', 'Travel_Rarely'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'High_Overall', 'No_Attrition'), 0.23103057757644394),
#  (('[11.0, 13.8)_%', 'No_OverTime'), 0.2842582106455266),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'No_Attrition'), 0.2491506228765572),
#  (('[11.0, 13.8)_%', 'Travel_Rarely'), 0.3035107587768969),
#  (('[11.0, 13.8)_%', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('[11.0, 13.8)_%', 'No_Attrition'), 0.33748584371460927),
#  (('0_stockOption', '2.0_Time'), 0.21630804077010193),
#  (('0_stockOption', 'Male'), 0.28312570781426954),
#  (('0_stockOption', 'Male', 'No_OverTime'), 0.20045300113250283),
#  (('0_stockOption', 'Male', 'Travel_Rarely'), 0.20498301245753114),
#  (('0_stockOption', 'Male', 'No_Attrition'), 0.2072480181200453),
#  (('0_stockOption', 'High_Overall'), 0.29218573046432617),
#  (('0_stockOption', 'High_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('0_stockOption', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('0_stockOption', 'No_OverTime'), 0.3091732729331823),
#  (('0_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.22310305775764439),
#  (('0_stockOption', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('0_stockOption', 'Travel_Rarely'), 0.3159682899207248),
#  (('0_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.22989807474518686),
#  (('0_stockOption', 'No_Attrition'), 0.32389580973952437),
#  (('2.0_Time', 'Male'), 0.30804077010192527),
#  (('2.0_Time', 'Male', 'High_Overall'), 0.20385050962627407),
#  (('2.0_Time', 'Male', 'No_OverTime'), 0.21064552661381652),
#  (('2.0_Time', 'Male', 'Travel_Rarely'), 0.22650056625141562),
#  (('2.0_Time', 'Male', 'No_Attrition'), 0.24235560588901472),
#  (('2.0_Time', 'High_Overall'), 0.32389580973952437),
#  (('2.0_Time', 'High_Overall', 'No_OverTime'), 0.21404303510758776),
#  (('2.0_Time', 'High_Overall', 'Travel_Rarely'), 0.23895809739524349),
#  (('2.0_Time', 'High_Overall', 'No_Attrition'), 0.2706681766704417),
#  (('2.0_Time', 'No_OverTime'), 0.32276330690826727),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely'), 0.23669309173272934),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('2.0_Time', 'No_OverTime', 'No_Attrition'), 0.2785956964892412),
#  (('2.0_Time', 'Travel_Rarely'), 0.3510758776896942),
#  (('2.0_Time', 'Travel_Rarely', 'No_Attrition'), 0.2785956964892412),
#  (('2.0_Time', 'No_Attrition'), 0.3827859569648924),
#  (('Male', 'High_Overall'), 0.3952434881087203),
#  (('Male', 'High_Overall', 'No_OverTime'), 0.27746319365798416),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely'), 0.29218573046432617),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'High_Overall', 'No_Attrition'), 0.3431483578708947),
#  (('Male', 'No_OverTime'), 0.44733861834654587),
#  (('Male', 'No_OverTime', 'Travel_Rarely'), 0.32955832389580975),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('Male', 'No_OverTime', 'No_Attrition'), 0.39184597961494905),
#  (('Male', 'Travel_Rarely'), 0.44620611551528877),
#  (('Male', 'Travel_Rarely', 'No_Attrition'), 0.3646659116647792),
#  (('Male', 'No_Attrition'), 0.5005662514156285),
#  (('High_Overall', 'No_OverTime'), 0.4654586636466591),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely'), 0.3431483578708947),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248),
#  (('High_Overall', 'No_OverTime', 'No_Attrition'), 0.42808607021517553),
#  (('High_Overall', 'Travel_Rarely'), 0.49490373725934317),
#  (('High_Overall', 'Travel_Rarely', 'No_Attrition'), 0.4258210645526614),
#  (('High_Overall', 'No_Attrition'), 0.5764439411098528),
#  (('No_OverTime', 'Travel_Rarely'), 0.5300113250283126),
#  (('No_OverTime', 'Travel_Rarely', 'No_Attrition'), 0.46885617214043035),
#  (('No_OverTime', 'No_Attrition'), 0.6398640996602492),
#  (('Travel_Rarely', 'No_Attrition'), 0.6047565118912798)]

# %%
itemsets7 = apriori(baskets, supp=20, report ='s', target='c',zmin = 3)
print('Number of itemsets:', len(itemsets7))
itemsets7
# Out:
# Number of itemsets: 78
# [(('[1009.0, 3607.8)_Income', 'No_OverTime', 'No_Attrition'),
#   0.20498301245753114),
#  (('[1.0, 3.8)_Distance', 'High_Overall', 'No_Attrition'),
#   0.21517553793884484),
#  (('[1.0, 3.8)_Distance', 'No_OverTime', 'No_Attrition'), 0.22310305775764439),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No_Attrition'),
#   0.20498301245753114),
#  (('[32.0, 39.0)_Age', 'High_Overall', 'No_Attrition'), 0.21970554926387317),
#  (('[32.0, 39.0)_Age', 'No_OverTime', 'No_Attrition'), 0.22650056625141562),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No_Attrition'), 0.21517553793884484),
#  (('MidLevel', 'Male', 'No_Attrition'), 0.20498301245753114),
#  (('MidLevel', 'High_Overall', 'No_Attrition'), 0.2276330690826727),
#  (('MidLevel', 'No_OverTime', 'No_Attrition'), 0.24462061155152887),
#  (('MidLevel', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('1_companies', 'High_Overall', 'Travel_Rarely'), 0.2015855039637599),
#  (('1_companies', 'High_Overall', 'No_Attrition'), 0.21857304643261607),
#  (('1_companies', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('1_companies', 'No_OverTime', 'No_Attrition'), 0.23895809739524349),
#  (('1_companies', 'Travel_Rarely', 'No_Attrition'), 0.23556058890147225),
#  (('Female', 'High_Overall', 'Travel_Rarely'), 0.20271800679501698),
#  (('Female', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('Female', 'No_OverTime', 'Travel_Rarely'), 0.20045300113250283),
#  (('Female', 'No_OverTime', 'No_Attrition'), 0.2480181200453001),
#  (('Female', 'Travel_Rarely', 'No_Attrition'), 0.24009060022650056),
#  (('1_stockOption', 'Male', 'No_Attrition'), 0.20611551528878821),
#  (('1_stockOption', 'High_Overall', 'No_Attrition'), 0.24688561721404303),
#  (('1_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.2072480181200453),
#  (('1_stockOption', 'No_OverTime', 'No_Attrition'), 0.2706681766704417),
#  (('1_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.2536806342015855),
#  (('Bachelor', 'Male', 'No_Attrition'), 0.20271800679501698),
#  (('Bachelor', 'High_Overall', 'Travel_Rarely'), 0.2072480181200453),
#  (('Bachelor', 'High_Overall', 'No_Attrition'), 0.22536806342015855),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely'), 0.23895809739524349),
#  (('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('Bachelor', 'No_OverTime', 'No_Attrition'), 0.2638731596828992),
#  (('Bachelor', 'Travel_Rarely', 'No_Attrition'), 0.25141562853907135),
#  (('EntryLevel', 'High_Overall', 'No_OverTime'), 0.2015855039637599),
#  (('EntryLevel', 'High_Overall', 'No_Attrition'), 0.217440543601359),
#  (('EntryLevel', 'No_OverTime', 'Travel_Rarely'), 0.21857304643261607),
#  (('EntryLevel', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('EntryLevel', 'Travel_Rarely', 'No_Attrition'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'Male', 'No_Attrition'), 0.21630804077010193),
#  (('[11.0, 13.8)_%', 'High_Overall', 'Travel_Rarely'), 0.21064552661381652),
#  (('[11.0, 13.8)_%', 'High_Overall', 'No_Attrition'), 0.23103057757644394),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'Travel_Rarely'), 0.20838052095130238),
#  (('[11.0, 13.8)_%', 'No_OverTime', 'No_Attrition'), 0.2491506228765572),
#  (('[11.0, 13.8)_%', 'Travel_Rarely', 'No_Attrition'), 0.2480181200453001),
#  (('0_stockOption', 'Male', 'No_OverTime'), 0.20045300113250283),
#  (('0_stockOption', 'Male', 'Travel_Rarely'), 0.20498301245753114),
#  (('0_stockOption', 'Male', 'No_Attrition'), 0.2072480181200453),
#  (('0_stockOption', 'High_Overall', 'Travel_Rarely'), 0.2129105322763307),
#  (('0_stockOption', 'High_Overall', 'No_Attrition'), 0.2332955832389581),
#  (('0_stockOption', 'No_OverTime', 'Travel_Rarely'), 0.22310305775764439),
#  (('0_stockOption', 'No_OverTime', 'No_Attrition'), 0.25254813137032844),
#  (('0_stockOption', 'Travel_Rarely', 'No_Attrition'), 0.22989807474518686),
#  (('2.0_Time', 'Male', 'High_Overall'), 0.20385050962627407),
#  (('2.0_Time', 'Male', 'No_OverTime'), 0.21064552661381652),
#  (('2.0_Time', 'Male', 'Travel_Rarely'), 0.22650056625141562),
#  (('2.0_Time', 'Male', 'No_Attrition'), 0.24235560588901472),
#  (('2.0_Time', 'High_Overall', 'No_OverTime'), 0.21404303510758776),
#  (('2.0_Time', 'High_Overall', 'Travel_Rarely'), 0.23895809739524349),
#  (('2.0_Time', 'High_Overall', 'No_Attrition'), 0.2706681766704417),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely'), 0.23669309173272934),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('2.0_Time', 'No_OverTime', 'No_Attrition'), 0.2785956964892412),
#  (('2.0_Time', 'Travel_Rarely', 'No_Attrition'), 0.2785956964892412),
#  (('Male', 'High_Overall', 'No_OverTime'), 0.27746319365798416),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely'), 0.29218573046432617),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'High_Overall', 'No_Attrition'), 0.3431483578708947),
#  (('Male', 'No_OverTime', 'Travel_Rarely'), 0.32955832389580975),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('Male', 'No_OverTime', 'No_Attrition'), 0.39184597961494905),
#  (('Male', 'Travel_Rarely', 'No_Attrition'), 0.3646659116647792),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely'), 0.3431483578708947),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248),
#  (('High_Overall', 'No_OverTime', 'No_Attrition'), 0.42808607021517553),
#  (('High_Overall', 'Travel_Rarely', 'No_Attrition'), 0.4258210645526614),
#  (('No_OverTime', 'Travel_Rarely', 'No_Attrition'), 0.46885617214043035)]

# %%
itemsets8 = apriori(baskets, supp=20, report ='s', target='c',zmin = 4)
print('Number of itemsets:', len(itemsets8))
itemsets8
# Out:
# Number of itemsets: 7
# [(('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2072480181200453),
#  (('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.20385050962627407),
#  (('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   0.20498301245753114),
#  (('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'), 0.2548131370328426),
#  (('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   0.2536806342015855),
#  (('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.2876557191392978),
#  (('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   0.3159682899207248)]

# %% [markdown]
# # Considerazioni finali

# %%
print('Numeber of itemset with support = 20')
print ('Target Frequent')
print('Number of itemsets [2]:', len(itemsets))
print('Number of itemsets [3]:', len(itemsets1))
print('Number of itemsets [4]:', len(itemsets2))
print ('Target Maximum')
print('Number of itemsets [2]:', len(itemsets3))
print('Number of itemsets [3]:', len(itemsets4))
print('Number of itemsets [4]:', len(itemsets5))
print('Target Closed')
print('Number of itemsets [2]:', len(itemsets6))
print('Number of itemsets [3]:', len(itemsets7))
print('Number of itemsets [4]:', len(itemsets8))
# Out:
# Numeber of itemset with support = 20
# Target Frequent
# Number of itemsets [2]: 167
# Number of itemsets [3]: 78
# Number of itemsets [4]: 7
# Target Maximum
# Number of itemsets [2]: 89
# Number of itemsets [3]: 62
# Number of itemsets [4]: 7
# Target Closed
# Number of itemsets [2]: 167
# Number of itemsets [3]: 78
# Number of itemsets [4]: 7

# %% [markdown]
# # Association Rules

# %%
y = range(19)
z = range(60,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=20, zmin=m, target='r', conf=n, report='ascl')
        print('Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
# Out:
# Number of rule with Confidance 60 % and zmin 0 : 628
# Number of rule with Confidance 60 % and zmin 1 : 628
# Number of rule with Confidance 60 % and zmin 2 : 623
# Number of rule with Confidance 60 % and zmin 3 : 504
# Number of rule with Confidance 60 % and zmin 4 : 191
# Number of rule with Confidance 60 % and zmin 5 : 9
# Number of rule with Confidance 60 % and zmin 6 : 0
# Number of rule with Confidance 60 % and zmin 7 : 0
# Number of rule with Confidance 60 % and zmin 8 : 0
# Number of rule with Confidance 60 % and zmin 9 : 0
# Number of rule with Confidance 60 % and zmin 10 : 0
# Number of rule with Confidance 60 % and zmin 11 : 0
# Number of rule with Confidance 60 % and zmin 12 : 0
# Number of rule with Confidance 60 % and zmin 13 : 0
# Number of rule with Confidance 60 % and zmin 14 : 0
# Number of rule with Confidance 60 % and zmin 15 : 0
# Number of rule with Confidance 60 % and zmin 16 : 0
# Number of rule with Confidance 60 % and zmin 17 : 0
# Number of rule with Confidance 60 % and zmin 18 : 0
# Number of rule with Confidance 70 % and zmin 0 : 381
# Number of rule with Confidance 70 % and zmin 1 : 381
# Number of rule with Confidance 70 % and zmin 2 : 378
# Number of rule with Confidance 70 % and zmin 3 : 304
# Number of rule with Confidance 70 % and zmin 4 : 109
# Number of rule with Confidance 70 % and zmin 5 : 3
# Number of rule with Confidance 70 % and zmin 6 : 0
# Number of rule with Confidance 70 % and zmin 7 : 0
# Number of rule with Confidance 70 % and zmin 8 : 0
# Number of rule with Confidance 70 % and zmin 9 : 0
# Number of rule with Confidance 70 % and zmin 10 : 0
# Number of rule with Confidance 70 % and zmin 11 : 0
# Number of rule with Confidance 70 % and zmin 12 : 0
# Number of rule with Confidance 70 % and zmin 13 : 0
# Number of rule with Confidance 70 % and zmin 14 : 0
# Number of rule with Confidance 70 % and zmin 15 : 0
# Number of rule with Confidance 70 % and zmin 16 : 0
# Number of rule with Confidance 70 % and zmin 17 : 0
# Number of rule with Confidance 70 % and zmin 18 : 0
# Number of rule with Confidance 80 % and zmin 0 : 105
# Number of rule with Confidance 80 % and zmin 1 : 105
# Number of rule with Confidance 80 % and zmin 2 : 104
# Number of rule with Confidance 80 % and zmin 3 : 82
# Number of rule with Confidance 80 % and zmin 4 : 27
# Number of rule with Confidance 80 % and zmin 5 : 1
# Number of rule with Confidance 80 % and zmin 6 : 0
# Number of rule with Confidance 80 % and zmin 7 : 0
# Number of rule with Confidance 80 % and zmin 8 : 0
# Number of rule with Confidance 80 % and zmin 9 : 0
# Number of rule with Confidance 80 % and zmin 10 : 0
# Number of rule with Confidance 80 % and zmin 11 : 0
# Number of rule with Confidance 80 % and zmin 12 : 0
# Number of rule with Confidance 80 % and zmin 13 : 0
# Number of rule with Confidance 80 % and zmin 14 : 0
# Number of rule with Confidance 80 % and zmin 15 : 0
# Number of rule with Confidance 80 % and zmin 16 : 0
# Number of rule with Confidance 80 % and zmin 17 : 0
# Number of rule with Confidance 80 % and zmin 18 : 0
# Number of rule with Confidance 90 % and zmin 0 : 17
# Number of rule with Confidance 90 % and zmin 1 : 17
# Number of rule with Confidance 90 % and zmin 2 : 17
# Number of rule with Confidance 90 % and zmin 3 : 16
# Number of rule with Confidance 90 % and zmin 4 : 5
# Number of rule with Confidance 90 % and zmin 5 : 1
# Number of rule with Confidance 90 % and zmin 6 : 0
# Number of rule with Confidance 90 % and zmin 7 : 0
# Number of rule with Confidance 90 % and zmin 8 : 0
# Number of rule with Confidance 90 % and zmin 9 : 0
# Number of rule with Confidance 90 % and zmin 10 : 0
# Number of rule with Confidance 90 % and zmin 11 : 0
# Number of rule with Confidance 90 % and zmin 12 : 0
# Number of rule with Confidance 90 % and zmin 13 : 0
# Number of rule with Confidance 90 % and zmin 14 : 0
# Number of rule with Confidance 90 % and zmin 15 : 0
# Number of rule with Confidance 90 % and zmin 16 : 0
# Number of rule with Confidance 90 % and zmin 17 : 0
# Number of rule with Confidance 90 % and zmin 18 : 0

# %% [markdown]
# Decido di stampare i set di rules più significativi

# %%
#confidance 60% e zmin = 5
rules = apriori(baskets, supp=20, zmin=5, target='r', conf=60, 
                report='ascl') 
print('Number of rule:', len(rules))
set(rules)
# Out:
# Number of rule: 9
# {('High_Overall',
#   ('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   123,
#   0.1392978482446206,
#   0.6833333333333333,
#   1.0279102782509937),
#  ('High_Overall',
#   ('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   124,
#   0.1404303510758777,
#   0.6775956284153005,
#   1.0192792843112612),
#  ('High_Overall',
#   ('Male', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   168,
#   0.19026047565118911,
#   0.6614173228346457,
#   0.9949429234463238),
#  ('Male',
#   ('2.0_Time', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   115,
#   0.13023782559456398,
#   0.6388888888888888,
#   1.044701646090535),
#  ('Male',
#   ('Bachelor', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   114,
#   0.1291053227633069,
#   0.6229508196721312,
#   1.0186399514268367),
#  ('Male',
#   ('High_Overall', 'No_OverTime', 'Travel_Rarely', 'No_Attrition'),
#   168,
#   0.19026047565118911,
#   0.6021505376344086,
#   0.9846276383910793),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   168,
#   0.19026047565118911,
#   0.9281767955801105,
#   1.1227124801332022),
#  ('No_OverTime',
#   ('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   168,
#   0.19026047565118911,
#   0.75,
#   1.0380094043887147),
#  ('Travel_Rarely',
#   ('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'),
#   168,
#   0.19026047565118911,
#   0.7466666666666667,
#   1.0174485596707818)}

# %%
#confidance 70% e zmin = 5
rules1 = apriori(baskets, supp=20, zmin=5, target='r', conf=70, 
                report='ascl') 
print('Number of rule:', len(rules1))
set(rules1)
# Out:
# Number of rule: 3
# {('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   168,
#   0.19026047565118911,
#   0.9281767955801105,
#   1.1227124801332022),
#  ('No_OverTime',
#   ('Male', 'High_Overall', 'Travel_Rarely', 'No_Attrition'),
#   168,
#   0.19026047565118911,
#   0.75,
#   1.0380094043887147),
#  ('Travel_Rarely',
#   ('Male', 'High_Overall', 'No_OverTime', 'No_Attrition'),
#   168,
#   0.19026047565118911,
#   0.7466666666666667,
#   1.0174485596707818)}

# %%
#confidance 80% e zimn = 4
rules2 = apriori(baskets, supp=20, zmin=4, target='r', conf=80, 
                report='ascl') 
print('Number of rule:', len(rules2))
set(rules2)
# Out:
# Number of rule: 27
# {('No_Attrition',
#   ('0_stockOption', 'Male', 'No_OverTime'),
#   142,
#   0.16081540203850508,
#   0.8022598870056498,
#   0.9704047674328612),
#  ('No_Attrition',
#   ('0_stockOption', 'No_OverTime', 'Travel_Rarely'),
#   160,
#   0.1812004530011325,
#   0.8121827411167513,
#   0.982407343022043),
#  ('No_Attrition',
#   ('1_companies', 'High_Overall', 'Travel_Rarely'),
#   146,
#   0.16534541336353342,
#   0.8202247191011236,
#   0.9921348314606742),
#  ('No_Attrition',
#   ('1_companies', 'No_OverTime', 'Travel_Rarely'),
#   161,
#   0.1823329558323896,
#   0.875,
#   1.0583904109589042),
#  ('No_Attrition',
#   ('1_stockOption', 'No_OverTime', 'Travel_Rarely'),
#   172,
#   0.19479048697621745,
#   0.9398907103825137,
#   1.13688150310652),
#  ('No_Attrition',
#   ('2.0_Time', 'High_Overall', 'No_OverTime'),
#   168,
#   0.19026047565118911,
#   0.8888888888888888,
#   1.0751902587519027),
#  ('No_Attrition',
#   ('2.0_Time', 'High_Overall', 'Travel_Rarely'),
#   174,
#   0.1970554926387316,
#   0.8246445497630331,
#   0.9974810101928195),
#  ('No_Attrition',
#   ('2.0_Time', 'Male', 'High_Overall'),
#   150,
#   0.16987542468856173,
#   0.8333333333333334,
#   1.0079908675799087),
#  ('No_Attrition',
#   ('2.0_Time', 'Male', 'No_OverTime'),
#   157,
#   0.17780294450736125,
#   0.8440860215053764,
#   1.0209972013551334),
#  ('No_Attrition',
#   ('2.0_Time', 'No_OverTime', 'Travel_Rarely'),
#   180,
#   0.20385050962627407,
#   0.861244019138756,
#   1.0417513272596186),
#  ('No_Attrition',
#   ('Bachelor', 'High_Overall', 'Travel_Rarely'),
#   153,
#   0.17327293318233294,
#   0.8360655737704918,
#   1.0112957556703346),
#  ('No_Attrition',
#   ('Bachelor', 'No_OverTime', 'Travel_Rarely'),
#   183,
#   0.2072480181200453,
#   0.8672985781990521,
#   1.0490748555476206),
#  ('No_Attrition',
#   ('EntryLevel', 'High_Overall', 'No_OverTime'),
#   157,
#   0.17780294450736125,
#   0.8820224719101124,
#   1.0668847160227797),
#  ('No_Attrition',
#   ('EntryLevel', 'No_OverTime', 'Travel_Rarely'),
#   158,
#   0.17893544733861835,
#   0.8186528497409327,
#   0.9902335155085528),
#  ('No_Attrition',
#   ('Female', 'High_Overall', 'Travel_Rarely'),
#   152,
#   0.17214043035107587,
#   0.8491620111731844,
#   1.0271370628300298),
#  ('No_Attrition',
#   ('Female', 'No_OverTime', 'Travel_Rarely'),
#   160,
#   0.1812004530011325,
#   0.903954802259887,
#   1.093413822459562),
#  ('No_Attrition',
#   ('High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   279,
#   0.3159682899207248,
#   0.9207920792079208,
#   1.1137800081378),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime'),
#   225,
#   0.2548131370328426,
#   0.9183673469387755,
#   1.1108470785574505),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   168,
#   0.19026047565118911,
#   0.9281767955801105,
#   1.1227124801332022),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'Travel_Rarely'),
#   224,
#   0.2536806342015855,
#   0.8682170542635659,
#   1.0501858341297654),
#  ('No_Attrition',
#   ('Male', 'No_OverTime', 'Travel_Rarely'),
#   254,
#   0.2876557191392978,
#   0.872852233676976,
#   1.0557924963517393),
#  ('No_Attrition',
#   ('[11.0, 13.8)_%', 'High_Overall', 'Travel_Rarely'),
#   157,
#   0.17780294450736125,
#   0.8440860215053764,
#   1.0209972013551334),
#  ('No_Attrition',
#   ('[11.0, 13.8)_%', 'No_OverTime', 'Travel_Rarely'),
#   163,
#   0.18459796149490373,
#   0.8858695652173914,
#   1.0715381179273378),
#  ('No_OverTime',
#   ('Bachelor', 'Male', 'No_Attrition'),
#   146,
#   0.16534541336353342,
#   0.8156424581005587,
#   1.1288593895028107),
#  ('No_OverTime',
#   ('Bachelor', 'Travel_Rarely', 'No_Attrition'),
#   183,
#   0.2072480181200453,
#   0.8243243243243243,
#   1.1408752012200287),
#  ('No_OverTime',
#   ('EntryLevel', 'High_Overall', 'No_Attrition'),
#   157,
#   0.17780294450736125,
#   0.8177083333333334,
#   1.1317185867293627),
#  ('No_OverTime',
#   ('EntryLevel', 'Travel_Rarely', 'No_Attrition'),
#   158,
#   0.17893544733861835,
#   0.8494623655913979,
#   1.1756665655442073)}

# %%
#confidance 80% e zmin = 5
rules3 = apriori(baskets, supp=20, zmin=5, target='r', conf=80, 
                report='ascl') 
print('Number of rule:', len(rules3))
set(rules3)
# Out:
# Number of rule: 1
# {('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   168,
#   0.19026047565118911,
#   0.9281767955801105,
#   1.1227124801332022)}

# %%
#confidance 90% e zmin = 3
rules4 = apriori(baskets, supp=20, zmin=3, target='r', conf=90, 
                report='ascl') 
print('Number of rule:', len(rules4))
set(rules4)
# Out:
# Number of rule: 16
# {('No_Attrition',
#   ('1_stockOption', 'High_Overall'),
#   218,
#   0.24688561721404303,
#   0.919831223628692,
#   1.1126177677590892),
#  ('No_Attrition',
#   ('1_stockOption', 'Male'),
#   182,
#   0.20611551528878821,
#   0.9054726368159204,
#   1.0952497785047366),
#  ('No_Attrition',
#   ('1_stockOption', 'No_OverTime'),
#   239,
#   0.2706681766704417,
#   0.9372549019607843,
#   1.133693258125168),
#  ('No_Attrition',
#   ('1_stockOption', 'No_OverTime', 'Travel_Rarely'),
#   172,
#   0.19479048697621745,
#   0.9398907103825137,
#   1.13688150310652),
#  ('No_Attrition',
#   ('1_stockOption', 'Travel_Rarely'),
#   224,
#   0.2536806342015855,
#   0.9032258064516129,
#   1.0925320371188687),
#  ('No_Attrition',
#   ('3.0_Time', 'No_OverTime'),
#   173,
#   0.19592298980747452,
#   0.9105263157894737,
#   1.1013626532083634),
#  ('No_Attrition',
#   ('Female', 'No_OverTime'),
#   219,
#   0.2480181200453001,
#   0.9012345679012346,
#   1.0901234567901235),
#  ('No_Attrition',
#   ('Female', 'No_OverTime', 'Travel_Rarely'),
#   160,
#   0.1812004530011325,
#   0.903954802259887,
#   1.093413822459562),
#  ('No_Attrition',
#   ('High_Overall', 'No_OverTime'),
#   378,
#   0.42808607021517553,
#   0.9197080291970803,
#   1.1124687531246875),
#  ('No_Attrition',
#   ('High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   279,
#   0.3159682899207248,
#   0.9207920792079208,
#   1.1137800081378),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime'),
#   225,
#   0.2548131370328426,
#   0.9183673469387755,
#   1.1108470785574505),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   168,
#   0.19026047565118911,
#   0.9281767955801105,
#   1.1227124801332022),
#  ('No_Attrition',
#   ('MidLevel', 'High_Overall'),
#   201,
#   0.2276330690826727,
#   0.95260663507109,
#   1.1522625462572227),
#  ('No_Attrition',
#   ('MidLevel', 'Male'),
#   181,
#   0.20498301245753114,
#   0.905,
#   1.0946780821917808),
#  ('No_Attrition',
#   ('MidLevel', 'No_OverTime'),
#   216,
#   0.24462061155152887,
#   0.935064935064935,
#   1.131044298167586),
#  ('No_Attrition',
#   ('MidLevel', 'Travel_Rarely'),
#   219,
#   0.2480181200453001,
#   0.9240506329113924,
#   1.1177215189873417)}

# %%
#confidance 90% e zmin = 4
rules5 = apriori(baskets, supp=20, zmin=4, target='r', conf=90, 
                report='ascl') 
print('Number of rule:', len(rules5))
set(rules5)
# Out:
# Number of rule: 5
# {('No_Attrition',
#   ('1_stockOption', 'No_OverTime', 'Travel_Rarely'),
#   172,
#   0.19479048697621745,
#   0.9398907103825137,
#   1.13688150310652),
#  ('No_Attrition',
#   ('Female', 'No_OverTime', 'Travel_Rarely'),
#   160,
#   0.1812004530011325,
#   0.903954802259887,
#   1.093413822459562),
#  ('No_Attrition',
#   ('High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   279,
#   0.3159682899207248,
#   0.9207920792079208,
#   1.1137800081378),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime'),
#   225,
#   0.2548131370328426,
#   0.9183673469387755,
#   1.1108470785574505),
#  ('No_Attrition',
#   ('Male', 'High_Overall', 'No_OverTime', 'Travel_Rarely'),
#   168,
#   0.19026047565118911,
#   0.9281767955801105,
#   1.1227124801332022)}
