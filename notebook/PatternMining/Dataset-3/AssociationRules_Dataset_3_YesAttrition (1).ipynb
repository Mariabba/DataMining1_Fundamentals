# %% [markdown]
# # ASSOCIATION RULE
# WITH OVERALL SATISFACTION AND THE OTHER SATISFACTION
#
# Express how product/services relate to each other, and tend to group together.

# %%
#vanno importate pandas e numpy e matplot per fare i grafici
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split  
from pandas import DataFrame

# %%
df = pd.read_csv(r'C:\Users\jigok\OneDrive\Desktop\UniPISA\1semestre1Anno\Data Mining\Progetto\Dataset AR\All_values_Train_HR_Employee_Attrition_AllSatisfaction.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       883 non-null    float64
#  1   Attrition                 883 non-null    object
#  2   BusinessTravel            883 non-null    object
#  3   DistanceFromHome          883 non-null    int64
#  4   Education                 883 non-null    int64
#  5   EnvironmentSatisfaction   883 non-null    int64
#  6   Gender                    883 non-null    object
#  7   JobInvolvement            883 non-null    int64
#  8   JobLevel                  883 non-null    int64
#  9   JobRole                   883 non-null    object
#  10  JobSatisfaction           883 non-null    int64
#  11  MonthlyIncome             883 non-null    float64
#  12  NumCompaniesWorked        883 non-null    int64
#  13  OverTime                  883 non-null    object
# ...

# %%
#discretizzo OverallSatisfaction
def labels(x):
    if  1.0 <= x <= 1.5:
        return(1)
    elif 1.6 <= x <= 2.5:
        return(2)
    elif 2.6 <= x <= 3.5:
        return(3)
    elif 3.6 <= x <= 4.5:
        return(4)
    else:
        return(4)

df['OverallSatisfaction'] = df['OverallSatisfaction'].apply(lambda x: labels(x))
#arrotondo le medie
df.head(5)
# Out:
#     Age Attrition     BusinessTravel  DistanceFromHome  Education  \
# 0  52.0        No      Travel_Rarely                 9          4
# 1  36.0        No      Travel_Rarely                 1          1
# 2  25.0        No  Travel_Frequently                16          3
# 3  33.0        No      Travel_Rarely                 5          4
# 4  31.0        No      Travel_Rarely                 9          2
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0                        2    Male               3         3
# 1                        2    Male               3         5
# 2                        3    Male               3         2
# 3                        2    Male               3         1
# 4                        3  Female               3         1
#
#                  JobRole  ...  PercentSalaryHike  RelationshipSatisfaction  \
# 0      Research Director  ...                 17                         3
# ...

# %%
df.describe()
# Out:
#               Age  DistanceFromHome   Education  EnvironmentSatisfaction  \
# count  883.000000        883.000000  883.000000               883.000000
# mean    36.554926          9.201586    2.886750                 2.684032
# std      8.266129          8.241818    1.008285                 1.092567
# min     18.000000          1.000000    1.000000                 1.000000
# 25%     30.000000          2.000000    2.000000                 2.000000
# 50%     35.000000          7.000000    3.000000                 3.000000
# 75%     42.000000         14.000000    4.000000                 4.000000
# max     60.000000         29.000000    5.000000                 4.000000
#
#        JobInvolvement    JobLevel  JobSatisfaction  MonthlyIncome  \
# count      883.000000  883.000000       883.000000     883.000000
# mean         2.750849    1.919592         2.703284    6932.335221
# std          0.729354    1.007506         1.087061    5453.370217
# ...

# %% [markdown]
# BINNING

# %%
#numero bin con la distribuzione istogrammi variabili
#Apply binning to continuous features

df['AgeBin'] = pd.cut(df['Age'].astype(int), 6, right=False)
df['DistanceFromHomeBin'] = pd.cut(df['DistanceFromHome'].astype(int), 10, right=False)
df['PercentSalaryHikeBin'] = pd.cut(df['PercentSalaryHike'].astype(int), 5, right=False)
df['MonthlyIncomeBin'] = pd.cut(df['MonthlyIncome'].astype(int), 10, right=False)
df['MonthlyHoursBin'] = pd.cut(df['MonthlyHours'].astype(int), 10, right=False)



df.drop(['Age', 'MonthlyIncome', 'MonthlyHours','DistanceFromHome','PercentSalaryHike'], axis=1, inplace=True)

df.head()
# Out:
#   Attrition     BusinessTravel  Education  EnvironmentSatisfaction  Gender  \
# 0        No      Travel_Rarely          4                        2    Male
# 1        No      Travel_Rarely          1                        2    Male
# 2        No  Travel_Frequently          3                        3    Male
# 3        No      Travel_Rarely          4                        2    Male
# 4        No      Travel_Rarely          2                        3  Female
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0               3         3      Research Director                3
# 1               3         5                Manager                3
# 2               3         2        Sales Executive                4
# 3               3         1     Research Scientist                2
# 4               3         1  Laboratory Technician                4
#
#    NumCompaniesWorked  ... WorkLifeBalance  YearsAtCompany  \
# ...

# %% [markdown]
# MAPPING

# %%
df['Education'] = df['Education'].map(
    {1: 'Below College', 2: 'College', 3:'Bachelor', 4:'Master', 5:'Doctor'}).astype(str)
df['OverallSatisfaction'] = df['OverallSatisfaction'].map(
    {1: 'Low', 2: 'Medium', 3:'High', 4:'Very High'}).astype(str)+'_Overall'
df['JobLevel'] = df['JobLevel'].map(
    {1: 'EntryLevel', 2: 'MidLevel', 3:'SeniorLevel', 4:'Manager', 5:'Director'}).astype(str)


df['AgeBin'] = df['AgeBin'].astype(str) + '_Age'
df['MonthlyIncomeBin'] = df['MonthlyIncomeBin'].astype(str) + '_Income'
df['MonthlyHoursBin'] = df['MonthlyHoursBin'].astype(str) + '_Hours'
df['DistanceFromHomeBin'] = df['DistanceFromHomeBin'].astype(str) + '_Distance'
df['YearsAtCompany'] = df['YearsAtCompany'].astype(str) + '_YearsAtCompany'
df['PercentSalaryHikeBin'] = df['PercentSalaryHikeBin'].astype(str) + '_%'

df['NumCompaniesWorked'] = df['NumCompaniesWorked'].astype(str) + '_companies'
df['StockOptionLevel'] = df['StockOptionLevel'].astype(str) + '_stockOption'
df['TrainingTimesLastYear'] = df['TrainingTimesLastYear'].astype(str) + '_Time'
df['YearsInCurrentRole'] = df['YearsInCurrentRole'].astype(str) + '_YearsInCurrentRole'
df['TaxRate'] = df['TaxRate'].astype(str) + '_TaxRate'
df['OverTime'] = df['OverTime'].astype(str) + '_OverTime'
df['Attrition'] = df['Attrition'].astype(str) + '_Attrition'

#add
df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].astype(str) + '_ESat'
df['JobSatisfaction'] = df['JobSatisfaction'].astype(str) + '_JSat'
df['JobInvolvement'] = df['JobInvolvement'].astype(str) + '_JIvol'
df['WorkLifeBalance'] = df['WorkLifeBalance'].astype(str) + '_WLBalance'
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].astype(str) + '_RSat'

df.head(5)
# Out:
#       Attrition     BusinessTravel      Education EnvironmentSatisfaction  \
# 0  No_Attrition      Travel_Rarely         Master                  2_ESat
# 1  No_Attrition      Travel_Rarely  Below College                  2_ESat
# 2  No_Attrition  Travel_Frequently       Bachelor                  3_ESat
# 3  No_Attrition      Travel_Rarely         Master                  2_ESat
# 4  No_Attrition      Travel_Rarely        College                  3_ESat
#
#    Gender JobInvolvement     JobLevel                JobRole JobSatisfaction  \
# 0    Male        3_JIvol  SeniorLevel      Research Director          3_JSat
# 1    Male        3_JIvol     Director                Manager          3_JSat
# 2    Male        3_JIvol     MidLevel        Sales Executive          4_JSat
# 3    Male        3_JIvol   EntryLevel     Research Scientist          2_JSat
# 4  Female        3_JIvol   EntryLevel  Laboratory Technician          4_JSat
#
# ...

# %% [markdown]
# # Creo i Baskets

# %%
baskets = df.values.tolist()

# %%
baskets[0]
# Out:
# ['No_Attrition',
#  'Travel_Rarely',
#  'Master',
#  '2_ESat',
#  'Male',
#  '3_JIvol',
#  'SeniorLevel',
#  'Research Director',
#  '3_JSat',
#  '9_companies',
#  'No_OverTime',
#  '3_RSat',
#  '0_stockOption',
#  '2.0_Time',
#  '2_WLBalance',
#  '8.0_YearsAtCompany',
#  '7_YearsInCurrentRole',
#  'High_Overall',
#  '0.3871716731969235_TaxRate',
#  '[46.0, 53.0)_Age',
#  '[6.6, 9.4)_Distance',
#  '[16.6, 19.4)_%',
#  '[6206.6, 8805.4)_Income',
#  '[138.8, 195.2)_Hours']

# %% [markdown]
# # Apriori Algorithm

# %%
from fim import apriori

# %%
help(apriori)
# Out:
# Help on built-in function apriori in module fim:
#
# apriori(...)
#     apriori (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#              eval='x', agg='x', thresh=10, prune=None, algo='b', mode='',
#              border=None)
#     Find frequent item sets with the Apriori algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
# ...

# %% [markdown]
# # Description of the Value

# %% [markdown]
# We have decide to do some proves with different characterized value of support. This value are 2,10,20,30,40,50,60,70,80,90.
# After that we have to do some proves with different type of target , a for frequent itemset, m for maximal itemset e c for closed itemset.
#
# For choosing the best combination we try to create the frequent itemset with different min value from the range 0-24.
#
# We find that for have rules with 'Yes_Attrition' the range value of support that we have to analyze is between 2 and 10. So in this File ther'is the study of AR with this Support Value.

# %% [markdown]
# # Support =2%

# %% [markdown]
# Frequent Itemsets with min value in a range 0 to 24

# %%
x = 0
for x in range (24):
    items = apriori(baskets, supp=2, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 138149
# Number of itemsets for zimin 1 : 138148
# Number of itemsets for zimin 2 : 138017
# Number of itemsets for zimin 3 : 134781
# Number of itemsets for zimin 4 : 114665
# Number of itemsets for zimin 5 : 69530
# Number of itemsets for zimin 6 : 25176
# Number of itemsets for zimin 7 : 4441
# Number of itemsets for zimin 8 : 287
# Number of itemsets for zimin 9 : 2
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %% [markdown]
# Maximal Itemset with min value in a range 0 to 24

# %%
x = 0
for x in range (24):
    items1 = apriori(baskets, supp=2, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items1))
# Out:
# Number of itemsets for zimin 0 : 43158
# Number of itemsets for zimin 1 : 43158
# Number of itemsets for zimin 2 : 43157
# Number of itemsets for zimin 3 : 42840
# Number of itemsets for zimin 4 : 39309
# Number of itemsets for zimin 5 : 27894
# Number of itemsets for zimin 6 : 13000
# Number of itemsets for zimin 7 : 3032
# Number of itemsets for zimin 8 : 269
# Number of itemsets for zimin 9 : 2
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %% [markdown]
# Closed Itemset with min value in a range 0 to 24

# %%
x = 0
for x in range (24):
    items2 = apriori(baskets, supp=2, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items2))
# Out:
# Number of itemsets for zimin 0 : 132918
# Number of itemsets for zimin 1 : 132917
# Number of itemsets for zimin 2 : 132791
# Number of itemsets for zimin 3 : 129628
# Number of itemsets for zimin 4 : 110117
# Number of itemsets for zimin 5 : 66828
# Number of itemsets for zimin 6 : 24436
# Number of itemsets for zimin 7 : 4384
# Number of itemsets for zimin 8 : 287
# Number of itemsets for zimin 9 : 2
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %% [markdown]
# # Association Rule

# %% [markdown]
# Here we have a cycle for all the minimum number of rule, basys on the fact that we have 24 columns, with different value of  Confidance

# %%
y = range(2,24)
z = range(60,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=2, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 60 % and zmin 2 : 556783
# ------------------------
# ('Yes_Attrition', ('1_WLBalance', 'Laboratory Technician', 'EntryLevel'), 14, 0.015855039637599093, 0.7368421052631579, 4.252493980048159)
# ------------------------
# ('Yes_Attrition', ('1_WLBalance', 'Laboratory Technician'), 14, 0.015855039637599093, 0.7368421052631579, 4.252493980048159)
# ------------------------
# ('Yes_Attrition', ('1_WLBalance', 'EntryLevel', 'Male'), 12, 0.013590033975084938, 0.631578947368421, 3.6449948400412797)
# ------------------------
# ('Yes_Attrition', ('1_WLBalance', 'EntryLevel', 'Travel_Rarely'), 13, 0.014722536806342015, 0.6842105263157895, 3.9487444100447195)
# ------------------------
# ('Yes_Attrition', ('Sales Representative', 'Yes_OverTime'), 11, 0.01245753114382786, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ...

# %% [markdown]
# # Support = 3%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=3, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 51623
# Number of itemsets for zimin 1 : 51622
# Number of itemsets for zimin 2 : 51501
# Number of itemsets for zimin 3 : 49170
# Number of itemsets for zimin 4 : 38081
# Number of itemsets for zimin 5 : 18982
# Number of itemsets for zimin 6 : 4994
# Number of itemsets for zimin 7 : 534
# Number of itemsets for zimin 8 : 13
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=3, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 17856
# Number of itemsets for zimin 1 : 17856
# Number of itemsets for zimin 2 : 17853
# Number of itemsets for zimin 3 : 17532
# Number of itemsets for zimin 4 : 15042
# Number of itemsets for zimin 5 : 9145
# Number of itemsets for zimin 6 : 3070
# Number of itemsets for zimin 7 : 444
# Number of itemsets for zimin 8 : 13
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=3, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 50986
# Number of itemsets for zimin 1 : 50985
# Number of itemsets for zimin 2 : 50866
# Number of itemsets for zimin 3 : 48547
# Number of itemsets for zimin 4 : 37542
# Number of itemsets for zimin 5 : 18738
# Number of itemsets for zimin 6 : 4954
# Number of itemsets for zimin 7 : 534
# Number of itemsets for zimin 8 : 13
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
y = range(2,24)
z = range(60,100,10)

for n in z:
    for m in y:
        rules1 = apriori(baskets, supp=3, zmin=m
                        , target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules1))
        for r in rules1: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 60 % and zmin 2 : 202137
# ------------------------
# ('Yes_Attrition', ('Sales Representative', 'EntryLevel', '0_stockOption'), 19, 0.021517553793884484, 0.6129032258064516, 3.537212734556188)
# ------------------------
# ('Yes_Attrition', ('0_YearsInCurrentRole', '1_companies', 'EntryLevel', '0_stockOption', 'Male'), 17, 0.01925254813137033, 0.6296296296296297, 3.633744855967078)
# ------------------------
# ('Yes_Attrition', ('0_YearsInCurrentRole', 'EntryLevel', '0_stockOption', 'Male'), 22, 0.02491506228765572, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ('Yes_Attrition', ('Laboratory Technician', 'Yes_OverTime', 'EntryLevel'), 25, 0.028312570781426953, 0.7352941176470589, 4.243560169165706)
# ------------------------
# ('Yes_Attrition', ('Laboratory Technician', 'Yes_OverTime', 'Travel_Rarely'), 20, 0.022650056625141562, 0.625, 3.6070261437908497)
# ------------------------
# ...

# %% [markdown]
# # Support = 4%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=4, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 25290
# Number of itemsets for zimin 1 : 25289
# Number of itemsets for zimin 2 : 25177
# Number of itemsets for zimin 3 : 23425
# Number of itemsets for zimin 4 : 16468
# Number of itemsets for zimin 5 : 6933
# Number of itemsets for zimin 6 : 1373
# Number of itemsets for zimin 7 : 90
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=4, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 9277
# Number of itemsets for zimin 1 : 9277
# Number of itemsets for zimin 2 : 9270
# Number of itemsets for zimin 3 : 8998
# Number of itemsets for zimin 4 : 7170
# Number of itemsets for zimin 5 : 3762
# Number of itemsets for zimin 6 : 1007
# Number of itemsets for zimin 7 : 90
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=4, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 25185
# Number of itemsets for zimin 1 : 25184
# Number of itemsets for zimin 2 : 25072
# Number of itemsets for zimin 3 : 23324
# Number of itemsets for zimin 4 : 16387
# Number of itemsets for zimin 5 : 6913
# Number of itemsets for zimin 6 : 1370
# Number of itemsets for zimin 7 : 90
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Association Rule
y = range(2,24)
z = range(60,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=4, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 60 % and zmin 2 : 99098
# ------------------------
# ('Yes_Attrition', ('0_YearsInCurrentRole', 'EntryLevel', '0_stockOption', 'Male'), 22, 0.02491506228765572, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ('Yes_Attrition', ('Laboratory Technician', 'Yes_OverTime'), 26, 0.02944507361268403, 0.65, 3.7513071895424837)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', '1_companies', 'EntryLevel', 'Travel_Rarely'), 25, 0.028312570781426953, 0.6097560975609756, 3.5190498963813166)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'Bachelor', 'EntryLevel'), 30, 0.03397508493771234, 0.6818181818181818, 3.9349376114081998)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', '0_stockOption'), 35, 0.039637599093997736, 0.7, 4.0398692810457515)
# ------------------------
# ...

# %% [markdown]
# # Support 5%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=5, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 14394
# Number of itemsets for zimin 1 : 14393
# Number of itemsets for zimin 2 : 14288
# Number of itemsets for zimin 3 : 12894
# Number of itemsets for zimin 4 : 8330
# Number of itemsets for zimin 5 : 3028
# Number of itemsets for zimin 6 : 442
# Number of itemsets for zimin 7 : 21
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=5, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 5448
# Number of itemsets for zimin 1 : 5448
# Number of itemsets for zimin 2 : 5437
# Number of itemsets for zimin 3 : 5186
# Number of itemsets for zimin 4 : 3857
# Number of itemsets for zimin 5 : 1882
# Number of itemsets for zimin 6 : 334
# Number of itemsets for zimin 7 : 21
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=5, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 14369
# Number of itemsets for zimin 1 : 14368
# Number of itemsets for zimin 2 : 14263
# Number of itemsets for zimin 3 : 12869
# Number of itemsets for zimin 4 : 8314
# Number of itemsets for zimin 5 : 3026
# Number of itemsets for zimin 6 : 442
# Number of itemsets for zimin 7 : 21
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Association Rule
y = range(2,24)
z = range(60,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=5, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 60 % and zmin 2 : 56803
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', '0_stockOption'), 35, 0.039637599093997736, 0.7, 4.0398692810457515)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', '2.0_Time'), 32, 0.0362400906002265, 0.64, 3.69359477124183)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', 'Travel_Rarely'), 44, 0.04983012457531144, 0.6111111111111112, 3.526870007262164)
# Number of rule with Confidance 60 % and zmin 3 : 56240
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', '0_stockOption'), 35, 0.039637599093997736, 0.7, 4.0398692810457515)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', '2.0_Time'), 32, 0.0362400906002265, 0.64, 3.69359477124183)
# ------------------------
# ...

# %% [markdown]
# # Support 6%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=6, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 9454
# Number of itemsets for zimin 1 : 9453
# Number of itemsets for zimin 2 : 9358
# Number of itemsets for zimin 3 : 8201
# Number of itemsets for zimin 4 : 4921
# Number of itemsets for zimin 5 : 1519
# Number of itemsets for zimin 6 : 201
# Number of itemsets for zimin 7 : 2
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=6, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 3667
# Number of itemsets for zimin 1 : 3667
# Number of itemsets for zimin 2 : 3659
# Number of itemsets for zimin 3 : 3420
# Number of itemsets for zimin 4 : 2434
# Number of itemsets for zimin 5 : 957
# Number of itemsets for zimin 6 : 188
# Number of itemsets for zimin 7 : 2
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=6, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 9449
# Number of itemsets for zimin 1 : 9448
# Number of itemsets for zimin 2 : 9353
# Number of itemsets for zimin 3 : 8196
# Number of itemsets for zimin 4 : 4919
# Number of itemsets for zimin 5 : 1519
# Number of itemsets for zimin 6 : 201
# Number of itemsets for zimin 7 : 2
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Association Rule
y = range(2,24)
z = range(50,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=6, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 50 % and zmin 2 : 53470
# ------------------------
# ('Yes_Attrition', ('0_YearsInCurrentRole', '0_stockOption', 'Travel_Rarely'), 28, 0.031710079275198186, 0.5, 2.8856209150326797)
# ------------------------
# ('Yes_Attrition', ('Laboratory Technician', 'EntryLevel', '0_stockOption'), 28, 0.031710079275198186, 0.509090909090909, 2.938086749851456)
# ------------------------
# ('Yes_Attrition', ('1_ESat', 'Medium_Overall', '0_stockOption'), 29, 0.03284258210645526, 0.5370370370370371, 3.0993706124425078)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'Medium_Overall'), 35, 0.039637599093997736, 0.5555555555555556, 3.206245461147422)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', '3_WLBalance'), 31, 0.035107587768969425, 0.5636363636363636, 3.252881758764112)
# ------------------------
# ...

# %% [markdown]
# # Support 7%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=7, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 6280
# Number of itemsets for zimin 1 : 6279
# Number of itemsets for zimin 2 : 6192
# Number of itemsets for zimin 3 : 5255
# Number of itemsets for zimin 4 : 2877
# Number of itemsets for zimin 5 : 771
# Number of itemsets for zimin 6 : 92
# Number of itemsets for zimin 7 : 1
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=7, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 2495
# Number of itemsets for zimin 1 : 2495
# Number of itemsets for zimin 2 : 2490
# Number of itemsets for zimin 3 : 2280
# Number of itemsets for zimin 4 : 1515
# Number of itemsets for zimin 5 : 460
# Number of itemsets for zimin 6 : 85
# Number of itemsets for zimin 7 : 1
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=7, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 6279
# Number of itemsets for zimin 1 : 6278
# Number of itemsets for zimin 2 : 6191
# Number of itemsets for zimin 3 : 5254
# Number of itemsets for zimin 4 : 2877
# Number of itemsets for zimin 5 : 771
# Number of itemsets for zimin 6 : 92
# Number of itemsets for zimin 7 : 1
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Association Rule
y = range(1,24)
z = range(50,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=7, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 50 % and zmin 1 : 35129
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'Medium_Overall'), 35, 0.039637599093997736, 0.5555555555555556, 3.206245461147422)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', 'Travel_Rarely'), 44, 0.04983012457531144, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 2 : 35122
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'Medium_Overall'), 35, 0.039637599093997736, 0.5555555555555556, 3.206245461147422)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', 'Travel_Rarely'), 44, 0.04983012457531144, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ...

# %% [markdown]
# # Support 8%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=8, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 4371
# Number of itemsets for zimin 1 : 4370
# Number of itemsets for zimin 2 : 4287
# Number of itemsets for zimin 3 : 3508
# Number of itemsets for zimin 4 : 1752
# Number of itemsets for zimin 5 : 425
# Number of itemsets for zimin 6 : 25
# Number of itemsets for zimin 7 : 1
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=8, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 1769
# Number of itemsets for zimin 1 : 1769
# Number of itemsets for zimin 2 : 1762
# Number of itemsets for zimin 3 : 1585
# Number of itemsets for zimin 4 : 965
# Number of itemsets for zimin 5 : 321
# Number of itemsets for zimin 6 : 18
# Number of itemsets for zimin 7 : 1
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=8, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 4371
# Number of itemsets for zimin 1 : 4370
# Number of itemsets for zimin 2 : 4287
# Number of itemsets for zimin 3 : 3508
# Number of itemsets for zimin 4 : 1752
# Number of itemsets for zimin 5 : 425
# Number of itemsets for zimin 6 : 25
# Number of itemsets for zimin 7 : 1
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Association Rule
y = range(1,24)
z = range(50,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=8, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 50 % and zmin 1 : 24210
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', 'Travel_Rarely'), 44, 0.04983012457531144, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 2 : 24203
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', 'Travel_Rarely'), 44, 0.04983012457531144, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 3 : 23595
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel', 'Travel_Rarely'), 44, 0.04983012457531144, 0.6111111111111112, 3.526870007262164)
# ------------------------
# ...

# %% [markdown]
# # Support 9%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=9, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 3170
# Number of itemsets for zimin 1 : 3169
# Number of itemsets for zimin 2 : 3093
# Number of itemsets for zimin 3 : 2446
# Number of itemsets for zimin 4 : 1135
# Number of itemsets for zimin 5 : 249
# Number of itemsets for zimin 6 : 10
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=9, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 1303
# Number of itemsets for zimin 1 : 1303
# Number of itemsets for zimin 2 : 1298
# Number of itemsets for zimin 3 : 1142
# Number of itemsets for zimin 4 : 621
# Number of itemsets for zimin 5 : 208
# Number of itemsets for zimin 6 : 10
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=9, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 3170
# Number of itemsets for zimin 1 : 3169
# Number of itemsets for zimin 2 : 3093
# Number of itemsets for zimin 3 : 2446
# Number of itemsets for zimin 4 : 1135
# Number of itemsets for zimin 5 : 249
# Number of itemsets for zimin 6 : 10
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Association Rule
y = range(1,24)
z = range(50,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=9, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 50 % and zmin 1 : 17391
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 2 : 17384
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 3 : 16831
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 4 : 12446
# Number of rule with Confidance 50 % and zmin 5 : 4808
# Number of rule with Confidance 50 % and zmin 6 : 774
# Number of rule with Confidance 50 % and zmin 7 : 16
# Number of rule with Confidance 50 % and zmin 8 : 0
# Number of rule with Confidance 50 % and zmin 9 : 0
# Number of rule with Confidance 50 % and zmin 10 : 0
# ...

# %% [markdown]
# # Support 10%

# %%
#Frequent
x = 0
for x in range (24):
    items = apriori(baskets, supp=10, report ='s', target='a',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 2368
# Number of itemsets for zimin 1 : 2367
# Number of itemsets for zimin 2 : 2294
# Number of itemsets for zimin 3 : 1738
# Number of itemsets for zimin 4 : 759
# Number of itemsets for zimin 5 : 139
# Number of itemsets for zimin 6 : 6
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Maximal
x = 0
for x in range (24):
    items = apriori(baskets, supp=10, report ='s', target='m',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 987
# Number of itemsets for zimin 1 : 987
# Number of itemsets for zimin 2 : 977
# Number of itemsets for zimin 3 : 826
# Number of itemsets for zimin 4 : 435
# Number of itemsets for zimin 5 : 118
# Number of itemsets for zimin 6 : 6
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Closed
x = 0
for x in range (24):
    items = apriori(baskets, supp=10, report ='s', target='c',zmin = x)
    print('Number of itemsets for zimin',x, ':' , len(items))
# Out:
# Number of itemsets for zimin 0 : 2368
# Number of itemsets for zimin 1 : 2367
# Number of itemsets for zimin 2 : 2294
# Number of itemsets for zimin 3 : 1738
# Number of itemsets for zimin 4 : 759
# Number of itemsets for zimin 5 : 139
# Number of itemsets for zimin 6 : 6
# Number of itemsets for zimin 7 : 0
# Number of itemsets for zimin 8 : 0
# Number of itemsets for zimin 9 : 0
# Number of itemsets for zimin 10 : 0
# Number of itemsets for zimin 11 : 0
# Number of itemsets for zimin 12 : 0
# Number of itemsets for zimin 13 : 0
# Number of itemsets for zimin 14 : 0
# Number of itemsets for zimin 15 : 0
# Number of itemsets for zimin 16 : 0
# Number of itemsets for zimin 17 : 0
# Number of itemsets for zimin 18 : 0
# Number of itemsets for zimin 19 : 0
# Number of itemsets for zimin 20 : 0
# Number of itemsets for zimin 21 : 0
# Number of itemsets for zimin 22 : 0
# Number of itemsets for zimin 23 : 0

# %%
#Association Rule
y = range(1,24)
z = range(50,100,10)

for n in z:
    for m in y:
        rules = apriori(baskets, supp=10, zmin=m, target='r', conf=n, report='ascl')
        print('\033[91m' + 'Number of rule with Confidance',n,'% and zmin',m,':', len(rules))
        for r in rules: 
            if r[0] == 'Yes_Attrition':
                print('\033[0m'+'------------------------')
                print(r)
# Out:
# Number of rule with Confidance 50 % and zmin 1 : 12919
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 2 : 12912
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 3 : 12384
# ------------------------
# ('Yes_Attrition', ('Yes_OverTime', 'EntryLevel'), 56, 0.06342015855039637, 0.5833333333333334, 3.366557734204793)
# Number of rule with Confidance 50 % and zmin 4 : 8660
# Number of rule with Confidance 50 % and zmin 5 : 3117
# Number of rule with Confidance 50 % and zmin 6 : 417
# Number of rule with Confidance 50 % and zmin 7 : 6
# Number of rule with Confidance 50 % and zmin 8 : 0
# Number of rule with Confidance 50 % and zmin 9 : 0
# Number of rule with Confidance 50 % and zmin 10 : 0
# ...
