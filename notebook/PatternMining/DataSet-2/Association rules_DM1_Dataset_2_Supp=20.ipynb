# %% [markdown]
# # ASSOCIATION RULES
# Express how product/services relate to each other, and tend to group together.

# %% [markdown]
# Library import

# %%
#vanno importate pandas e numpy e matplot per fare i grafici
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier 
from sklearn.model_selection import train_test_split  
from pandas import DataFrame

# %%
df = pd.read_csv(r'C:\Users\jigok\OneDrive\Desktop\UniPISA\1semestre1Anno\Data Mining\Progetto\Dataset AR\All_values_Train_HR_Employee_Attrition_No_OverallSatisfaction.csv')

# %%
df.head(5) #fammi vedere le prime 10 righe
# Out:
#     Age Attrition     BusinessTravel  DistanceFromHome  Education  \
# 0  52.0        No      Travel_Rarely                 9          4
# 1  36.0        No      Travel_Rarely                 1          1
# 2  25.0        No  Travel_Frequently                16          3
# 3  33.0        No      Travel_Rarely                 5          4
# 4  31.0        No      Travel_Rarely                 9          2
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0                        2    Male               3         3
# 1                        2    Male               3         5
# 2                        3    Male               3         2
# 3                        2    Male               3         1
# 4                        3  Female               3         1
#
#                  JobRole  ...  OverTime  PercentSalaryHike  \
# 0      Research Director  ...        No                 17
# 1                Manager  ...       Yes                 14
# ...

# %%
df.describe()
# Out:
#               Age  DistanceFromHome   Education  EnvironmentSatisfaction  \
# count  883.000000        883.000000  883.000000               883.000000
# mean    36.554926          9.201586    2.886750                 2.684032
# std      8.266129          8.241818    1.008285                 1.092567
# min     18.000000          1.000000    1.000000                 1.000000
# 25%     30.000000          2.000000    2.000000                 2.000000
# 50%     35.000000          7.000000    3.000000                 3.000000
# 75%     42.000000         14.000000    4.000000                 4.000000
# max     60.000000         29.000000    5.000000                 4.000000
#
#        JobInvolvement    JobLevel  JobSatisfaction  MonthlyIncome  \
# count      883.000000  883.000000       883.000000     883.000000
# mean         2.750849    1.919592         2.703284    6932.335221
# std          0.729354    1.007506         1.087061    5453.370217
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       883 non-null    float64
#  1   Attrition                 883 non-null    object
#  2   BusinessTravel            883 non-null    object
#  3   DistanceFromHome          883 non-null    int64
#  4   Education                 883 non-null    int64
#  5   EnvironmentSatisfaction   883 non-null    int64
#  6   Gender                    883 non-null    object
#  7   JobInvolvement            883 non-null    int64
#  8   JobLevel                  883 non-null    int64
#  9   JobRole                   883 non-null    object
#  10  JobSatisfaction           883 non-null    int64
#  11  MonthlyIncome             883 non-null    float64
#  12  NumCompaniesWorked        883 non-null    int64
#  13  OverTime                  883 non-null    object
# ...

# %%
#numero bin con la distribuzione istogrammi variabili
#Apply binning to continuous features

df['AgeBin'] = pd.cut(df['Age'].astype(int), 6, right=False)
df['DistanceFromHomeBin'] = pd.cut(df['DistanceFromHome'].astype(int), 10, right=False)
df['PercentSalaryHikeBin'] = pd.cut(df['PercentSalaryHike'].astype(int), 5, right=False)
df['MonthlyIncomeBin'] = pd.cut(df['MonthlyIncome'].astype(int), 10, right=False)
df['MonthlyHoursBin'] = pd.cut(df['MonthlyHours'].astype(int), 10, right=False)



df.drop(['Age', 'MonthlyIncome', 'MonthlyHours','DistanceFromHome','PercentSalaryHike'], axis=1, inplace=True)

df.head()
# Out:
#   Attrition     BusinessTravel  Education  EnvironmentSatisfaction  Gender  \
# 0        No      Travel_Rarely          4                        2    Male
# 1        No      Travel_Rarely          1                        2    Male
# 2        No  Travel_Frequently          3                        3    Male
# 3        No      Travel_Rarely          4                        2    Male
# 4        No      Travel_Rarely          2                        3  Female
#
#    JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0               3         3      Research Director                3
# 1               3         5                Manager                3
# 2               3         2        Sales Executive                4
# 3               3         1     Research Scientist                2
# 4               3         1  Laboratory Technician                4
#
#    NumCompaniesWorked  ... TrainingTimesLastYear  WorkLifeBalance  \
# ...

# %% [markdown]
# Mapping

# %%
df['Education'] = df['Education'].map(
    {1: 'Below College', 2: 'College', 3:'Bachelor', 4:'Master', 5:'Doctor'}).astype(str)

df['JobLevel'] = df['JobLevel'].map(
    {1: 'EntryLevel', 2: 'MidLevel', 3:'SeniorLevel', 4:'Manager', 5:'Director'}).astype(str)


df['AgeBin'] = df['AgeBin'].astype(str) + '_Age'
df['MonthlyIncomeBin'] = df['MonthlyIncomeBin'].astype(str) + '_Income'
df['MonthlyHoursBin'] = df['MonthlyHoursBin'].astype(str) + '_Hours'
df['DistanceFromHomeBin'] = df['DistanceFromHomeBin'].astype(str) + '_Distance'
df['YearsAtCompany'] = df['YearsAtCompany'].astype(str) + '_YearsAtCompany'
df['PercentSalaryHikeBin'] = df['PercentSalaryHikeBin'].astype(str) + '_%'

df['NumCompaniesWorked'] = df['NumCompaniesWorked'].astype(str) + '_companies'
df['StockOptionLevel'] = df['StockOptionLevel'].astype(str) + '_stockOption'
df['TrainingTimesLastYear'] = df['TrainingTimesLastYear'].astype(str) + '_Time'
df['YearsInCurrentRole'] = df['YearsInCurrentRole'].astype(str) + '_YearsInCurrentRole'
df['TaxRate'] = df['TaxRate'].astype(str) + '_TaxRate'

df['EnvironmentSatisfaction'] = df['EnvironmentSatisfaction'].astype(str) + '_ESat'
df['JobSatisfaction'] = df['JobSatisfaction'].astype(str) + '_JSat'
df['JobInvolvement'] = df['JobInvolvement'].astype(str) + '_JIvol'
df['WorkLifeBalance'] = df['WorkLifeBalance'].astype(str) + '_WLBalance'
df['RelationshipSatisfaction'] = df['RelationshipSatisfaction'].astype(str) + '_RSat'


df.head(10)
# Out:
#   Attrition     BusinessTravel      Education EnvironmentSatisfaction  Gender  \
# 0        No      Travel_Rarely         Master                  2_ESat    Male
# 1        No      Travel_Rarely  Below College                  2_ESat    Male
# 2        No  Travel_Frequently       Bachelor                  3_ESat    Male
# 3        No      Travel_Rarely         Master                  2_ESat    Male
# 4        No      Travel_Rarely        College                  3_ESat  Female
# 5        No      Travel_Rarely       Bachelor                  4_ESat    Male
# 6        No      Travel_Rarely        College                  3_ESat    Male
# 7        No  Travel_Frequently  Below College                  4_ESat    Male
# 8        No      Travel_Rarely        College                  4_ESat    Male
# 9        No      Travel_Rarely       Bachelor                  2_ESat    Male
#
#   JobInvolvement     JobLevel                 JobRole JobSatisfaction  \
# ...

# %% [markdown]
# Conto le transazioni che contengono attrition(yes)e le totali

# %%
df['Attrition'].value_counts()
# Out:
# No     730
# Yes    153
# Name: Attrition, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 883 entries, 0 to 882
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Attrition                 883 non-null    object
#  1   BusinessTravel            883 non-null    object
#  2   Education                 883 non-null    object
#  3   EnvironmentSatisfaction   883 non-null    object
#  4   Gender                    883 non-null    object
#  5   JobInvolvement            883 non-null    object
#  6   JobLevel                  883 non-null    object
#  7   JobRole                   883 non-null    object
#  8   JobSatisfaction           883 non-null    object
#  9   NumCompaniesWorked        883 non-null    object
#  10  OverTime                  883 non-null    object
#  11  RelationshipSatisfaction  883 non-null    object
#  12  StockOptionLevel          883 non-null    object
# ...

# %% [markdown]
# Ora so che il support di ATTRITION è dato da 153/883 ed è 0.17 quindi 17

# %% [markdown]
# # Creo i baskets

# %%
baskets = df.values.tolist()

# %%
baskets[0]
# Out:
# ['No',
#  'Travel_Rarely',
#  'Master',
#  '2_ESat',
#  'Male',
#  '3_JIvol',
#  'SeniorLevel',
#  'Research Director',
#  '3_JSat',
#  '9_companies',
#  'No',
#  '3_RSat',
#  '0_stockOption',
#  '2.0_Time',
#  '2_WLBalance',
#  '8.0_YearsAtCompany',
#  '7_YearsInCurrentRole',
#  '0.3871716731969235_TaxRate',
#  '[46.0, 53.0)_Age',
#  '[6.6, 9.4)_Distance',
#  '[16.6, 19.4)_%',
#  '[6206.6, 8805.4)_Income',
#  '[138.8, 195.2)_Hours']

# %% [markdown]
# # Apriori Algorithm

# %%
from fim import apriori

# %%
help(apriori)
# Out:
# Help on built-in function apriori in module fim:
#
# apriori(...)
#     apriori (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#              eval='x', agg='x', thresh=10, prune=None, algo='b', mode='',
#              border=None)
#     Find frequent item sets with the Apriori algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
# ...

# %% [markdown]
# # Description of the Value

# %% [markdown]
# We have ecide to do some proves with different characterized value of support. This value are 2,10,20,30,40,50,60,70,80,90.
# After that we have to do some proves with different type of target , a for frequent itemset, m for maximal itemset e c for closed itemset.
#
# For choosing the best combination we try to create the frequent itemset with 2/3/4 min value.

# %% [markdown]
# # Support = 20%

# %% [markdown]
#  Frequent Itemsets with min value 2/3/4

# %%
itemsets = apriori(baskets, supp=20, report ='s', target='a',zmin = 2)
print('Number of itemsets:', len(itemsets))
itemsets
# Out:
# Number of itemsets: 156
# [(('2_WLBalance', 'No'), 0.20385050962627407),
#  (('2_JIvol', 'No'), 0.21517553793884484),
#  (('[25.0, 32.0)_Age', 'No'), 0.22650056625141562),
#  (('Master', 'No'), 0.23669309173272934),
#  (('[13.8, 16.6)_%', 'No'), 0.23669309173272934),
#  (('2_YearsInCurrentRole', 'Travel_Rarely'), 0.20271800679501698),
#  (('2_YearsInCurrentRole', 'No'), 0.2480181200453001),
#  (('3.0_Time', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No'), 0.2582106455266138),
#  (('4_ESat', 'Travel_Rarely'), 0.22083805209513024),
#  (('4_ESat', 'Travel_Rarely', 'No'), 0.20045300113250283),
#  (('4_ESat', 'No'), 0.26160815402038506),
#  (('4_JSat', 'Travel_Rarely'), 0.2015855039637599),
#  (('4_JSat', 'No'), 0.27519818799546997),
#  (('4_RSat', 'Travel_Rarely'), 0.21404303510758776),
#  (('4_RSat', 'No'), 0.26840317100792754),
#  (('[3607.8, 6206.6)_Income', 'Travel_Rarely'), 0.20838052095130238),
#  (('[3607.8, 6206.6)_Income', 'No'), 0.27633069082672707),
# ...

# %%
itemsets1 = apriori(baskets, supp=20, report ='s', target='a',zmin = 3)
print('Number of itemsets:', len(itemsets1))
itemsets1
# Out:
# Number of itemsets: 57
# [(('4_ESat', 'Travel_Rarely', 'No'), 0.20045300113250283),
#  (('3_RSat', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('3_JSat', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('[1009.0, 3607.8)_Income', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No'), 0.22197055492638731),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No'), 0.23442808607021517),
#  (('MidLevel', '3_JIvol', 'No'), 0.20838052095130238),
#  (('MidLevel', '3_WLBalance', 'No'), 0.2129105322763307),
#  (('MidLevel', 'Male', 'No'), 0.217440543601359),
#  (('MidLevel', 'Travel_Rarely', 'No'), 0.25934314835787087),
#  (('1_companies', '3_WLBalance', 'No'), 0.2276330690826727),
#  (('1_companies', 'Male', 'No'), 0.21630804077010193),
#  (('1_companies', 'Travel_Rarely', 'No'), 0.26160815402038506),
#  (('Female', '3_WLBalance', 'No'), 0.22083805209513024),
#  (('Female', 'Travel_Rarely', 'No'), 0.25934314835787087),
# ...

# %%
itemsets2 = apriori(baskets, supp=20, report ='s', target='a',zmin = 4)
print('Number of itemsets:', len(itemsets2))
itemsets2
# Out:
# Number of itemsets: 5
# [(('2.0_Time', 'Male', 'Travel_Rarely', 'No'), 0.20271800679501698),
#  (('3_JIvol', '3_WLBalance', 'Male', 'No'), 0.20385050962627407),
#  (('3_JIvol', '3_WLBalance', 'Travel_Rarely', 'No'), 0.2434881087202718),
#  (('3_JIvol', 'Male', 'Travel_Rarely', 'No'), 0.23442808607021517),
#  (('3_WLBalance', 'Male', 'Travel_Rarely', 'No'), 0.25028312570781425)]

# %% [markdown]
# Maximal Itemset with min value 2/3/4

# %%
itemsets3 = apriori(baskets, supp=20, report ='s', target='m',zmin = 2)
print('Number of itemsets:', len(itemsets3))
itemsets3
# Out:
# Number of itemsets: 79
# [(('2_WLBalance', 'No'), 0.20385050962627407),
#  (('2_JIvol', 'No'), 0.21517553793884484),
#  (('[25.0, 32.0)_Age', 'No'), 0.22650056625141562),
#  (('Master', 'No'), 0.23669309173272934),
#  (('[13.8, 16.6)_%', 'No'), 0.23669309173272934),
#  (('2_YearsInCurrentRole', 'Travel_Rarely'), 0.20271800679501698),
#  (('2_YearsInCurrentRole', 'No'), 0.2480181200453001),
#  (('3.0_Time', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No'), 0.2582106455266138),
#  (('4_ESat', 'Travel_Rarely', 'No'), 0.20045300113250283),
#  (('4_JSat', 'Travel_Rarely'), 0.2015855039637599),
#  (('4_JSat', 'No'), 0.27519818799546997),
#  (('4_RSat', 'Travel_Rarely'), 0.21404303510758776),
#  (('4_RSat', 'No'), 0.26840317100792754),
#  (('[3607.8, 6206.6)_Income', 'Travel_Rarely'), 0.20838052095130238),
#  (('[3607.8, 6206.6)_Income', 'No'), 0.27633069082672707),
#  (('3_ESat', 'Travel_Rarely'), 0.21404303510758776),
#  (('3_ESat', 'No'), 0.2865232163080408),
# ...

# %%
itemsets4 = apriori(baskets, supp=20, report ='s', target='m',zmin = 3)
print('Number of itemsets:', len(itemsets4))
itemsets4
# Out:
# Number of itemsets: 44
# [(('4_ESat', 'Travel_Rarely', 'No'), 0.20045300113250283),
#  (('3_RSat', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('3_JSat', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('[1009.0, 3607.8)_Income', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No'), 0.22197055492638731),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No'), 0.23442808607021517),
#  (('MidLevel', '3_JIvol', 'No'), 0.20838052095130238),
#  (('MidLevel', '3_WLBalance', 'No'), 0.2129105322763307),
#  (('MidLevel', 'Male', 'No'), 0.217440543601359),
#  (('MidLevel', 'Travel_Rarely', 'No'), 0.25934314835787087),
#  (('1_companies', '3_WLBalance', 'No'), 0.2276330690826727),
#  (('1_companies', 'Male', 'No'), 0.21630804077010193),
#  (('1_companies', 'Travel_Rarely', 'No'), 0.26160815402038506),
#  (('Female', '3_WLBalance', 'No'), 0.22083805209513024),
#  (('Female', 'Travel_Rarely', 'No'), 0.25934314835787087),
# ...

# %%
itemsets5 = apriori(baskets, supp=20, report ='s', target='m',zmin = 4)
print('Number of itemsets:', len(itemsets5))
itemsets5
# Out:
# Number of itemsets: 5
# [(('2.0_Time', 'Male', 'Travel_Rarely', 'No'), 0.20271800679501698),
#  (('3_JIvol', '3_WLBalance', 'Male', 'No'), 0.20385050962627407),
#  (('3_JIvol', '3_WLBalance', 'Travel_Rarely', 'No'), 0.2434881087202718),
#  (('3_JIvol', 'Male', 'Travel_Rarely', 'No'), 0.23442808607021517),
#  (('3_WLBalance', 'Male', 'Travel_Rarely', 'No'), 0.25028312570781425)]

# %% [markdown]
# Closed Itemset with min value 2/3/4

# %%
itemsets6 = apriori(baskets, supp=20, report ='s', target='c',zmin = 2)
print('Number of itemsets:', len(itemsets6))
itemsets6
# Out:
# Number of itemsets: 156
# [(('2_WLBalance', 'No'), 0.20385050962627407),
#  (('2_JIvol', 'No'), 0.21517553793884484),
#  (('[25.0, 32.0)_Age', 'No'), 0.22650056625141562),
#  (('Master', 'No'), 0.23669309173272934),
#  (('[13.8, 16.6)_%', 'No'), 0.23669309173272934),
#  (('2_YearsInCurrentRole', 'Travel_Rarely'), 0.20271800679501698),
#  (('2_YearsInCurrentRole', 'No'), 0.2480181200453001),
#  (('3.0_Time', 'Travel_Rarely'), 0.20385050962627407),
#  (('3.0_Time', 'No'), 0.2582106455266138),
#  (('4_ESat', 'Travel_Rarely'), 0.22083805209513024),
#  (('4_ESat', 'Travel_Rarely', 'No'), 0.20045300113250283),
#  (('4_ESat', 'No'), 0.26160815402038506),
#  (('4_JSat', 'Travel_Rarely'), 0.2015855039637599),
#  (('4_JSat', 'No'), 0.27519818799546997),
#  (('4_RSat', 'Travel_Rarely'), 0.21404303510758776),
#  (('4_RSat', 'No'), 0.26840317100792754),
#  (('[3607.8, 6206.6)_Income', 'Travel_Rarely'), 0.20838052095130238),
#  (('[3607.8, 6206.6)_Income', 'No'), 0.27633069082672707),
# ...

# %%
itemsets7 = apriori(baskets, supp=20, report ='s', target='c',zmin = 3)
print('Number of itemsets:', len(itemsets7))
itemsets7
# Out:
# Number of itemsets: 57
# [(('4_ESat', 'Travel_Rarely', 'No'), 0.20045300113250283),
#  (('3_RSat', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('3_JSat', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('[1009.0, 3607.8)_Income', 'Travel_Rarely', 'No'), 0.21404303510758776),
#  (('[1.0, 3.8)_Distance', 'Travel_Rarely', 'No'), 0.22197055492638731),
#  (('[32.0, 39.0)_Age', 'Travel_Rarely', 'No'), 0.23442808607021517),
#  (('MidLevel', '3_JIvol', 'No'), 0.20838052095130238),
#  (('MidLevel', '3_WLBalance', 'No'), 0.2129105322763307),
#  (('MidLevel', 'Male', 'No'), 0.217440543601359),
#  (('MidLevel', 'Travel_Rarely', 'No'), 0.25934314835787087),
#  (('1_companies', '3_WLBalance', 'No'), 0.2276330690826727),
#  (('1_companies', 'Male', 'No'), 0.21630804077010193),
#  (('1_companies', 'Travel_Rarely', 'No'), 0.26160815402038506),
#  (('Female', '3_WLBalance', 'No'), 0.22083805209513024),
#  (('Female', 'Travel_Rarely', 'No'), 0.25934314835787087),
# ...

# %%
itemsets8 = apriori(baskets, supp=20, report ='s', target='c',zmin = 4)
print('Number of itemsets:', len(itemsets8))
itemsets8
# Out:
# Number of itemsets: 5
# [(('2.0_Time', 'Male', 'Travel_Rarely', 'No'), 0.20271800679501698),
#  (('3_JIvol', '3_WLBalance', 'Male', 'No'), 0.20385050962627407),
#  (('3_JIvol', '3_WLBalance', 'Travel_Rarely', 'No'), 0.2434881087202718),
#  (('3_JIvol', 'Male', 'Travel_Rarely', 'No'), 0.23442808607021517),
#  (('3_WLBalance', 'Male', 'Travel_Rarely', 'No'), 0.25028312570781425)]

# %% [markdown]
# # Considerazioni finali

# %% [markdown]
# Un valore di supporto elevato non permette di catturare molte associazioni significative, viceversa un valore troppo basso
# porta ad un numero elevato di itemset ed a una difficile analisi con 50 e 60

# %%
print('Numeber of itemset with support = 20')
print ('Target Frequent')
print('Number of itemsets [2]:', len(itemsets))
print('Number of itemsets [3]:', len(itemsets1))
print('Number of itemsets [4]:', len(itemsets2))
print ('Target Maximum')
print('Number of itemsets [2]:', len(itemsets3))
print('Number of itemsets [3]:', len(itemsets4))
print('Number of itemsets [4]:', len(itemsets5))
print('Target Closed')
print('Number of itemsets [2]:', len(itemsets6))
print('Number of itemsets [3]:', len(itemsets7))
print('Number of itemsets [4]:', len(itemsets8))
# Out:
# Numeber of itemset with support = 20
# Target Frequent
# Number of itemsets [2]: 156
# Number of itemsets [3]: 57
# Number of itemsets [4]: 5
# Target Maximum
# Number of itemsets [2]: 79
# Number of itemsets [3]: 44
# Number of itemsets [4]: 5
# Target Closed
# Number of itemsets [2]: 156
# Number of itemsets [3]: 57
# Number of itemsets [4]: 5

# %% [markdown]
# # Association Rules zmin = 2

# %%
rules = apriori(baskets, supp=20, zmin=2, target='r', conf=60, 
                report='ascl') 
print('Number of rule:', len(rules))
set(rules)
# Out:
# Number of rule: 494
# {('3_JIvol',
#   ('0_stockOption', '3_WLBalance', 'No'),
#   130,
#   0.14722536806342015,
#   0.6161137440758294,
#   1.062555539099526),
#  ('3_JIvol',
#   ('0_stockOption', 'Male', 'No'),
#   132,
#   0.14949037372593432,
#   0.6055045871559633,
#   1.044258887614679),
#  ('3_JIvol',
#   ('1_companies', 'Male', 'No'),
#   117,
#   0.13250283125707815,
#   0.612565445026178,
#   1.0564361092931938),
#  ('3_JIvol',
#   ('1_stockOption',),
#   207,
#   0.23442808607021517,
#   0.6017441860465116,
#   1.0377736646075582),
#  ('3_JIvol',
#   ('1_stockOption', 'Male'),
#   122,
#   0.13816534541336353,
#   0.6069651741293532,
#   1.04677782960199),
#  ('3_JIvol',
#   ('1_stockOption', 'Male', 'No'),
#   117,
#   0.13250283125707815,
#   0.6157894736842106,
#   1.0619962993421053),
#  ('3_JIvol',
#   ('1_stockOption', 'No'),
#   197,
#   0.22310305775764439,
#   0.6061538461538462,
#   1.0453786057692307),
#  ('3_JIvol',
#   ('2_YearsInCurrentRole',),
#   155,
# ...

# %%
rules1 = apriori(baskets, supp=20, zmin=2, target='r', conf=70, 
                report='ascl') 
print('Number of rule:', len(rules1))
set(rules1)
# Out:
# Number of rule: 232
# {('EntryLevel',
#   ('Research Scientist',),
#   151,
#   0.1710079275198188,
#   0.8031914893617021,
#   1.9484013327098433),
#  ('MidLevel',
#   ('Sales Executive',),
#   145,
#   0.16421291053227632,
#   0.7712765957446809,
#   2.0954991816693944),
#  ('No',
#   ('0_stockOption',),
#   336,
#   0.38052095130237823,
#   0.8682170542635659,
#   0.954714394663423),
#  ('No',
#   ('0_stockOption', '2.0_Time'),
#   158,
#   0.17893544733861835,
#   0.8272251308900523,
#   0.9096385934942917),
#  ('No',
#   ('0_stockOption', '3_JIvol'),
#   198,
#   0.22423556058890148,
#   0.8918918918918919,
#   0.9807478711588301),
#  ('No',
#   ('0_stockOption', '3_WLBalance'),
#   211,
#   0.23895809739524349,
#   0.8865546218487395,
#   0.9748788681101332),
#  ('No',
#   ('0_stockOption', 'Male'),
#   218,
#   0.24688561721404303,
#   0.872,
#   0.9588742216687423),
#  ('No',
#   ('0_stockOption', 'Male', 'Travel_Rarely'),
#   156,
#   0.17667044167610418,
# ...

# %%
rules2 = apriori(baskets, supp=20, zmin=2, target='r', conf=80, 
                report='ascl') 
print('Number of rule:', len(rules2))
set(rules2)
# Out:
# Number of rule: 110
# {('EntryLevel',
#   ('Research Scientist',),
#   151,
#   0.1710079275198188,
#   0.8031914893617021,
#   1.9484013327098433),
#  ('No',
#   ('0_stockOption',),
#   336,
#   0.38052095130237823,
#   0.8682170542635659,
#   0.954714394663423),
#  ('No',
#   ('0_stockOption', '2.0_Time'),
#   158,
#   0.17893544733861835,
#   0.8272251308900523,
#   0.9096385934942917),
#  ('No',
#   ('0_stockOption', '3_JIvol'),
#   198,
#   0.22423556058890148,
#   0.8918918918918919,
#   0.9807478711588301),
#  ('No',
#   ('0_stockOption', '3_WLBalance'),
#   211,
#   0.23895809739524349,
#   0.8865546218487395,
#   0.9748788681101332),
#  ('No',
#   ('0_stockOption', 'Male'),
#   218,
#   0.24688561721404303,
#   0.872,
#   0.9588742216687423),
#  ('No',
#   ('0_stockOption', 'Male', 'Travel_Rarely'),
#   156,
#   0.17667044167610418,
#   0.861878453038674,
#   0.9477443014111446),
#  ('No',
#   ('0_stockOption', 'Travel_Rarely'),
#   240,
#   0.2718006795016987,
# ...

# %%
rules3 = apriori(baskets, supp=20, zmin=2, target='r', conf=90, 
                report='ascl') 
print('Number of rule:', len(rules3))
set(rules3)
# Out:
# Number of rule: 69
# {('No',
#   ('1_companies', '3_JIvol'),
#   174,
#   0.1970554926387316,
#   0.90625,
#   0.9965364259028643),
#  ('No',
#   ('1_companies', '3_WLBalance'),
#   201,
#   0.2276330690826727,
#   0.9054054054054054,
#   0.9956076873885094),
#  ('No',
#   ('1_stockOption',),
#   325,
#   0.36806342015855037,
#   0.9447674418604651,
#   1.0388912218714703),
#  ('No',
#   ('1_stockOption', '3_JIvol'),
#   197,
#   0.22310305775764439,
#   0.9516908212560387,
#   1.0465043526389566),
#  ('No',
#   ('1_stockOption', '3_WLBalance'),
#   189,
#   0.21404303510758776,
#   0.945,
#   1.0391469489414695),
#  ('No',
#   ('1_stockOption', 'Male'),
#   190,
#   0.21517553793884484,
#   0.945273631840796,
#   1.039447841737762),
#  ('No',
#   ('1_stockOption', 'Travel_Rarely'),
#   235,
#   0.26613816534541335,
#   0.9475806451612904,
#   1.0419846944924276),
#  ('No',
#   ('2.0_Time', '3_JIvol'),
#   224,
#   0.2536806342015855,
#   0.9142857142857143,
#   1.0053727094822986),
# ...

# %%
print('Numeber of rules with support = 20 e zmin = 2')

print('Number of rules, confidance [60]:', len(rules))
print('Number of rules, confidance [70]:', len(rules1))
print('Number of rules, confidance [80]:', len(rules2))
print('Number of rules, confidance [90]:', len(rules3))
# Out:
# Numeber of rules with support = 20 e zmin = 2
# Number of rules, confidance [60]: 494
# Number of rules, confidance [70]: 232
# Number of rules, confidance [80]: 110
# Number of rules, confidance [90]: 69

# %% [markdown]
# # Association Rules, zimn=3

# %%
rules = apriori(baskets, supp=20, zmin=3, target='r', conf=60, 
                report='ascl') 
print('Number of rule:', len(rules))
set(rules)
# Out:
# Number of rule: 361
# {('3_JIvol',
#   ('0_stockOption', '3_WLBalance', 'No'),
#   130,
#   0.14722536806342015,
#   0.6161137440758294,
#   1.062555539099526),
#  ('3_JIvol',
#   ('0_stockOption', 'Male', 'No'),
#   132,
#   0.14949037372593432,
#   0.6055045871559633,
#   1.044258887614679),
#  ('3_JIvol',
#   ('1_companies', 'Male', 'No'),
#   117,
#   0.13250283125707815,
#   0.612565445026178,
#   1.0564361092931938),
#  ('3_JIvol',
#   ('1_stockOption', 'Male'),
#   122,
#   0.13816534541336353,
#   0.6069651741293532,
#   1.04677782960199),
#  ('3_JIvol',
#   ('1_stockOption', 'Male', 'No'),
#   117,
#   0.13250283125707815,
#   0.6157894736842106,
#   1.0619962993421053),
#  ('3_JIvol',
#   ('1_stockOption', 'No'),
#   197,
#   0.22310305775764439,
#   0.6061538461538462,
#   1.0453786057692307),
#  ('3_JIvol',
#   ('2_YearsInCurrentRole', 'No'),
#   142,
#   0.16081540203850508,
#   0.6484018264840182,
#   1.1182398687214612),
#  ('3_JIvol',
# ...

# %%
rules1 = apriori(baskets, supp=20, zmin=3, target='r', conf=70, 
                report='ascl') 
print('Number of rule:', len(rules1))
set(rules1)
# Out:
# Number of rule: 161
# {('No',
#   ('0_stockOption', '2.0_Time'),
#   158,
#   0.17893544733861835,
#   0.8272251308900523,
#   0.9096385934942917),
#  ('No',
#   ('0_stockOption', '3_JIvol'),
#   198,
#   0.22423556058890148,
#   0.8918918918918919,
#   0.9807478711588301),
#  ('No',
#   ('0_stockOption', '3_WLBalance'),
#   211,
#   0.23895809739524349,
#   0.8865546218487395,
#   0.9748788681101332),
#  ('No',
#   ('0_stockOption', 'Male'),
#   218,
#   0.24688561721404303,
#   0.872,
#   0.9588742216687423),
#  ('No',
#   ('0_stockOption', 'Male', 'Travel_Rarely'),
#   156,
#   0.17667044167610418,
#   0.861878453038674,
#   0.9477443014111446),
#  ('No',
#   ('0_stockOption', 'Travel_Rarely'),
#   240,
#   0.2718006795016987,
#   0.8602150537634409,
#   0.9459151836527002),
#  ('No',
#   ('1_companies', '3_JIvol'),
#   174,
#   0.1970554926387316,
#   0.90625,
#   0.9965364259028643),
#  ('No',
#   ('1_companies', '3_WLBalance'),
#   201,
#   0.2276330690826727,
# ...

# %%
rules2 = apriori(baskets, supp=20, zmin=3, target='r', conf=80, 
                report='ascl') 
print('Number of rule:', len(rules2))
set(rules2)
# Out:
# Number of rule: 73
# {('No',
#   ('0_stockOption', '2.0_Time'),
#   158,
#   0.17893544733861835,
#   0.8272251308900523,
#   0.9096385934942917),
#  ('No',
#   ('0_stockOption', '3_JIvol'),
#   198,
#   0.22423556058890148,
#   0.8918918918918919,
#   0.9807478711588301),
#  ('No',
#   ('0_stockOption', '3_WLBalance'),
#   211,
#   0.23895809739524349,
#   0.8865546218487395,
#   0.9748788681101332),
#  ('No',
#   ('0_stockOption', 'Male'),
#   218,
#   0.24688561721404303,
#   0.872,
#   0.9588742216687423),
#  ('No',
#   ('0_stockOption', 'Male', 'Travel_Rarely'),
#   156,
#   0.17667044167610418,
#   0.861878453038674,
#   0.9477443014111446),
#  ('No',
#   ('0_stockOption', 'Travel_Rarely'),
#   240,
#   0.2718006795016987,
#   0.8602150537634409,
#   0.9459151836527002),
#  ('No',
#   ('1_companies', '3_JIvol'),
#   174,
#   0.1970554926387316,
#   0.90625,
#   0.9965364259028643),
#  ('No',
#   ('1_companies', '3_WLBalance'),
#   201,
#   0.2276330690826727,
# ...

# %%
rules3 = apriori(baskets, supp=20, zmin=3, target='r', conf=90, 
                report='ascl') 
print('Number of rule:', len(rules3))
set(rules3)
# Out:
# Number of rule: 43
# {('No',
#   ('1_companies', '3_JIvol'),
#   174,
#   0.1970554926387316,
#   0.90625,
#   0.9965364259028643),
#  ('No',
#   ('1_companies', '3_WLBalance'),
#   201,
#   0.2276330690826727,
#   0.9054054054054054,
#   0.9956076873885094),
#  ('No',
#   ('1_stockOption', '3_JIvol'),
#   197,
#   0.22310305775764439,
#   0.9516908212560387,
#   1.0465043526389566),
#  ('No',
#   ('1_stockOption', '3_WLBalance'),
#   189,
#   0.21404303510758776,
#   0.945,
#   1.0391469489414695),
#  ('No',
#   ('1_stockOption', 'Male'),
#   190,
#   0.21517553793884484,
#   0.945273631840796,
#   1.039447841737762),
#  ('No',
#   ('1_stockOption', 'Travel_Rarely'),
#   235,
#   0.26613816534541335,
#   0.9475806451612904,
#   1.0419846944924276),
#  ('No',
#   ('2.0_Time', '3_JIvol'),
#   224,
#   0.2536806342015855,
#   0.9142857142857143,
#   1.0053727094822986),
#  ('No',
#   ('3.0_Time', 'Travel_Rarely'),
#   165,
#   0.1868629671574179,
#   0.9166666666666666,
# ...

# %%
print('Numeber of rules with support = 20 e zmin = 3')

print('Number of rules, confidance [60]:', len(rules))
print('Number of rules, confidance [70]:', len(rules1))
print('Number of rules, confidance [80]:', len(rules2))
print('Number of rules, confidance [90]:', len(rules3))
# Out:
# Numeber of rules with support = 20 e zmin = 3
# Number of rules, confidance [60]: 361
# Number of rules, confidance [70]: 161
# Number of rules, confidance [80]: 73
# Number of rules, confidance [90]: 43

# %% [markdown]
# # Association Rules, zimn=4

# %%
rules = apriori(baskets, supp=20, zmin=4, target='r', conf=60, 
                report='ascl') 
print('Number of rule:', len(rules))
set(rules)
# Out:
# Number of rule: 98
# {('3_JIvol',
#   ('0_stockOption', '3_WLBalance', 'No'),
#   130,
#   0.14722536806342015,
#   0.6161137440758294,
#   1.062555539099526),
#  ('3_JIvol',
#   ('0_stockOption', 'Male', 'No'),
#   132,
#   0.14949037372593432,
#   0.6055045871559633,
#   1.044258887614679),
#  ('3_JIvol',
#   ('1_companies', 'Male', 'No'),
#   117,
#   0.13250283125707815,
#   0.612565445026178,
#   1.0564361092931938),
#  ('3_JIvol',
#   ('1_stockOption', 'Male', 'No'),
#   117,
#   0.13250283125707815,
#   0.6157894736842106,
#   1.0619962993421053),
#  ('3_JIvol',
#   ('3_WLBalance', 'Male', 'No'),
#   180,
#   0.20385050962627407,
#   0.6143344709897611,
#   1.0594869880546076),
#  ('3_JIvol',
#   ('4_ESat', 'Travel_Rarely', 'No'),
#   110,
#   0.1245753114382786,
#   0.6214689265536724,
#   1.0717911370056497),
#  ('3_JIvol',
#   ('EntryLevel', '3_WLBalance', 'No'),
#   113,
#   0.12797281993204984,
#   0.6042780748663101,
#   1.0421436330213905),
#  ('3_JIvol',
# ...

# %%
rules1 = apriori(baskets, supp=20, zmin=4, target='r', conf=70, 
                report='ascl') 
print('Number of rule:', len(rules1))
set(rules1)
# Out:
# Number of rule: 30
# {('No',
#   ('0_stockOption', 'Male', 'Travel_Rarely'),
#   156,
#   0.17667044167610418,
#   0.861878453038674,
#   0.9477443014111446),
#  ('No',
#   ('2.0_Time', '3_WLBalance', 'Travel_Rarely'),
#   157,
#   0.17780294450736125,
#   0.8820224719101124,
#   0.9698951963843452),
#  ('No',
#   ('2.0_Time', 'Male', 'Travel_Rarely'),
#   179,
#   0.20271800679501698,
#   0.895,
#   0.9841656288916563),
#  ('No',
#   ('3_JIvol', '3_WLBalance', 'Male'),
#   180,
#   0.20385050962627407,
#   0.9375,
#   1.0308997509339974),
#  ('No',
#   ('3_JIvol', '3_WLBalance', 'Travel_Rarely'),
#   215,
#   0.2434881087202718,
#   0.9307359307359307,
#   1.0234618017930597),
#  ('No',
#   ('3_JIvol', 'Male', 'Travel_Rarely'),
#   207,
#   0.23442808607021517,
#   0.92,
#   1.0116562889165628),
#  ('No',
#   ('3_WLBalance', 'Male', 'Travel_Rarely'),
#   221,
#   0.25028312570781425,
#   0.9208333333333333,
#   1.0125726442507264),
#  ('Travel_Rarely',
# ...

# %%
rules2 = apriori(baskets, supp=20, zmin=4, target='r', conf=80, 
                report='ascl') 
print('Number of rule:', len(rules2))
set(rules2)
# Out:
# Number of rule: 8
# {('No',
#   ('0_stockOption', 'Male', 'Travel_Rarely'),
#   156,
#   0.17667044167610418,
#   0.861878453038674,
#   0.9477443014111446),
#  ('No',
#   ('2.0_Time', '3_WLBalance', 'Travel_Rarely'),
#   157,
#   0.17780294450736125,
#   0.8820224719101124,
#   0.9698951963843452),
#  ('No',
#   ('2.0_Time', 'Male', 'Travel_Rarely'),
#   179,
#   0.20271800679501698,
#   0.895,
#   0.9841656288916563),
#  ('No',
#   ('3_JIvol', '3_WLBalance', 'Male'),
#   180,
#   0.20385050962627407,
#   0.9375,
#   1.0308997509339974),
#  ('No',
#   ('3_JIvol', '3_WLBalance', 'Travel_Rarely'),
#   215,
#   0.2434881087202718,
#   0.9307359307359307,
#   1.0234618017930597),
#  ('No',
#   ('3_JIvol', 'Male', 'Travel_Rarely'),
#   207,
#   0.23442808607021517,
#   0.92,
#   1.0116562889165628),
#  ('No',
#   ('3_WLBalance', 'Male', 'Travel_Rarely'),
#   221,
#   0.25028312570781425,
#   0.9208333333333333,
#   1.0125726442507264),
#  ('Travel_Rarely',
# ...

# %%
rules3 = apriori(baskets, supp=20, zmin=4, target='r', conf=90, 
                report='ascl') 
print('Number of rule:', len(rules3))
set(rules3)
# Out:
# Number of rule: 4
# {('No',
#   ('3_JIvol', '3_WLBalance', 'Male'),
#   180,
#   0.20385050962627407,
#   0.9375,
#   1.0308997509339974),
#  ('No',
#   ('3_JIvol', '3_WLBalance', 'Travel_Rarely'),
#   215,
#   0.2434881087202718,
#   0.9307359307359307,
#   1.0234618017930597),
#  ('No',
#   ('3_JIvol', 'Male', 'Travel_Rarely'),
#   207,
#   0.23442808607021517,
#   0.92,
#   1.0116562889165628),
#  ('No',
#   ('3_WLBalance', 'Male', 'Travel_Rarely'),
#   221,
#   0.25028312570781425,
#   0.9208333333333333,
#   1.0125726442507264)}

# %%
print('Numeber of rules with support = 20 e zmin = 4')

print('Number of rules, confidance [60]:', len(rules))
print('Number of rules, confidance [70]:', len(rules1))
print('Number of rules, confidance [80]:', len(rules2))
print('Number of rules, confidance [90]:', len(rules3))
# Out:
# Numeber of rules with support = 20 e zmin = 4
# Number of rules, confidance [60]: 98
# Number of rules, confidance [70]: 30
# Number of rules, confidance [80]: 8
# Number of rules, confidance [90]: 4
