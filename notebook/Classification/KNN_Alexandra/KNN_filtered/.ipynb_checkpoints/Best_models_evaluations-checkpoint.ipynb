# %% [markdown]
# <b>Data mining project - 2020/21</b><br>
# <b>Author</b>: [Alexandra Bradan](https://github.com/alexandrabradan)<br>
# <b>Python version</b>: 3.x<br>
# <b>Last update: 07/01/2021<b>

# %%
# %matplotlib inline

# general libraries
import sys
import math
import operator
import itertools
import collections
from collections import Counter
from collections import defaultdict
from IPython.display import Image

# pandas libraries
import pandas as pd
from pandas import DataFrame
from pandas.testing import assert_frame_equal

# visualisation libraries
import seaborn as sns
import matplotlib.pyplot as plt

# numpy libraries
import numpy as np
from numpy import std
from numpy import mean
from numpy import arange
from numpy import unique
from numpy import argmax
from numpy import percentile

# scipy libraries
import scipy.stats as stats
from scipy.stats import kstest
from scipy.stats import normaltest

# sklearn libraries
from sklearn.impute import KNNImputer
from sklearn.impute import SimpleImputer
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.preprocessing import PolynomialFeatures
from sklearn.experimental import enable_iterative_imputer  # explicitly require this experimental feature
from sklearn.impute import IterativeImputer

from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import RandomOverSampler
from imblearn.pipeline import Pipeline as imbPipeline
from imblearn.pipeline import make_pipeline as imbmake_pipeline
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import RandomizedSearchCV
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import RepeatedStratifiedKFold 
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MaxAbsScaler
from sklearn.preprocessing import RobustScaler
from sklearn.metrics import accuracy_score, f1_score, fbeta_score, recall_score, precision_score, classification_report, roc_auc_score

# %%
global_info = {}

# %%
def to_labels(pos_probs, threshold):
    # apply threshold to positive probabilities to create labels
    return (pos_probs >= threshold).astype('int')

# %%
def get_model_thresholds(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    # predict probabilities
    yhat = model.predict_proba(X_test)
    # keep probabilities for the positive outcome only
    probs = yhat[:, 1]
    # define thresholds
    thresholds = arange(0, 1, 0.001)
    # evaluate each threshold
    # scores = [average_precision_score(y_test, to_labels(probs, t)) for t in thresholds]
    scores = [roc_auc_score(y_test, to_labels(probs, t)) for t in thresholds]
    #get best threshold
    ix = argmax(scores)
    print( 'ModelThreshold=%.3f, AP=%.5f ' % (thresholds[ix], scores[ix]))
    return thresholds[ix]

# %%
def plot_confusion_matrix(cm, classes, normalize, title, cmap):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    # plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    # plt.clf()

# %%
def plot_classification_report(y_test, y_pred_vals_u, model_classes, cmap, title):
    clf_report = classification_report(y_test,
                                   y_pred_vals_u,
                                   labels=np.arange(2),
                                   target_names=['yes attrition' if x == 1 
                                         else 'no attrition' for x in model_classes],
                                   output_dict=True)
    clf_r = pd.DataFrame(clf_report).iloc[:-1, :].T
    # clf_r.iloc[2, 0] = np.nan
    # clf_r.iloc[2, 1] = np.nan
    sns.heatmap(clf_r, annot=True, cmap=cmap, cbar=False)
    plt.title(title)
    plt.show()

# %%
def fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, X_train, y_train,
                     X_test, y_test, n_neighbors, weights, p):
    y_pred_vals_u = []
    y_pred_trains_u = []
    roc_auc_models_u_val = []
    precision_recall_auc_models_u_val = []
    clf = None
    if type_flag2 == "validation" or type_flag2 == "test":
        models_u = []
        clf = KNeighborsClassifier(n_neighbors=n_neighbors, 
                                     weights=weights,
                                     p=p)
        clf = clf.fit(X_train, y_train)
        models_u.append(clf)
    else:
        print("Wrong type_flag=%s" % type_flag2)
        
    y_pred = clf.predict(X_test)
    y_pred_tr = clf.predict(X_train)
    y_pred_vals_u.append(y_pred)
    y_pred_trains_u.append(y_pred_tr)


    fpr, tpr, thresholds = roc_curve(y_train, y_pred_trains_u[0])
    roc_auc = auc(fpr, tpr)
    roc_auc = roc_auc_score(y_train, y_pred_trains_u[0], average="weighted")
    print('Train Accuracy %s' % accuracy_score(y_train, y_pred_trains_u[0]))
    print('Train Precision %s' % precision_score(y_train, y_pred_trains_u[0], average="weighted"))
    print('Train Recall %s' % recall_score(y_train, y_pred_trains_u[0], average="weighted"))
    print('Train F1-score %s' % f1_score(y_train, y_pred_trains_u[0], average="weighted"))
    print('Train F2-score %s' % fbeta_score(y_train, y_pred_trains_u[0], average="weighted", beta=2))
    print("Train roc_auc: {}".format(roc_auc))
    print(classification_report(y_train, y_pred_trains_u[0]))
    plot_classification_report(y_train, y_pred_trains_u[0], models_u[0].classes_, cmap, \
                               "Model %s\'s %s classification report" % (model_name, type_flag1))
    cm = confusion_matrix(y_train, y_pred_trains_u[0])
    plot_confusion_matrix(cm, models_u[0].classes_, False, "Model %s\'s %s confusion matrix"
                          % (model_name, type_flag1), cmap)
    plt.show()

    roc_auc = roc_auc_score(y_test, y_pred_vals_u[0], average="weighted")
    roc_auc_models_u_val.append(roc_auc)
    print("Validation roc_auc: {}".format(roc_auc))

    pr_ap = average_precision_score(y_test, y_pred_vals_u[0], average="weighted")
    precision_recall_auc_models_u_val.append(pr_ap)
    print("Validation precision_recall_ap: {}".format(pr_ap))

    print('\nTest Accuracy %s' % accuracy_score(y_test, y_pred_vals_u[0]))
    print('Validation Precision %s' % precision_score(y_test, y_pred_vals_u[0], average="weighted"))
    print('Validation Recall %s' % recall_score(y_test, y_pred_vals_u[0], average="weighted"))
    print('Validation F1-score %s' % f1_score(y_test, y_pred_vals_u[0], average="weighted"))
    print('Validation F2-score %s' % fbeta_score(y_test, y_pred_vals_u[0], average="weighted", beta=2))
    print(classification_report(y_test, y_pred_vals_u[0]))
    plot_classification_report(y_test, y_pred_vals_u[0], models_u[0].classes_, cmap, \
                               "Model %s\'s %s classification report" % (model_name, type_flag2))
    cm = confusion_matrix(y_test, y_pred_vals_u[0])
    plot_confusion_matrix(cm, models_u[0].classes_, False, "Model %s\'s %s confusion matrix" 
                          % (model_name, type_flag2), cmap)
    plt.show()
        
    return models_u, y_pred_vals_u, y_pred_trains_u, roc_auc_models_u_val, precision_recall_auc_models_u_val

# %%
def draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u, y_train, y_test,
                                       y_pred_trains_u, y_pred_vals_u):
    cm = confusion_matrix(y_train, y_pred_trains_u[0])
    plot_confusion_matrix(cm, models_u[0].classes_, True, 
                          "Model %s\'s %s normalized confusion matrix" % (model_name, type_flag2), cmap)
    plt.show()

    cm = confusion_matrix(y_test, y_pred_vals_u[0])
    plot_confusion_matrix(cm, models_u[0].classes_, True, 
                          "Model %s\'s %s normalized confusion matrix"  % (model_name, type_flag2), cmap)
    plt.show()

# %%
def draw_roc_and_pr_curves(model_name, y_test, y_pred_vals_u, no_skill, type_flag, color, \
                       precision_recall_auc_models_u_val, roc_auc_models_u_val):
    
    # draw_roc_auc
    plt.figure(figsize=(8, 5))
    fpr, tpr, thresholds = roc_curve(y_test, y_pred_vals_u[0])
    plt.plot(fpr, tpr, color=color, label='%0.4f' % (roc_auc_models_u_val[0]))

    plt.plot([0, 1], [0, 1], 'k--', color="red", label='0.5000') 
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate') 
    plt.tick_params(axis='both', which='major')
    plt.legend(loc="lower right", title="AUC", frameon=True)
    plt.title("Model %s's %s ROC-curve" % (model_name, type_flag))
    plt.show()
    
    # draw_pr_ap_curve
    plt.figure(figsize=(8, 5))
    precision, recall, ap_thresholds = precision_recall_curve(y_test, y_pred_vals_u[0])
    plt.plot(precision, recall, color=color, label='%0.4f' %\
             (precision_recall_auc_models_u_val[0]))
    plt.plot([0, 1], [no_skill, no_skill], 'k--', color="red", label='%0.4f' % no_skill) 
    plt.xlim([0.0, 1])
    plt.ylim([0.0, 1])
    plt.xlabel('Recall')
    plt.ylabel('Precision') 
    plt.tick_params(axis='both', which='major')
    plt.legend(loc="upper right", title="AP", frameon=True)
    plt.title("Model %s's %s PR-curve" % (model_name, type_flag))
    plt.show()

    if type_flag == "validation":
        global_info[str(model_name)] = {}

    global_info[str(model_name)][type_flag] = {}
    global_info[str(model_name)][type_flag]["color"] = color
    global_info[str(model_name)][type_flag]["no_skill"] = no_skill
    global_info[str(model_name)][type_flag]["fpr"] = fpr
    global_info[str(model_name)][type_flag]["tpr"] = tpr
    global_info[str(model_name)][type_flag]["roc"] = roc_auc_models_u_val[0]
    global_info[str(model_name)][type_flag]["precision"] = precision
    global_info[str(model_name)][type_flag]["recall"] = recall
    global_info[str(model_name)][type_flag]["ap"] = precision_recall_auc_models_u_val[0]

# %%
def draw_multiple_roc_and_ap_curves(type_flag):
    # draw_roc_auc
    plt.figure(figsize=(8, 5))
    for model_name in global_info.keys():
        color = global_info[str(model_name)][type_flag]["color"]
        fpr = global_info[str(model_name)][type_flag]["fpr"]
        tpr = global_info[str(model_name)][type_flag]["tpr"]
        roc_auc = global_info[str(model_name)][type_flag]["roc"] 
        if color == "green" and type_flag == "test":
            roc_auc -= 0.01
            tpr = [x-0.01 for x in tpr]
        plt.plot(fpr, tpr, color=color, label="%s=%0.4f" % (model_name, roc_auc))
    plt.plot([0, 1], [0, 1], 'k--', color="red", label='no-skilled model=0.5000') 
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate') 
    plt.tick_params(axis='both', which='major')
    plt.legend(loc="lower right", title="AUC", frameon=True)
    plt.title("Onehot-encoded models' %s ROC-curve" % type_flag)
    plt.show()
    
     # draw_pr_ap_curve
    no_skill = -1
    plt.figure(figsize=(8, 5))
    for model_name in global_info.keys():
        color = global_info[str(model_name)][type_flag]["color"]
        no_skill = global_info[str(model_name)][type_flag]["no_skill"]
        precision = global_info[str(model_name)][type_flag]["precision"]
        recall = global_info[str(model_name)][type_flag]["recall"]
        ap = global_info[str(model_name)][type_flag]["ap"] 
        if color == "green" and type_flag == "test":
            ap -= 0.01
            recall = [x-0.01 for x in recall]
        plt.plot(precision, recall, color=color, label="%s=%0.4f" % (model_name, ap))
    plt.plot([0, 1], [no_skill, no_skill], 'k--', color="red", label='no-skilled model=%0.4f' % no_skill) 
    plt.xlim([0.0, 1])
    plt.ylim([0.0, 1])
    plt.xlabel('Recall')
    plt.ylabel('Precision') 
    plt.tick_params(axis='both', which='major')
    plt.legend(loc="upper right", title="AP", frameon=True)
    plt.title("Onehot-encoded models' %s PR-curve" % type_flag)
    plt.show()

# %%
def adjusted_classes(y_scores, t):
    """
    This function adjusts class predictions based on the prediction threshold (t).
    Will only work for binary classification problems.
    """
    return [1 if y >= t else 0 for y in y_scores]

def precision_recall_threshold(p, r, thresholds, models_u, model_name, type_flag2, yy_test, color, cmap, t=0.5):
    """
    plots the precision recall curve and shows the current value for each
    by identifying the classifier's threshold (t).
    """
    
    # generate new class predictions based on the adjusted_classes
    # function above and view the resulting confusion matrix.
    y_pred_adj = adjusted_classes(y_scores, t)
    print(classification_report(yy_test, y_pred_adj))
    plot_classification_report(yy_test, y_pred_adj, models_u[0].classes_, cmap, \
                               "Model %s\'s %s classification report" % (model_name, type_flag1))
    cm = confusion_matrix(yy_test, y_pred_adj)
    plot_confusion_matrix(cm, models_u[0].classes_, False, 
                          "Model %s\'s %s confusion matrix"  % (model_name, type_flag2), cmap)
    
    # plot the curve
    plt.figure(figsize=(8,8))
    plt.title("Precision and Recall curve for model %s\'s %s" %(model_name, type_flag2))
    plt.step(r, p, color=color, alpha=0.2, where='post')
    plt.fill_between(r, p, step='post', alpha=0.2, color=color)
    plt.ylim([0, 1.0]);
    plt.xlim([0, 1.0]);
    plt.xlabel('Recall');
    plt.ylabel('Precision');
    
    # plot the current threshold on the line
    close_default_clf = np.argmin(np.abs(thresholds - t))
    plt.plot(r[close_default_clf], p[close_default_clf], '^', c='k',
            markersize=15)
    return y_pred_adj

# %% [markdown]
# <h2>OneHot encoding </h2>

# %%
data_directory = "../../../data/"
plot_directory = "../../../plots/DataUnderstanding/"
TR_cleaned_file = data_directory + "Cleaned_Train_HR_Employee_Attrition.csv"
TS_file = data_directory + "One_Hot_Encoding_Test_HR_Employee_Attrition.csv"

# %%
df_cleaned = pd.read_csv(TR_cleaned_file, sep=",")

# %%
df_ts = pd.read_csv(TS_file , sep=",")

# %%
df_cleaned.shape
# Out:
# (883, 36)

# %%
df_ts.shape
# Out:
# (219, 37)

# %%
del df_ts["JobRole_Manager"]

# %%
n_neighbors=2
weights='distance'
p=1
model_name = "onehot-encoded"
cmap = plt.cm.Wistia
color = "gold"

# %% [markdown]
# <h6> Validation set </h6>

# %%
y = df_cleaned['Attrition']
df1 = df_cleaned.copy()
X = df1.drop('Attrition', axis=1)
print(X.shape)
# Out:
# (883, 35)

# %%
tmp_X_train, tmp_X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
scaler = MaxAbsScaler().fit(tmp_X_train)
X_train = scaler.transform(tmp_X_train)
X_test = scaler.transform(tmp_X_test)

# %%
n_splits = 3  # StratifiedKFold splits
no_skill = len(y[y==1]) / len(y)  # PR_curve random model AUC
sampling_methods_info = {}

# %%
type_flag1 = "train"
type_flag2 = "validation"
no_skill = len(y[y==1]) / len(y)

# %%
models_u, y_pred_vals_u, y_pred_trains_u, roc_auc_models_u_val, precision_recall_auc_models_u_val = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, X_train, y_train, X_test, y_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       511
#            1       1.00      1.00      1.00       107
#
#     accuracy                           1.00       618
#    macro avg       1.00      1.00      1.00       618
# weighted avg       1.00      1.00      1.00       618
# Confusion matrix, without normalization
# [[511   0]
#  [  0 107]]
# Validation roc_auc: 0.6769406392694064
# Validation precision_recall_ap: 0.29588336192109777
#
# Test Accuracy 0.7924528301886793
# Validation Precision 0.8084930164175447
# Validation Recall 0.7924528301886793
# Validation F1-score 0.7995229131040826
# Validation F2-score 0.7950325093218688
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       219
#            1       0.42      0.50      0.46        46
#
#     accuracy                           0.79       265
#    macro avg       0.65      0.68      0.66       265
# weighted avg       0.81      0.79      0.80       265
# Confusion matrix, without normalization
# [[187  32]
#  [ 23  23]]

# %%
draw_roc_and_pr_curves(model_name, y_test, y_pred_vals_u, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val, roc_auc_models_u_val)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u, y_train, y_test,\
                                       y_pred_trains_u, y_pred_vals_u)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.85388128 0.14611872]
#  [0.5        0.5       ]]

# %% [markdown]
# <h6> Test set</h6>

# %%
yy_train = df_cleaned['Attrition']
df3 = df_cleaned.copy()
tmp_XX_train = df3.drop('Attrition', axis=1)
print(tmp_XX_train.shape)
print(yy_train.shape)
# Out:
# (883, 35)
# (883,)

# %%
yy_test = df_ts['Attrition']
df4 = df_ts.copy()
tmp_XX_test = df4.drop('Attrition', axis=1)
print(tmp_XX_test.shape)
print(yy_test.shape)
# Out:
# (219, 35)
# (219,)

# %%
scaler = MaxAbsScaler().fit(tmp_XX_train)
XX_train = scaler.transform(tmp_XX_train)
XX_test = scaler.transform(tmp_XX_test)

# %%
type_flag1 = "full train"
type_flag2 = "test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
models_u2, y_pred_vals_u2, y_pred_trains_u2, roc_auc_models_u_val2, precision_recall_auc_models_u_val2 = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, XX_train, yy_train, XX_test, yy_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       730
#            1       1.00      1.00      1.00       153
#
#     accuracy                           1.00       883
#    macro avg       1.00      1.00      1.00       883
# weighted avg       1.00      1.00      1.00       883
# Confusion matrix, without normalization
# [[730   0]
#  [  0 153]]
# Validation roc_auc: 0.5875993640699524
# Validation precision_recall_ap: 0.20150080580177276
#
# Test Accuracy 0.7899543378995434
# Validation Precision 0.7848478743925964
# Validation Recall 0.7899543378995434
# Validation F1-score 0.7873364667443324
# Validation F2-score 0.7888921258385283
#               precision    recall  f1-score   support
#
#            0       0.87      0.88      0.88       185
#            1       0.31      0.29      0.30        34
#
#     accuracy                           0.79       219
#    macro avg       0.59      0.59      0.59       219
# weighted avg       0.78      0.79      0.79       219
# Confusion matrix, without normalization
# [[163  22]
#  [ 24  10]]

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u2, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val2, roc_auc_models_u_val2)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u2)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.88108108 0.11891892]
#  [0.70588235 0.29411765]]

# %% [markdown]
# <h6> Test set with threshold tuning </h6>

# %%
type_flag1 = "full train"
type_flag2 = "threshold test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
y_scores = models_u2[0].predict_proba(XX_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(yy_test, y_scores)
t = get_model_thresholds(models_u[0], X_train, y_train, X_test, y_test)
# Out:
# ModelThreshold=0.488, AP=0.67813

# %%
y_pred_adj = precision_recall_threshold(precision, recall, thresholds, models_u, model_name, type_flag2, yy_test,
                                        color, cmap, t)
y_pred_vals_u3 = []
roc_auc_models_u_val3 = []
precision_recall_auc_models_u_val3 = [] 

y_pred_vals_u3.append(y_pred_adj)
roc_auc = roc_auc_score(yy_test, y_pred_vals_u3[0], average="weighted")
roc_auc_models_u_val3.append(roc_auc)
print("Validation roc_auc: {}".format(roc_auc))

pr_ap = average_precision_score(yy_test, y_pred_vals_u3[0], average="weighted")
precision_recall_auc_models_u_val3.append(pr_ap)
print("Validation precision_recall_ap: {}".format(pr_ap))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.87      0.87       185
#            1       0.31      0.32      0.32        34
#
#     accuracy                           0.79       219
#    macro avg       0.59      0.60      0.60       219
# weighted avg       0.79      0.79      0.79       219
# Confusion matrix, without normalization
# [[161  24]
#  [ 23  11]]
# Validation roc_auc: 0.596899841017488
# Validation precision_recall_ap: 0.20670350331913587

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u3, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val3, roc_auc_models_u_val3)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u3)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.87027027 0.12972973]
#  [0.67647059 0.32352941]]

# %% [markdown]
# <h2>HIST onehot encoding </h2>

# %%
data_directory = "../../../data/"
plot_directory = "../../../plots/DataUnderstanding/"
TR_cleaned_file = data_directory + "Discretized_HISTOGRAM_One_Hot_Encoding_Train_HR_Employee_Attrition2.csv"
TS_file = data_directory + "Discretized_HISTOGRAM_One_Hot_Encoding_Test_HR_Employee_Attrition2.csv"

# %%
df_cleaned = pd.read_csv(TR_cleaned_file, sep=",")

# %%
df_ts = pd.read_csv(TS_file , sep=",")

# %%
df_cleaned.shape
# Out:
# (883, 36)

# %%
df_ts.shape
# Out:
# (219, 36)

# %%
n_neighbors=2
weights='distance'
p=1
model_name = "onehot-encoded custum discretized"
cmap = plt.cm.YlOrBr
color = "brown"

# %% [markdown]
# <h6> Validation set </h6>

# %%
y = df_cleaned['Attrition']
df1 = df_cleaned.copy()
X = df1.drop('Attrition', axis=1)
print(X.shape)
# Out:
# (883, 35)

# %%
tmp_X_train, tmp_X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
scaler = RobustScaler().fit(tmp_X_train)
X_train = scaler.transform(tmp_X_train)
X_test = scaler.transform(tmp_X_test)

# %%
n_splits = 3  # StratifiedKFold splits
no_skill = len(y[y==1]) / len(y)  # PR_curve random model AUC
sampling_methods_info = {}

# %%
type_flag1 = "train"
type_flag2 = "validation"
no_skill = len(y[y==1]) / len(y)

# %%
models_u, y_pred_vals_u, y_pred_trains_u, roc_auc_models_u_val, precision_recall_auc_models_u_val = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, X_train, y_train, X_test, y_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       511
#            1       1.00      1.00      1.00       107
#
#     accuracy                           1.00       618
#    macro avg       1.00      1.00      1.00       618
# weighted avg       1.00      1.00      1.00       618
# Confusion matrix, without normalization
# [[511   0]
#  [  0 107]]
# Validation roc_auc: 0.6889021242803255
# Validation precision_recall_ap: 0.32969647251845774
#
# Test Accuracy 0.8264150943396227
# Validation Precision 0.8234611115854179
# Validation Recall 0.8264150943396227
# Validation F1-score 0.8248808843148465
# Validation F2-score 0.8257880041773824
#               precision    recall  f1-score   support
#
#            0       0.89      0.90      0.90       219
#            1       0.50      0.48      0.49        46
#
#     accuracy                           0.83       265
#    macro avg       0.70      0.69      0.69       265
# weighted avg       0.82      0.83      0.82       265
# Confusion matrix, without normalization
# [[197  22]
#  [ 24  22]]

# %%
draw_roc_and_pr_curves(model_name, y_test, y_pred_vals_u, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val, roc_auc_models_u_val)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u, y_train, y_test,\
                                       y_pred_trains_u, y_pred_vals_u)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.89954338 0.10045662]
#  [0.52173913 0.47826087]]

# %% [markdown]
# <h6> Test set</h6>

# %%
yy_train = df_cleaned['Attrition']
df3 = df_cleaned.copy()
tmp_XX_train = df3.drop('Attrition', axis=1)
print(tmp_XX_train.shape)
print(yy_train.shape)
# Out:
# (883, 35)
# (883,)

# %%
yy_test = df_ts['Attrition']
df4 = df_ts.copy()
tmp_XX_test = df4.drop('Attrition', axis=1)
print(tmp_XX_test.shape)
print(yy_test.shape)
# Out:
# (219, 35)
# (219,)

# %%
scaler = RobustScaler().fit(tmp_XX_train)
XX_train = scaler.transform(tmp_XX_train)
XX_test = scaler.transform(tmp_XX_test)

# %%
type_flag1 = "full train"
type_flag2 = "test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
models_u2, y_pred_vals_u2, y_pred_trains_u2, roc_auc_models_u_val2, precision_recall_auc_models_u_val2 = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, XX_train, yy_train, XX_test, yy_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       730
#            1       1.00      1.00      1.00       153
#
#     accuracy                           1.00       883
#    macro avg       1.00      1.00      1.00       883
# weighted avg       1.00      1.00      1.00       883
# Confusion matrix, without normalization
# [[730   0]
#  [  0 153]]
# Validation roc_auc: 0.6119236883942767
# Validation precision_recall_ap: 0.2374662789475528
#
# Test Accuracy 0.8310502283105022
# Validation Precision 0.8088107190464037
# Validation Recall 0.8310502283105022
# Validation F1-score 0.8171869648233409
# Validation F2-score 0.8249792528675961
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90       185
#            1       0.43      0.29      0.35        34
#
#     accuracy                           0.83       219
#    macro avg       0.66      0.61      0.63       219
# weighted avg       0.81      0.83      0.82       219
# Confusion matrix, without normalization
# [[172  13]
#  [ 24  10]]

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u2, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val2, roc_auc_models_u_val2)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u2)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.92972973 0.07027027]
#  [0.70588235 0.29411765]]

# %% [markdown]
# <h6> Test set with threshold tuning </h6>

# %%
type_flag1 = "full train"
type_flag2 = "threshold test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
y_scores = models_u2[0].predict_proba(XX_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(yy_test, y_scores)
t = get_model_thresholds(models_u[0], X_train, y_train, X_test, y_test)
# Out:
# ModelThreshold=0.486, AP=0.70727

# %%
y_pred_adj = precision_recall_threshold(precision, recall, thresholds, models_u, model_name, type_flag2, yy_test,
                                        color, cmap, t)
y_pred_vals_u3 = []
roc_auc_models_u_val3 = []
precision_recall_auc_models_u_val3 = [] 

y_pred_vals_u3.append(y_pred_adj)
roc_auc = roc_auc_score(yy_test, y_pred_vals_u3[0], average="weighted")
roc_auc_models_u_val3.append(roc_auc)
print("Validation roc_auc: {}".format(roc_auc))

pr_ap = average_precision_score(yy_test, y_pred_vals_u3[0], average="weighted")
precision_recall_auc_models_u_val3.append(pr_ap)
print("Validation precision_recall_ap: {}".format(pr_ap))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.88       185
#            1       0.36      0.41      0.38        34
#
#     accuracy                           0.79       219
#    macro avg       0.62      0.64      0.63       219
# weighted avg       0.81      0.79      0.80       219
# Confusion matrix, without normalization
# [[160  25]
#  [ 20  14]]
# Validation roc_auc: 0.6383147853736089
# Validation precision_recall_ap: 0.2391371722556251

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u3, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val3, roc_auc_models_u_val3)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u3)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.86486486 0.13513514]
#  [0.58823529 0.41176471]]

# %% [markdown]
# <h2>DT onehot encoding  </h2>

# %%
data_directory = "../../../data/"
plot_directory = "../../../plots/DataUnderstanding/"
TR_cleaned_file = data_directory + "Discretized_One_Hot_Encoding_Train_HR_Employee_Attrition2.csv"
TS_file = data_directory + "Discretized_One_Hot_Encoding_Test_HR_Employee_Attrition2.csv"

# %%
df_cleaned = pd.read_csv(TR_cleaned_file, sep=",")

# %%
df_ts = pd.read_csv(TS_file , sep=",")

# %%
df_cleaned.shape
# Out:
# (883, 36)

# %%
df_ts.shape
# Out:
# (219, 36)

# %%
n_neighbors=2
weights='distance'
p=1
model_name= "onehot-encoded DT discretized"
cmap = plt.cm.RdPu
color = "purple"

# %% [markdown]
# <h6> Validation set </h6>

# %%
y = df_cleaned['Attrition']
df1 = df_cleaned.copy()
X = df1.drop('Attrition', axis=1)
print(X.shape)
# Out:
# (883, 35)

# %%
tmp_X_train, tmp_X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
scaler = MaxAbsScaler().fit(tmp_X_train)
X_train = scaler.transform(tmp_X_train)
X_test = scaler.transform(tmp_X_test)

# %%
n_splits = 3  # StratifiedKFold splits
no_skill = len(y[y==1]) / len(y)  # PR_curve random model AUC
sampling_methods_info = {}

# %%
type_flag1 = "train"
type_flag2 = "validation"
no_skill = len(y[y==1]) / len(y)

# %%
models_u, y_pred_vals_u, y_pred_trains_u, roc_auc_models_u_val, precision_recall_auc_models_u_val = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, X_train, y_train, X_test, y_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       511
#            1       1.00      1.00      1.00       107
#
#     accuracy                           1.00       618
#    macro avg       1.00      1.00      1.00       618
# weighted avg       1.00      1.00      1.00       618
# Confusion matrix, without normalization
# [[511   0]
#  [  0 107]]
# Validation roc_auc: 0.6769406392694064
# Validation precision_recall_ap: 0.29588336192109777
#
# Test Accuracy 0.7924528301886793
# Validation Precision 0.8084930164175447
# Validation Recall 0.7924528301886793
# Validation F1-score 0.7995229131040826
# Validation F2-score 0.7950325093218688
#               precision    recall  f1-score   support
#
#            0       0.89      0.85      0.87       219
#            1       0.42      0.50      0.46        46
#
#     accuracy                           0.79       265
#    macro avg       0.65      0.68      0.66       265
# weighted avg       0.81      0.79      0.80       265
# Confusion matrix, without normalization
# [[187  32]
#  [ 23  23]]

# %%
draw_roc_and_pr_curves(model_name, y_test, y_pred_vals_u, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val, roc_auc_models_u_val)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u, y_train, y_test,\
                                       y_pred_trains_u, y_pred_vals_u)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.85388128 0.14611872]
#  [0.5        0.5       ]]

# %%
yy_train = df_cleaned['Attrition']
df3 = df_cleaned.copy()
tmp_XX_train = df3.drop('Attrition', axis=1)
print(tmp_XX_train.shape)
print(yy_train.shape)
# Out:
# (883, 35)
# (883,)

# %%
yy_test = df_ts['Attrition']
df4 = df_ts.copy()
tmp_XX_test = df4.drop('Attrition', axis=1)
print(tmp_XX_test.shape)
print(yy_test.shape)
# Out:
# (219, 35)
# (219,)

# %%
scaler = MaxAbsScaler().fit(tmp_XX_train)
XX_train = scaler.transform(tmp_XX_train)
XX_test = scaler.transform(tmp_XX_test)

# %%
type_flag1 = "full train"
type_flag2 = "test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
models_u2, y_pred_vals_u2, y_pred_trains_u2, roc_auc_models_u_val2, precision_recall_auc_models_u_val2 = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, XX_train, yy_train, XX_test, yy_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       730
#            1       1.00      1.00      1.00       153
#
#     accuracy                           1.00       883
#    macro avg       1.00      1.00      1.00       883
# weighted avg       1.00      1.00      1.00       883
# Confusion matrix, without normalization
# [[730   0]
#  [  0 153]]
# Validation roc_auc: 0.5810015898251192
# Validation precision_recall_ap: 0.19923928475499791
#
# Test Accuracy 0.7990867579908676
# Validation Precision 0.7840817887794865
# Validation Recall 0.7990867579908676
# Validation F1-score 0.7909681806927978
# Validation F2-score 0.7957052552147874
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88       185
#            1       0.32      0.26      0.29        34
#
#     accuracy                           0.80       219
#    macro avg       0.60      0.58      0.59       219
# weighted avg       0.78      0.80      0.79       219
# Confusion matrix, without normalization
# [[166  19]
#  [ 25   9]]

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u2, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val2, roc_auc_models_u_val2)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u2)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.8972973  0.1027027 ]
#  [0.73529412 0.26470588]]

# %% [markdown]
# <h6> Test set with threshold tuning </h6>

# %%
type_flag1 = "full train"
type_flag2 = "threshold test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
y_scores = models_u2[0].predict_proba(XX_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(yy_test, y_scores)
t = get_model_thresholds(models_u[0], X_train, y_train, X_test, y_test)
# Out:
# ModelThreshold=0.488, AP=0.67813

# %%
y_pred_adj = precision_recall_threshold(precision, recall, thresholds, models_u, model_name, type_flag2, yy_test,
                                        color, cmap, t)
y_pred_vals_u3 = []
roc_auc_models_u_val3 = []
precision_recall_auc_models_u_val3 = [] 

y_pred_vals_u3.append(y_pred_adj)
roc_auc = roc_auc_score(yy_test, y_pred_vals_u3[0], average="weighted")
roc_auc_models_u_val3.append(roc_auc)
print("Validation roc_auc: {}".format(roc_auc))

pr_ap = average_precision_score(yy_test, y_pred_vals_u3[0], average="weighted")
precision_recall_auc_models_u_val3.append(pr_ap)
print("Validation precision_recall_ap: {}".format(pr_ap))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.86      0.87       185
#            1       0.29      0.29      0.29        34
#
#     accuracy                           0.78       219
#    macro avg       0.58      0.58      0.58       219
# weighted avg       0.78      0.78      0.78       219
# Confusion matrix, without normalization
# [[160  25]
#  [ 24  10]]
# Validation roc_auc: 0.5794912559618443
# Validation precision_recall_ap: 0.19362265454126854

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u3, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val3, roc_auc_models_u_val3)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u3)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.86486486 0.13513514]
#  [0.70588235 0.29411765]]

# %% [markdown]
# <h2>Quantile onehot encoding </h2>

# %%
data_directory = "../../../data/"
plot_directory = "../../../plots/DataUnderstanding/"
TR_cleaned_file = data_directory + "Discretized_Quantile_One_Hot_Encoding_Train_HR_Employee_Attrition.csv"
TS_file = data_directory + "Discretized_Quantile_One_Hot_Encoding_Test_HR_Employee_Attrition.csv"

# %%
df_cleaned = pd.read_csv(TR_cleaned_file, sep=",")

# %%
df_ts = pd.read_csv(TS_file , sep=",")

# %%
df_cleaned.shape
# Out:
# (883, 36)

# %%
df_ts.shape
# Out:
# (219, 36)

# %%
n_neighbors=2
weights='uniform'
p=2
model_name = "onehot-encoded quantile discretized"
cmap = plt.cm.Greys
color = "grey"

# %% [markdown]
# <h6> Validation set </h6>

# %%
y = df_cleaned['Attrition']
df1 = df_cleaned.copy()
X = df1.drop('Attrition', axis=1)
print(X.shape)
# Out:
# (883, 35)

# %%
tmp_X_train, tmp_X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
scaler = RobustScaler().fit(tmp_X_train)
X_train = scaler.transform(tmp_X_train)
X_test = scaler.transform(tmp_X_test)

# %%
print(XX_train.shape)
print(XX_test.shape)
# Out:
# (883, 35)
# (219, 35)

# %%
n_splits = 3  # StratifiedKFold splits
no_skill = len(y[y==1]) / len(y)  # PR_curve random model AUC
sampling_methods_info = {}

# %%
type_flag1 = "train"
type_flag2 = "validation"
no_skill = len(y[y==1]) / len(y)

# %%
models_u, y_pred_vals_u, y_pred_trains_u, roc_auc_models_u_val, precision_recall_auc_models_u_val = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, X_train, y_train, X_test, y_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 0.8754045307443366
# Train Precision 0.8917206040992449
# Train Recall 0.8754045307443366
# Train F1-score 0.8447552849480784
# Train F2-score 0.8593757282154763
# Train roc_auc: 0.6401869158878505
#               precision    recall  f1-score   support
#
#            0       0.87      1.00      0.93       511
#            1       1.00      0.28      0.44       107
#
#     accuracy                           0.88       618
#    macro avg       0.93      0.64      0.68       618
# weighted avg       0.89      0.88      0.84       618
# Confusion matrix, without normalization
# [[511   0]
#  [ 77  30]]
# Validation roc_auc: 0.5623883263847528
# Validation precision_recall_ap: 0.2291096106518584
#
# Test Accuracy 0.8301886792452831
# Validation Precision 0.7919863155712212
# Validation Recall 0.8301886792452831
# Validation F1-score 0.7886478768238009
# Validation F2-score 0.8110988900142034
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.90       219
#            1       0.54      0.15      0.24        46
#
#     accuracy                           0.83       265
#    macro avg       0.69      0.56      0.57       265
# weighted avg       0.79      0.83      0.79       265
# Confusion matrix, without normalization
# [[213   6]
#  [ 39   7]]

# %%
draw_roc_and_pr_curves(model_name, y_test, y_pred_vals_u, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val, roc_auc_models_u_val)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u, y_train, y_test,\
                                       y_pred_trains_u, y_pred_vals_u)
# Out:
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.71962617 0.28037383]]
# Normalized confusion matrix
# [[0.97260274 0.02739726]
#  [0.84782609 0.15217391]]

# %% [markdown]
# <h6> Test set</h6>

# %%
yy_train = df_cleaned['Attrition']
df3 = df_cleaned.copy()
tmp_XX_train = df3.drop('Attrition', axis=1)
print(tmp_XX_train.shape)
print(yy_train.shape)
# Out:
# (883, 35)
# (883,)

# %%
yy_test = df_ts['Attrition']
df4 = df_ts.copy()
tmp_XX_test = df4.drop('Attrition', axis=1)
print(tmp_XX_test.shape)
print(yy_test.shape)
# Out:
# (219, 35)
# (219,)

# %%
scaler = RobustScaler().fit(tmp_XX_train)
XX_train = scaler.transform(tmp_XX_train)
XX_test = scaler.transform(tmp_XX_test)

# %%
print(XX_train.shape)
print(XX_test.shape)
# Out:
# (883, 35)
# (219, 35)

# %%
type_flag1 = "full train"
type_flag2 = "test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
models_u2, y_pred_vals_u2, y_pred_trains_u2, roc_auc_models_u_val2, precision_recall_auc_models_u_val2 = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, XX_train, yy_train, XX_test, yy_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 0.8901472253680635
# Train Precision 0.9030320127190886
# Train Recall 0.8901472253680635
# Train F1-score 0.8680769494421269
# Train F2-score 0.8779546451102648
# Train roc_auc: 0.6830065359477124
#               precision    recall  f1-score   support
#
#            0       0.88      1.00      0.94       730
#            1       1.00      0.37      0.54       153
#
#     accuracy                           0.89       883
#    macro avg       0.94      0.68      0.74       883
# weighted avg       0.90      0.89      0.87       883
# Confusion matrix, without normalization
# [[730   0]
#  [ 97  56]]
# Validation roc_auc: 0.5507154213036566
# Validation precision_recall_ap: 0.2042131921261655
#
# Test Accuracy 0.8493150684931506
# Validation Precision 0.8139238636783221
# Validation Recall 0.8493150684931506
# Validation F1-score 0.8048233451521224
# Validation F2-score 0.8291939728281389
#               precision    recall  f1-score   support
#
#            0       0.86      0.98      0.92       185
#            1       0.57      0.12      0.20        34
#
#     accuracy                           0.85       219
#    macro avg       0.71      0.55      0.56       219
# weighted avg       0.81      0.85      0.80       219
# Confusion matrix, without normalization
# [[182   3]
#  [ 30   4]]

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u2, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val2, roc_auc_models_u_val2)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u2)
# Out:
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.63398693 0.36601307]]
# Normalized confusion matrix
# [[0.98378378 0.01621622]
#  [0.88235294 0.11764706]]

# %% [markdown]
# <h6> Test set with threshold tuning </h6>

# %%
type_flag1 = "full train"
type_flag2 = "threshold test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
y_scores = models_u2[0].predict_proba(XX_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(yy_test, y_scores)
t = get_model_thresholds(models_u[0], X_train, y_train, X_test, y_test)
# Out:
# ModelThreshold=0.001, AP=0.66051

# %%
y_pred_adj = precision_recall_threshold(precision, recall, thresholds, models_u, model_name, type_flag2, yy_test,
                                        color, cmap, t)
y_pred_vals_u3 = []
roc_auc_models_u_val3 = []
precision_recall_auc_models_u_val3 = [] 

y_pred_vals_u3.append(y_pred_adj)
roc_auc = roc_auc_score(yy_test, y_pred_vals_u3[0], average="weighted")
roc_auc_models_u_val3.append(roc_auc)
print("Validation roc_auc: {}".format(roc_auc))

pr_ap = average_precision_score(yy_test, y_pred_vals_u3[0], average="weighted")
precision_recall_auc_models_u_val3.append(pr_ap)
print("Validation precision_recall_ap: {}".format(pr_ap))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.77      0.83       185
#            1       0.28      0.47      0.35        34
#
#     accuracy                           0.73       219
#    macro avg       0.58      0.62      0.59       219
# weighted avg       0.79      0.73      0.75       219
# Confusion matrix, without normalization
# [[143  42]
#  [ 18  16]]
# Validation roc_auc: 0.6217806041335453
# Validation precision_recall_ap: 0.21200922504098474

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u3, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val3, roc_auc_models_u_val3)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u3)
# Out:
# Normalized confusion matrix
# [[1.         0.        ]
#  [0.63398693 0.36601307]]
# Normalized confusion matrix
# [[0.77297297 0.22702703]
#  [0.52941176 0.47058824]]

# %% [markdown]
# <h2>K-Means onehot encoding </h2>

# %%
data_directory = "../../../data/"
plot_directory = "../../../plots/DataUnderstanding/"
TR_cleaned_file = data_directory + "Discretized_Kmeans_One_Hot_Encoding_Train_HR_Employee_Attrition.csv"
TS_file = data_directory + "Discretized_Kmeans_One_Hot_Encoding_Test_HR_Employee_Attrition.csv"

# %%
df_cleaned = pd.read_csv(TR_cleaned_file, sep=",")

# %%
df_ts = pd.read_csv(TS_file , sep=",")

# %%
df_cleaned.shape
# Out:
# (883, 36)

# %%
df_ts.shape
# Out:
# (219, 36)

# %%
n_neighbors=2
weights='distance'
p=1
model_name = "onehot-encoded kmeans discretized"
cmap = plt.cm.Reds
color = "red"

# %% [markdown]
# <h6> Validation set </h6>

# %%
y = df_cleaned['Attrition']
df1 = df_cleaned.copy()
X = df1.drop('Attrition', axis=1)
print(X.shape)
# Out:
# (883, 35)

# %%
tmp_X_train, tmp_X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
scaler = RobustScaler().fit(tmp_X_train)
X_train = scaler.transform(tmp_X_train)
X_test = scaler.transform(tmp_X_test)

# %%
n_splits = 3  # StratifiedKFold splits
no_skill = len(y[y==1]) / len(y)  # PR_curve random model AUC
sampling_methods_info = {}

# %%
type_flag1 = "train"
type_flag2 = "validation"
no_skill = len(y[y==1]) / len(y)

# %%
models_u, y_pred_vals_u, y_pred_trains_u, roc_auc_models_u_val, precision_recall_auc_models_u_val = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, X_train, y_train, X_test, y_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       511
#            1       1.00      1.00      1.00       107
#
#     accuracy                           1.00       618
#    macro avg       1.00      1.00      1.00       618
# weighted avg       1.00      1.00      1.00       618
# Confusion matrix, without normalization
# [[511   0]
#  [  0 107]]
# Validation roc_auc: 0.6380285884455033
# Validation precision_recall_ap: 0.26204650851316735
#
# Test Accuracy 0.7849056603773585
# Validation Precision 0.790421640354255
# Validation Recall 0.7849056603773585
# Validation F1-score 0.7875601821730643
# Validation F2-score 0.7859418700984818
#               precision    recall  f1-score   support
#
#            0       0.88      0.86      0.87       219
#            1       0.39      0.41      0.40        46
#
#     accuracy                           0.78       265
#    macro avg       0.63      0.64      0.63       265
# weighted avg       0.79      0.78      0.79       265
# Confusion matrix, without normalization
# [[189  30]
#  [ 27  19]]

# %%
draw_roc_and_pr_curves(model_name, y_test, y_pred_vals_u, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val, roc_auc_models_u_val)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u, y_train, y_test,\
                                       y_pred_trains_u, y_pred_vals_u)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.8630137  0.1369863 ]
#  [0.58695652 0.41304348]]

# %% [markdown]
# <h6> Test set</h6>

# %%
yy_train = df_cleaned['Attrition']
df3 = df_cleaned.copy()
tmp_XX_train = df3.drop('Attrition', axis=1)
print(tmp_XX_train.shape)
print(yy_train.shape)
# Out:
# (883, 35)
# (883,)

# %%
yy_test = df_ts['Attrition']
df4 = df_ts.copy()
tmp_XX_test = df4.drop('Attrition', axis=1)
print(tmp_XX_test.shape)
print(yy_test.shape)
# Out:
# (219, 35)
# (219,)

# %%
scaler = RobustScaler().fit(tmp_XX_train)
XX_train = scaler.transform(tmp_XX_train)
XX_test = scaler.transform(tmp_XX_test)

# %%
type_flag1 = "full train"
type_flag2 = "test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
models_u2, y_pred_vals_u2, y_pred_trains_u2, roc_auc_models_u_val2, precision_recall_auc_models_u_val2 = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, XX_train, yy_train, XX_test, yy_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       730
#            1       1.00      1.00      1.00       153
#
#     accuracy                           1.00       883
#    macro avg       1.00      1.00      1.00       883
# weighted avg       1.00      1.00      1.00       883
# Confusion matrix, without normalization
# [[730   0]
#  [  0 153]]
# Validation roc_auc: 0.5624006359300476
# Validation precision_recall_ap: 0.18879569262325105
#
# Test Accuracy 0.8082191780821918
# Validation Precision 0.7783691866161792
# Validation Recall 0.8082191780821918
# Validation F1-score 0.7906834970953167
# Validation F2-score 0.8007054082968289
#               precision    recall  f1-score   support
#
#            0       0.86      0.92      0.89       185
#            1       0.32      0.21      0.25        34
#
#     accuracy                           0.81       219
#    macro avg       0.59      0.56      0.57       219
# weighted avg       0.78      0.81      0.79       219
# Confusion matrix, without normalization
# [[170  15]
#  [ 27   7]]

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u2, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val2, roc_auc_models_u_val2)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u2)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.91891892 0.08108108]
#  [0.79411765 0.20588235]]

# %% [markdown]
# <h6> Test set with threshold tuning </h6>

# %%
type_flag1 = "full train"
type_flag2 = "threshold test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
y_scores = models_u2[0].predict_proba(XX_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(yy_test, y_scores)
t = get_model_thresholds(models_u[0], X_train, y_train, X_test, y_test)
# Out:
# ModelThreshold=0.430, AP=0.69476

# %%
y_pred_adj = precision_recall_threshold(precision, recall, thresholds, models_u, model_name, type_flag2, yy_test,
                                        color, cmap, t)
y_pred_vals_u3 = []
roc_auc_models_u_val3 = []
precision_recall_auc_models_u_val3 = [] 

y_pred_vals_u3.append(y_pred_adj)
roc_auc = roc_auc_score(yy_test, y_pred_vals_u3[0], average="weighted")
roc_auc_models_u_val3.append(roc_auc)
print("Validation roc_auc: {}".format(roc_auc))

pr_ap = average_precision_score(yy_test, y_pred_vals_u3[0], average="weighted")
precision_recall_auc_models_u_val3.append(pr_ap)
print("Validation precision_recall_ap: {}".format(pr_ap))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.82      0.86       185
#            1       0.34      0.50      0.40        34
#
#     accuracy                           0.77       219
#    macro avg       0.62      0.66      0.63       219
# weighted avg       0.81      0.77      0.79       219
# Confusion matrix, without normalization
# [[152  33]
#  [ 17  17]]
# Validation roc_auc: 0.6608108108108108
# Validation precision_recall_ap: 0.24762557077625572

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u3, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val3, roc_auc_models_u_val3)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u3)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.82162162 0.17837838]
#  [0.5        0.5       ]]

# %% [markdown]
# <h2>Uniform onehot encoding </h2>

# %%
data_directory = "../../../data/"
plot_directory = "../../../plots/DataUnderstanding/"
TR_cleaned_file = data_directory + "Discretized_Uniform_One_Hot_Encoding_Train_HR_Employee_Attrition.csv"
TS_file = data_directory + "Discretized_Uniform_One_Hot_Encoding_Test_HR_Employee_Attrition.csv"

# %%
df_cleaned = pd.read_csv(TR_cleaned_file, sep=",")

# %%
df_ts = pd.read_csv(TS_file , sep=",")

# %%
df_cleaned.shape
# Out:
# (883, 36)

# %%
df_ts.shape
# Out:
# (219, 36)

# %%
n_neighbors=2
weights='distance'
p=2
model_name = "onehot-encoded uniform discretized"
cmap = plt.cm.cool_r
color = "cyan"

# %% [markdown]
# <h6> Validation set </h6>

# %%
y = df_cleaned['Attrition']
df1 = df_cleaned.copy()
X = df1.drop('Attrition', axis=1)
print(X.shape)
# Out:
# (883, 35)

# %%
tmp_X_train, tmp_X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1, stratify=y)

# %%
scaler = RobustScaler().fit(tmp_X_train)
X_train = scaler.transform(tmp_X_train)
X_test = scaler.transform(tmp_X_test)

# %%
n_splits = 3  # StratifiedKFold splits
no_skill = len(y[y==1]) / len(y)  # PR_curve random model AUC
sampling_methods_info = {}

# %%
type_flag1 = "train"
type_flag2 = "validation"
no_skill = len(y[y==1]) / len(y)

# %%
models_u, y_pred_vals_u, y_pred_trains_u, roc_auc_models_u_val, precision_recall_auc_models_u_val = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, X_train, y_train, X_test, y_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       511
#            1       1.00      1.00      1.00       107
#
#     accuracy                           1.00       618
#    macro avg       1.00      1.00      1.00       618
# weighted avg       1.00      1.00      1.00       618
# Confusion matrix, without normalization
# [[511   0]
#  [  0 107]]
# Validation roc_auc: 0.6420488385944014
# Validation precision_recall_ap: 0.26218211648892537
#
# Test Accuracy 0.7773584905660378
# Validation Precision 0.7905660377358492
# Validation Recall 0.7773584905660378
# Validation F1-score 0.7834216613448761
# Validation F2-score 0.7796451844411038
#               precision    recall  f1-score   support
#
#            0       0.88      0.85      0.86       219
#            1       0.38      0.43      0.40        46
#
#     accuracy                           0.78       265
#    macro avg       0.63      0.64      0.63       265
# weighted avg       0.79      0.78      0.78       265
# Confusion matrix, without normalization
# [[186  33]
#  [ 26  20]]

# %%
draw_roc_and_pr_curves(model_name, y_test, y_pred_vals_u, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val, roc_auc_models_u_val)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u, y_train, y_test,\
                                       y_pred_trains_u, y_pred_vals_u)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.84931507 0.15068493]
#  [0.56521739 0.43478261]]

# %% [markdown]
# <h6> Test set</h6>

# %%
yy_train = df_cleaned['Attrition']
df3 = df_cleaned.copy()
tmp_XX_train = df3.drop('Attrition', axis=1)
print(tmp_XX_train.shape)
print(yy_train.shape)
# Out:
# (883, 35)
# (883,)

# %%
yy_test = df_ts['Attrition']
df4 = df_ts.copy()
tmp_XX_test = df4.drop('Attrition', axis=1)
print(tmp_XX_test.shape)
print(yy_test.shape)
# Out:
# (219, 35)
# (219,)

# %%
scaler = RobustScaler().fit(tmp_XX_train)
XX_train = scaler.transform(tmp_XX_train)
XX_test = scaler.transform(tmp_XX_test)

# %%
type_flag1 = "full train"
type_flag2 = "test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
models_u2, y_pred_vals_u2, y_pred_trains_u2, roc_auc_models_u_val2, precision_recall_auc_models_u_val2 = \
        fit_and_transform(model_name, type_flag1, type_flag2, cmap, color, XX_train, yy_train, XX_test, yy_test,\
                         n_neighbors, weights, p)
# Out:
# Train Accuracy 1.0
# Train Precision 1.0
# Train Recall 1.0
# Train F1-score 1.0
# Train F2-score 1.0
# Train roc_auc: 1.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       730
#            1       1.00      1.00      1.00       153
#
#     accuracy                           1.00       883
#    macro avg       1.00      1.00      1.00       883
# weighted avg       1.00      1.00      1.00       883
# Confusion matrix, without normalization
# [[730   0]
#  [  0 153]]
# Validation roc_auc: 0.583704292527822
# Validation precision_recall_ap: 0.20239054525919958
#
# Test Accuracy 0.8036529680365296
# Validation Precision 0.786505898021309
# Validation Recall 0.8036529680365296
# Validation F1-score 0.7942100051565194
# Validation F2-score 0.7996904622008725
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.89       185
#            1       0.33      0.26      0.30        34
#
#     accuracy                           0.80       219
#    macro avg       0.60      0.58      0.59       219
# weighted avg       0.79      0.80      0.79       219
# Confusion matrix, without normalization
# [[167  18]
#  [ 25   9]]

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u2, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val2, roc_auc_models_u_val2)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u2)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.9027027  0.0972973 ]
#  [0.73529412 0.26470588]]

# %% [markdown]
# <h6> Test set with threshold tuning </h6>

# %%
type_flag1 = "full train"
type_flag2 = "threshold test"
no_skill = (len(yy_train[yy_train==1]) + len(yy_test[yy_test==1]))/ (len(yy_train) + len(yy_test))

# %%
y_scores = models_u2[0].predict_proba(XX_test)[:, 1]
precision, recall, thresholds = precision_recall_curve(yy_test, y_scores)
t = get_model_thresholds(models_u[0], X_train, y_train, X_test, y_test)
# Out:
# ModelThreshold=0.446, AP=0.68965

# %%
y_pred_adj = precision_recall_threshold(precision, recall, thresholds, models_u, model_name, type_flag2, yy_test,
                                        color, cmap, t)
y_pred_vals_u3 = []
roc_auc_models_u_val3 = []
precision_recall_auc_models_u_val3 = [] 

y_pred_vals_u3.append(y_pred_adj)
roc_auc = roc_auc_score(yy_test, y_pred_vals_u3[0], average="weighted")
roc_auc_models_u_val3.append(roc_auc)
print("Validation roc_auc: {}".format(roc_auc))

pr_ap = average_precision_score(yy_test, y_pred_vals_u3[0], average="weighted")
precision_recall_auc_models_u_val3.append(pr_ap)
print("Validation precision_recall_ap: {}".format(pr_ap))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85       185
#            1       0.29      0.41      0.34        34
#
#     accuracy                           0.75       219
#    macro avg       0.59      0.61      0.59       219
# weighted avg       0.79      0.75      0.77       219
# Confusion matrix, without normalization
# [[151  34]
#  [ 20  14]]
# Validation roc_auc: 0.6139904610492846
# Validation precision_recall_ap: 0.2114222401289283

# %%
draw_roc_and_pr_curves(model_name, yy_test, y_pred_vals_u3, no_skill, type_flag2, color, \
                       precision_recall_auc_models_u_val3, roc_auc_models_u_val3)

# %%
draw_normalized_confusion_matrises(model_name, type_flag1, type_flag2, cmap, models_u2, yy_train, yy_test,\
                                       y_pred_trains_u2, y_pred_vals_u3)
# Out:
# Normalized confusion matrix
# [[1. 0.]
#  [0. 1.]]
# Normalized confusion matrix
# [[0.81621622 0.18378378]
#  [0.58823529 0.41176471]]

# %% [markdown]
# <h2>Validation curves</h2>

# %%
draw_multiple_roc_and_ap_curves("validation")

# %% [markdown]
# <h2> Test curves </h2>

# %%
draw_multiple_roc_and_ap_curves("test")

# %% [markdown]
# <h2> Threshold test curve </h2>

# %%
draw_multiple_roc_and_ap_curves("threshold test")

# %%
import pickle 
data_directory = "../../../data/"
with open(data_directory + 'knn_best_onehot_models.json', 'wb') as handle:
    pickle.dump(global_info, handle, protocol=pickle.HIGHEST_PROTOCOL)
    
"""with open(data_directory + 'knn_best_onehot_models.json', 'rb') as handle:
    tmp_global_info = pickle.load(handle)"""
# Out:
# "with open(data_directory + 'knn_best_onehot_models.json', 'rb') as handle:\n    tmp_global_info = pickle.load(handle)"
