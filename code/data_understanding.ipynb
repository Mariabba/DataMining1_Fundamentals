# %%
# %matplotlib inline
import math
import numpy as np
import pandas as pd
from numpy import std
from numpy import mean
import scipy.stats as stats
import matplotlib.pyplot as plt

from collections import defaultdict
from scipy.stats.stats import pearsonr

# %%
data_directory = "../data/"
TR_file = data_directory + "Train_HR_Employee_Attrition.csv"
TS_file = data_directory + "Test_HR_Employee_Attrition.csv"

# %%
df = pd.read_csv(TR_file)

# %%
df.head()  # first rows sneak peek
# Out:
#     Age Attrition     BusinessTravel  DailyRate              Department  \
# 0  52.0        No      Travel_Rarely        593  Research & Development
# 1  36.0        No      Travel_Rarely       1218  Research & Development
# 2   NaN        No  Travel_Frequently        530                   Sales
# 3  33.0        No      Travel_Rarely        953  Research & Development
# 4   NaN        No      Travel_Rarely       1380  Research & Development
#
#    DistanceFromHome  Education    EducationField  EnvironmentSatisfaction  \
# 0                 9          4           Medical                        2
# 1                 1          1     Life Sciences                        2
# 2                16          3     Life Sciences                        3
# 3                 5          4  Technical Degree                        2
# 4                 9          2     Life Sciences                        3
#
#    Gender  ...  RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0    Male  ...                         3           80.0                 0
# 1    Male  ...                         3           80.0                 1
# 2     NaN  ...                         3            NaN                 1
# 3    Male  ...                         2            NaN                 0
# 4  Female  ...                         3           80.0                 0
#
#   TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# 0                20                    2.0               2             8.0
# 1                21                    3.0               3             1.0
# 2                 7                    4.0               3             1.0
# 3                12                    1.0               3             3.0
# 4                 2                    NaN               3            10.0
#
#    YearsInCurrentRole  YearsSinceLastPromotion YearsWithCurrManager
# 0                   7                        2                   13
# 1                   8                        1                    6
# 2                   5                        1                    2
# 3                   7                        0                    7
# 4                   2                        2                    1
#
# [5 rows x 33 columns]

# %%
df.info()  # columns non-null elements and type
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1176 entries, 0 to 1175
# Data columns (total 33 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1000 non-null   float64
#  1   Attrition                 1176 non-null   object
#  2   BusinessTravel            1069 non-null   object
#  3   DailyRate                 1176 non-null   int64
#  4   Department                1176 non-null   object
#  5   DistanceFromHome          1176 non-null   int64
#  6   Education                 1176 non-null   int64
#  7   EducationField            1176 non-null   object
#  8   EnvironmentSatisfaction   1176 non-null   int64
#  9   Gender                    1117 non-null   object
#  10  HourlyRate                1176 non-null   int64
#  11  JobInvolvement            1176 non-null   int64
#  12  JobLevel                  1176 non-null   int64
#  13  JobRole                   1176 non-null   object
#  14  JobSatisfaction           1176 non-null   int64
#  15  MaritalStatus             1176 non-null   object
#  16  MonthlyIncome             963 non-null    float64
#  17  MonthlyRate               1176 non-null   int64
#  18  NumCompaniesWorked        1176 non-null   int64
#  19  Over18                    804 non-null    object
#  20  OverTime                  1176 non-null   object
#  21  PercentSalaryHike         1176 non-null   int64
#  22  PerformanceRating         1038 non-null   float64
#  23  RelationshipSatisfaction  1176 non-null   int64
#  24  StandardHours             606 non-null    float64
#  25  StockOptionLevel          1176 non-null   int64
#  26  TotalWorkingYears         1176 non-null   int64
#  27  TrainingTimesLastYear     943 non-null    float64
#  28  WorkLifeBalance           1176 non-null   int64
#  29  YearsAtCompany            1116 non-null   float64
#  30  YearsInCurrentRole        1176 non-null   int64
#  31  YearsSinceLastPromotion   1176 non-null   int64
#  32  YearsWithCurrManager      1176 non-null   int64
# dtypes: float64(6), int64(18), object(9)
# memory usage: 303.3+ KB

# %% [markdown]
# <h6> Identify Rows That Contain Duplicate Data </h6>

# %%
# calculate duplicated rows
dups = df.duplicated()
# report if there are any duplicates
dups.any()

# report if there are any duplicates
# print(dups.any())
# Out:
# False

# %% [markdown]
# <h6> Idenotfy zero-variance predictors (columns which contains a single value) => no variation displayed by the predictor, so I'll remove them </h6>

# %%
# summarize the number of unique values in each column
counts = df.nunique()
zero_variance_predictors = [df.columns.values.tolist()[int(i)] for i, c in enumerate(counts) if c == 1]  
for column_name in zero_variance_predictors:
    print("zero_variance_predictors removed:", column_name, sep="\t")
    del df[column_name]  # remove zero_variance_predictors
df.shape
# Out:
# zero_variance_predictors removed:	Over18
# zero_variance_predictors removed:	StandardHours
# (1176, 31)

# %% [markdown]
# ### N.B.
# Over18 derived by column "Age" <br>
# StandardHours derived by column "OverTime" (is specified StandardHours is equal to 80)

# %% [markdown]
# <h6> Indetify near-zero variance predictors (columns which contains dummies binary variables) => this predictors may
# or may not contribute to the skill of a model</h6>
#  Perhaps the unique values can be encoded as ordinal values? <br>
#  Perhaps the unique values can be encoded as categorical values? <br>
#  Perhaps compare model skill with each variable removed from the dataset?

# %%
# summarize the number of low variance values in each column (idealy binary of tridic dummy variables),
# by counting each column's unique values, (the low variance values will show as < 1%,
# when divinding the county by the rows number)
near_zero_variance_predictors = [i for i, c in enumerate(counts) if (float(c)/df.shape[0]*100) < 1]  
print("near_zero_variance_predictors = ", len(near_zero_variance_predictors))
print("near_zero_variance_predictors' unique values:")
for column_index in near_zero_variance_predictors:
    column_name = df.columns.values.tolist()[int(column_index)]
    print(column_name + ":", df.iloc[:, column_index].unique(), sep="\t")
# Out:
# near_zero_variance_predictors =  21
# near_zero_variance_predictors' unique values:
# Attrition:	['No' 'Yes']
# BusinessTravel:	['Travel_Rarely' 'Travel_Frequently' nan 'Non-Travel']
# Department:	['Research & Development' 'Sales' 'Human Resources']
# Education:	[4 1 3 2 5]
# EducationField:	['Medical' 'Life Sciences' 'Technical Degree' 'Other' 'Human Resources'
#  'Marketing']
# EnvironmentSatisfaction:	[2 3 4 1]
# Gender:	['Male' nan 'Female']
# JobInvolvement:	[3 4 1 2]
# JobLevel:	[3 5 2 1 4]
# JobRole:	['Research Director' 'Manager' 'Sales Executive' 'Research Scientist'
#  'Laboratory Technician' 'Sales Representative' 'Manufacturing Director'
#  'Healthcare Representative' 'Human Resources']
# JobSatisfaction:	[3 4 2 1]
# MaritalStatus:	['Single' 'Divorced' 'Married']
# NumCompaniesWorked:	[9 1 2 0 3 8 7 4 5 6]
# OverTime:	['No' 'Yes']
# PercentSalaryHike:	[17 14 25 12 11 18 20 13 21 15 19 22 16 24 23]
# RelationshipSatisfaction:	[3 2 4 1]
# StockOptionLevel:	[0 1 3 2]
# TotalWorkingYears:	[20 21  7 12  2  4  6 13 19  1 10 25 14  5 15  8  3 17 37 24 31  9 22 18
#  11 23 26 16 40 35 28 34 36  0 29 27 32 30 33]
# TrainingTimesLastYear:	[ 2.  3.  4.  1. nan  0.  5.  6.]
# YearsAtCompany:	[ 8.  1.  3. 10.  9.  6.  4.  2. 34.  5. 13.  7. 22. 18. 14. 17. 15. 31.
#  21. nan 24.  0. 20. 11. 19. 12. 16. 29. 32. 40. 33. 26. 25. 37. 36. 30.]
# YearsInCurrentRole:	[ 7  8  5  2  3  0  9 10 12  1  4  6 13 15 17 16 14 11 18]

# %% [markdown]
# <h6> Encode object values as categorical values (they are actually all near-zero variance predictors in our case) </h6>

# %%
data_types= df.dtypes
print("Object values encodings:")
for column_name, column_type in dataTypeDict.items():
    if column_type == np.object:
        column_index = df.columns.get_loc(column_name)
        unique_values = df.iloc[:, column_index].unique()
        replacement_dict = {}
        
        if column_name == "BusinessTravel":
            replacement_dict = {"Non-Travel": 0, "Travel_Rarely": 1, "Travel_Frequently": 2}
        elif column_name == "MaritalStatus":
            replacement_dict = {"Single": 0, "Married": 1, "Divorced": 2}
        else:
            i = 0
            other_flag = False
            for v in unique_values:
                if pd.isnull(v) is False:
                    if v == "Other":
                        other_flag = True
                    else:
                        replacement_dict[str(v)] = int(i)
                        i += 1
            if other_flag:
                replacement_dict["Other"] = i
        print(replacement_dict)
        df[column_name].replace(replacement_dict, inplace=True)
# Out:
# Object values encodings:
# {'No': 0, 'Yes': 1}
# {'Non-Travel': 0, 'Travel_Rarely': 1, 'Travel_Frequently': 2}
# {'Research & Development': 0, 'Sales': 1, 'Human Resources': 2}
# {'Medical': 0, 'Life Sciences': 1, 'Technical Degree': 2, 'Human Resources': 3, 'Marketing': 4, 'Other': 5}
# {'Male': 0, 'Female': 1}
# {'Research Director': 0, 'Manager': 1, 'Sales Executive': 2, 'Research Scientist': 3, 'Laboratory Technician': 4, 'Sales Representative': 5, 'Manufacturing Director': 6, 'Healthcare Representative': 7, 'Human Resources': 8}
# {'Single': 0, 'Married': 1, 'Divorced': 2}
# {'No': 0, 'Yes': 1}

# %% [markdown]
# <h6> Analyzing variables distributions </h6>

# %%
def draw_hist(x, x_label, y_label, title, pngfile):

# %%
column_names = list(df.columns)
print("column_name" , "mean", "std", "outliers", sep="\t")
for column_name in column_names:
    data = df[column_name].dropna()  # get each column's values, omitting NaN values 
    draw_hist(data, x_label, y_label, title, pngfile)

# %% [markdown]
# <h6> Outliers removing </h6>

# %% [markdown]
# <h6> Standard Deviation Method (for Guassian distributed values) </h6>

# %%
# calculate summary statistics
column_names = list(df.columns)
print("column_name" , "mean", "std", "outliers", sep="\t")
for column_name in column_names:
    data = df[column_name].dropna()  # get each column's values, omitting NaN values 
    data_mean, data_std = mean(data), std(data)
    # define outliers as values, three standard deviations from the mean (99.7%)
    cut_off = data_std * 3
    lower, upper = data_mean - cut_off, data_mean + cut_off
    # identify outliers
    outliers = [x for x in data if x < lower or x > upper]
    if  len(outliers) > 0:
        print(column_name , data_mean, data_std, outliers, sep="\t")
# Out:
# column_name	mean	std	outliers
# TotalWorkingYears	11.019557823129253	7.6915753768177355	[37, 40, 35, 37, 36, 36, 36, 36, 37, 37, 35, 36, 36]
# YearsAtCompany	6.926523297491039	6.0604759053458945	[34.0, 31.0, 31.0, 31.0, 29.0, 32.0, 40.0, 33.0, 26.0, 32.0, 37.0, 36.0, 26.0, 30.0, 33.0, 33.0, 33.0]
# YearsInCurrentRole	4.188775510204081	3.635858337114303	[17, 16, 18, 16, 17, 16, 16, 16, 16, 16]
# YearsSinceLastPromotion	2.171768707482993	3.1884280989889096	[14, 14, 12, 13, 15, 15, 15, 12, 13, 14, 15, 13, 13, 13, 14, 15, 15, 12, 14, 13, 14, 12, 15, 13, 12, 15, 14, 13, 12, 14, 13]
# YearsWithCurrManager	4.107993197278912	3.599565929984835	[15, 15, 17, 15, 15, 16, 17, 17, 17, 17, 16]

# %% [markdown]
# <h6> Interquartile Range Method (non-Gaussian distributed values) </h6>

# %% [markdown]
# <h6> Replacing missing values </h6>

# %%
null_columns = df.isnull().sum()
nan_columns = []
print("num_null_columns = ", len(null_columns), sep="\t")
print("null_columns:\n")
for column_name, missing_values in null_columns.items():
    if missing_values > 0:
        print(column_name, missing_values, sep="\t")
        nan_columns.append(column_name)
# Out:
# num_null_columns = 	31
# null_columns:
#
# Age	176
# BusinessTravel	107
# Gender	59
# MonthlyIncome	213
# PerformanceRating	138
# TrainingTimesLastYear	233
# YearsAtCompany	60

# %% [markdown]
# @TODO: continue

# %%
df.describe()  # columns statistics
# Out:
#                Age    Attrition  BusinessTravel    DailyRate   Department  \
# count  1000.000000  1176.000000     1069.000000  1176.000000  1176.000000
# mean     37.199000     0.163265        1.073901   803.650510     0.385204
# std       9.015802     0.369765        0.529258   406.683045     0.561535
# min      18.000000     0.000000        0.000000   102.000000     0.000000
# 25%      30.000000     0.000000        1.000000   460.500000     0.000000
# 50%      36.000000     0.000000        1.000000   804.000000     0.000000
# 75%      43.000000     0.000000        1.000000  1169.000000     1.000000
# max      60.000000     1.000000        2.000000  1499.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EnvironmentSatisfaction  \
# count       1176.000000  1176.000000     1176.000000              1176.000000
# mean           9.210034     2.884354        1.348639                 2.715986
# std            8.097024     1.016574        1.478083                 1.088876
# min            1.000000     1.000000        0.000000                 1.000000
# 25%            2.000000     2.000000        0.000000                 2.000000
# 50%            7.000000     3.000000        1.000000                 3.000000
# 75%           14.000000     4.000000        2.000000                 4.000000
# max           29.000000     5.000000        5.000000                 4.000000
#
#             Gender  ...  PerformanceRating  RelationshipSatisfaction  \
# count  1117.000000  ...        1038.000000               1176.000000
# mean      0.405551  ...           3.152216                  2.702381
# std       0.491218  ...           0.359403                  1.092268
# min       0.000000  ...           3.000000                  1.000000
# 25%       0.000000  ...           3.000000                  2.000000
# 50%       0.000000  ...           3.000000                  3.000000
# 75%       1.000000  ...           3.000000                  4.000000
# max       1.000000  ...           4.000000                  4.000000
#
#        StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# count       1176.000000        1176.000000             943.000000
# mean           0.783163          11.019558               2.827147
# std            0.851385           7.694848               1.273120
# min            0.000000           0.000000               0.000000
# 25%            0.000000           6.000000               2.000000
# 50%            1.000000          10.000000               3.000000
# 75%            1.000000          15.000000               3.000000
# max            3.000000          40.000000               6.000000
#
#        WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# count      1176.000000     1116.000000         1176.000000
# mean          2.755952        6.926523            4.188776
# std           0.707984        6.063193            3.637405
# min           1.000000        0.000000            0.000000
# 25%           2.000000        3.000000            2.000000
# 50%           3.000000        5.000000            3.000000
# 75%           3.000000        9.000000            7.000000
# max           4.000000       40.000000           18.000000
#
#        YearsSinceLastPromotion  YearsWithCurrManager
# count              1176.000000           1176.000000
# mean                  2.171769              4.107993
# std                   3.189785              3.601097
# min                   0.000000              0.000000
# 25%                   0.000000              2.000000
# 50%                   1.000000              3.000000
# 75%                   3.000000              7.000000
# max                  15.000000             17.000000
#
# [8 rows x 31 columns]

# %% [markdown]
# <h2> Correlation </h2>

# %% [markdown]
# <h6> Person correlation coefficient </h6> <br>
# $\rho_{xy} = \dfrac{Cov(x, y)}{\sigma_{x}, \sigma_{y}}$ <br>
# where: <br>
# - $Cov(x, y)$ is the covariance between variable x and y; <br>
# - $\sigma_{x}$ and $\sigma_{y}$ are variables' standard deviations. <br>
#
# Values always range between -1 (strong negative relationship) and +1 (strong positive relationship). Values at or close to zero imply weak or no linear relationship.

# %%
df.corr("pearson") # pearson correlation
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000  -0.027961          0.008081   0.005951
# DailyRate                -0.027961   1.000000          0.014447  -0.014759
# DistanceFromHome          0.008081   0.014447          1.000000   0.021564
# Education                 0.005951  -0.014759          0.021564   1.000000
# EnvironmentSatisfaction   0.026259   0.047369          0.000980  -0.054301
# HourlyRate                0.045007   0.007709          0.037306   0.007589
# JobInvolvement            0.005358   0.049508         -0.009932   0.039782
# JobLevel                  0.040556  -0.009872          0.020217   0.086789
# JobSatisfaction          -0.056664   0.044478          0.004533  -0.036841
# MonthlyIncome             0.496275  -0.030414          0.000690   0.008964
# MonthlyRate               0.032088  -0.031826          0.007779  -0.017993
# NumCompaniesWorked       -0.002443   0.044370         -0.016573   0.142888
# PercentSalaryHike        -0.028621   0.056850         -0.008141  -0.015003
# PerformanceRating        -0.005926  -0.027231         -0.002548   0.050993
# RelationshipSatisfaction  0.028624   0.002869          0.013618   0.004234
# StandardHours                  NaN        NaN               NaN        NaN
# StockOptionLevel          0.033101   0.040397          0.072908   0.001485
# TotalWorkingYears         0.023891   0.015554          0.008690   0.140639
# TrainingTimesLastYear    -0.017973  -0.018077         -0.006520  -0.006407
# WorkLifeBalance           0.011215  -0.046024         -0.026830   0.025790
# YearsAtCompany            0.330892  -0.016744          0.044862   0.022576
# YearsInCurrentRole        0.039994   0.004506          0.014401   0.053092
# YearsSinceLastPromotion   0.006215  -0.032954          0.004995   0.032377
# YearsWithCurrManager      0.012462  -0.015054          0.006839   0.066882
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.026259    0.045007        0.005358
# DailyRate                                0.047369    0.007709        0.049508
# DistanceFromHome                         0.000980    0.037306       -0.009932
# Education                               -0.054301    0.007589        0.039782
# EnvironmentSatisfaction                  1.000000   -0.043890       -0.007997
# HourlyRate                              -0.043890    1.000000        0.032840
# JobInvolvement                          -0.007997    0.032840        1.000000
# JobLevel                                 0.036607   -0.043203       -0.022649
# JobSatisfaction                         -0.015897   -0.088872       -0.025413
# MonthlyIncome                           -0.053153   -0.014530        0.011389
# MonthlyRate                              0.043695   -0.010387       -0.013873
# NumCompaniesWorked                       0.012716    0.030317        0.016825
# PercentSalaryHike                       -0.038159   -0.001567       -0.005572
# PerformanceRating                       -0.027166    0.019484       -0.001335
# RelationshipSatisfaction                 0.016884    0.004297        0.054873
# StandardHours                                 NaN         NaN             NaN
# StockOptionLevel                         0.020726    0.026602        0.042657
# TotalWorkingYears                        0.030425   -0.017562       -0.022687
# TrainingTimesLastYear                   -0.008389   -0.013365       -0.023995
# WorkLifeBalance                          0.034762   -0.015012       -0.026684
# YearsAtCompany                          -0.016126    0.007165       -0.028960
# YearsInCurrentRole                       0.030739   -0.027806        0.002518
# YearsSinceLastPromotion                  0.036111   -0.038817       -0.032253
# YearsWithCurrManager                     0.014774   -0.025352        0.022631
#
#                           JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# Age                       0.040556        -0.056664       0.496275  ...
# DailyRate                -0.009872         0.044478      -0.030414  ...
# DistanceFromHome          0.020217         0.004533       0.000690  ...
# Education                 0.086789        -0.036841       0.008964  ...
# EnvironmentSatisfaction   0.036607        -0.015897      -0.053153  ...
# HourlyRate               -0.043203        -0.088872      -0.014530  ...
# JobInvolvement           -0.022649        -0.025413       0.011389  ...
# JobLevel                  1.000000        -0.007627       0.014883  ...
# JobSatisfaction          -0.007627         1.000000       0.019431  ...
# MonthlyIncome             0.014883         0.019431       1.000000  ...
# MonthlyRate               0.062637         0.015172       0.015936  ...
# NumCompaniesWorked        0.141611        -0.063839      -0.002085  ...
# PercentSalaryHike        -0.025999         0.008720       0.010562  ...
# PerformanceRating         0.049699         0.006947      -0.051518  ...
# RelationshipSatisfaction -0.009148        -0.024167      -0.019264  ...
# StandardHours                  NaN              NaN            NaN  ...
# StockOptionLevel          0.003197        -0.011700      -0.032897  ...
# TotalWorkingYears         0.774492        -0.025719      -0.005489  ...
# TrainingTimesLastYear    -0.001041         0.041760       0.013194  ...
# WorkLifeBalance           0.031580        -0.032101       0.027635  ...
# YearsAtCompany            0.014837        -0.012542       0.513209  ...
# YearsInCurrentRole        0.402092         0.002989       0.006859  ...
# YearsSinceLastPromotion   0.348876        -0.034122      -0.021624  ...
# YearsWithCurrManager      0.391790        -0.032654      -0.023804  ...
#
#                           RelationshipSatisfaction  StandardHours  \
# Age                                       0.028624            NaN
# DailyRate                                 0.002869            NaN
# DistanceFromHome                          0.013618            NaN
# Education                                 0.004234            NaN
# EnvironmentSatisfaction                   0.016884            NaN
# HourlyRate                                0.004297            NaN
# JobInvolvement                            0.054873            NaN
# JobLevel                                 -0.009148            NaN
# JobSatisfaction                          -0.024167            NaN
# MonthlyIncome                            -0.019264            NaN
# MonthlyRate                               0.020464            NaN
# NumCompaniesWorked                        0.053839            NaN
# PercentSalaryHike                        -0.016576            NaN
# PerformanceRating                        -0.029555            NaN
# RelationshipSatisfaction                  1.000000            NaN
# StandardHours                                  NaN            NaN
# StockOptionLevel                         -0.066710            NaN
# TotalWorkingYears                        -0.003661            NaN
# TrainingTimesLastYear                     0.026968            NaN
# WorkLifeBalance                           0.038061            NaN
# YearsAtCompany                            0.036262            NaN
# YearsInCurrentRole                       -0.025904            NaN
# YearsSinceLastPromotion                   0.012243            NaN
# YearsWithCurrManager                     -0.016488            NaN
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.033101           0.023891
# DailyRate                         0.040397           0.015554
# DistanceFromHome                  0.072908           0.008690
# Education                         0.001485           0.140639
# EnvironmentSatisfaction           0.020726           0.030425
# HourlyRate                        0.026602          -0.017562
# JobInvolvement                    0.042657          -0.022687
# JobLevel                          0.003197           0.774492
# JobSatisfaction                  -0.011700          -0.025719
# MonthlyIncome                    -0.032897          -0.005489
# MonthlyRate                      -0.047928           0.041006
# NumCompaniesWorked                0.014899           0.251089
# PercentSalaryHike                 0.033405          -0.012607
# PerformanceRating                 0.000996           0.032611
# RelationshipSatisfaction         -0.066710          -0.003661
# StandardHours                          NaN                NaN
# StockOptionLevel                  1.000000           0.005974
# TotalWorkingYears                 0.005974           1.000000
# TrainingTimesLastYear             0.015088          -0.038327
# WorkLifeBalance                   0.003908          -0.016776
# YearsAtCompany                   -0.012259           0.011106
# YearsInCurrentRole                0.054452           0.476768
# YearsSinceLastPromotion           0.031589           0.404436
# YearsWithCurrManager              0.032072           0.486055
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                   -0.017973         0.011215
# DailyRate                             -0.018077        -0.046024
# DistanceFromHome                      -0.006520        -0.026830
# Education                             -0.006407         0.025790
# EnvironmentSatisfaction               -0.008389         0.034762
# HourlyRate                            -0.013365        -0.015012
# JobInvolvement                        -0.023995        -0.026684
# JobLevel                              -0.001041         0.031580
# JobSatisfaction                        0.041760        -0.032101
# MonthlyIncome                          0.013194         0.027635
# MonthlyRate                           -0.025640         0.004091
# NumCompaniesWorked                     0.015554        -0.009961
# PercentSalaryHike                      0.042976        -0.009367
# PerformanceRating                     -0.026415        -0.010419
# RelationshipSatisfaction               0.026968         0.038061
# StandardHours                               NaN              NaN
# StockOptionLevel                       0.015088         0.003908
# TotalWorkingYears                     -0.038327        -0.016776
# TrainingTimesLastYear                  1.000000         0.048428
# WorkLifeBalance                        0.048428         1.000000
# YearsAtCompany                        -0.017594        -0.046617
# YearsInCurrentRole                    -0.018507         0.045665
# YearsSinceLastPromotion               -0.007092         0.008780
# YearsWithCurrManager                  -0.001812         0.001667
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.330892            0.039994
# DailyRate                      -0.016744            0.004506
# DistanceFromHome                0.044862            0.014401
# Education                       0.022576            0.053092
# EnvironmentSatisfaction        -0.016126            0.030739
# HourlyRate                      0.007165           -0.027806
# JobInvolvement                 -0.028960            0.002518
# JobLevel                        0.014837            0.402092
# JobSatisfaction                -0.012542            0.002989
# MonthlyIncome                   0.513209            0.006859
# MonthlyRate                    -0.034734           -0.012991
# NumCompaniesWorked              0.025475           -0.074500
# PercentSalaryHike               0.013730           -0.028813
# PerformanceRating              -0.013189            0.010034
# RelationshipSatisfaction        0.036262           -0.025904
# StandardHours                        NaN                 NaN
# StockOptionLevel               -0.012259            0.054452
# TotalWorkingYears               0.011106            0.476768
# TrainingTimesLastYear          -0.017594           -0.018507
# WorkLifeBalance                -0.046617            0.045665
# YearsAtCompany                  1.000000            0.010734
# YearsInCurrentRole              0.010734            1.000000
# YearsSinceLastPromotion        -0.040400            0.566704
# YearsWithCurrManager            0.012181            0.710746
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                      0.006215              0.012462
# DailyRate                               -0.032954             -0.015054
# DistanceFromHome                         0.004995              0.006839
# Education                                0.032377              0.066882
# EnvironmentSatisfaction                  0.036111              0.014774
# HourlyRate                              -0.038817             -0.025352
# JobInvolvement                          -0.032253              0.022631
# JobLevel                                 0.348876              0.391790
# JobSatisfaction                         -0.034122             -0.032654
# MonthlyIncome                           -0.021624             -0.023804
# MonthlyRate                              0.026096             -0.027774
# NumCompaniesWorked                      -0.041337             -0.096784
# PercentSalaryHike                       -0.035909             -0.039616
# PerformanceRating                        0.002888              0.006743
# RelationshipSatisfaction                 0.012243             -0.016488
# StandardHours                                 NaN                   NaN
# StockOptionLevel                         0.031589              0.032072
# TotalWorkingYears                        0.404436              0.486055
# TrainingTimesLastYear                   -0.007092             -0.001812
# WorkLifeBalance                          0.008780              0.001667
# YearsAtCompany                          -0.040400              0.012181
# YearsInCurrentRole                       0.566704              0.710746
# YearsSinceLastPromotion                  1.000000              0.515614
# YearsWithCurrManager                     0.515614              1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# <h6> Sperarman correlation coefficient </h6> <br>
# $r = \rho_{rg_{x}rg_{y}} = \dfrac{Cov(rg_{x}, rg_{y})}{\sigma_{rg_{x}}, \sigma_{rg_{y}}}$ <br>
# where: <br>
# - $rg_{x}$ and $rg_{y}$ are variable's x and y rankings; <br>
# - $Cov(rg_{x}, rg_{y})$ is rankings' covariance; <br>
# - $\sigma_{rg_{x}}$ and $\sigma_{rg_{y}}$ are rankings' standard deviations. <br>
#
# Values always range between -1 (strong negative relationship) and +1 (strong positive relationship). Values at or close to zero imply weak or no relationship.

# %%
df.corr("spearman")  # spearman correlation
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000  -0.036965         -0.000851   0.004444
# DailyRate                -0.036965   1.000000          0.015002  -0.011829
# DistanceFromHome         -0.000851   0.015002          1.000000   0.012412
# Education                 0.004444  -0.011829          0.012412   1.000000
# EnvironmentSatisfaction   0.026231   0.047641          0.007325  -0.056361
# HourlyRate                0.035865   0.007962          0.033866   0.006465
# JobInvolvement           -0.000500   0.047062          0.010069   0.033177
# JobLevel                  0.049527   0.001940          0.028471   0.091429
# JobSatisfaction          -0.058197   0.042839         -0.005883  -0.030685
# MonthlyIncome             0.490325  -0.002856         -0.051726  -0.000722
# MonthlyRate               0.030743  -0.031529          0.024065  -0.014005
# NumCompaniesWorked       -0.008901   0.043391          0.002048   0.157478
# PercentSalaryHike        -0.034819   0.057805         -0.007941   0.005949
# PerformanceRating        -0.003895  -0.027955          0.002456   0.053645
# RelationshipSatisfaction  0.022757   0.005834          0.013857  -0.003219
# StandardHours                  NaN        NaN               NaN        NaN
# StockOptionLevel          0.015047   0.031334          0.059409  -0.006269
# TotalWorkingYears         0.042117   0.027126         -0.002116   0.152730
# TrainingTimesLastYear     0.005793  -0.020247         -0.028747  -0.003441
# WorkLifeBalance           0.014900  -0.051521         -0.012463   0.032127
# YearsAtCompany            0.262058  -0.017722         -0.007060   0.009163
# YearsInCurrentRole        0.052693   0.002314          0.005639   0.055080
# YearsSinceLastPromotion  -0.006190  -0.039053         -0.016885   0.016847
# YearsWithCurrManager      0.025985   0.003623         -0.007520   0.054961
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.026231    0.035865       -0.000500
# DailyRate                                0.047641    0.007962        0.047062
# DistanceFromHome                         0.007325    0.033866        0.010069
# Education                               -0.056361    0.006465        0.033177
# EnvironmentSatisfaction                  1.000000   -0.048333       -0.015574
# HourlyRate                              -0.048333    1.000000        0.034801
# JobInvolvement                          -0.015574    0.034801        1.000000
# JobLevel                                 0.022812   -0.046816       -0.025360
# JobSatisfaction                         -0.010098   -0.085110       -0.019122
# MonthlyIncome                           -0.046849   -0.020359       -0.008752
# MonthlyRate                              0.045945   -0.008833       -0.015775
# NumCompaniesWorked                       0.008507    0.024749        0.011810
# PercentSalaryHike                       -0.036802    0.004929       -0.005328
# PerformanceRating                       -0.024537    0.019831        0.006220
# RelationshipSatisfaction                 0.014275    0.003246        0.054147
# StandardHours                                 NaN         NaN             NaN
# StockOptionLevel                         0.026173    0.020598        0.053401
# TotalWorkingYears                        0.010198   -0.021129       -0.004387
# TrainingTimesLastYear                   -0.002576   -0.030178       -0.023579
# WorkLifeBalance                          0.037566   -0.023704       -0.033537
# YearsAtCompany                          -0.013881    0.024465       -0.031360
# YearsInCurrentRole                       0.023721   -0.041148        0.015284
# YearsSinceLastPromotion                  0.032848   -0.066429       -0.007876
# YearsWithCurrManager                     0.015152   -0.024488        0.034067
#
#                           JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# Age                       0.049527        -0.058197       0.490325  ...
# DailyRate                 0.001940         0.042839      -0.002856  ...
# DistanceFromHome          0.028471        -0.005883      -0.051726  ...
# Education                 0.091429        -0.030685      -0.000722  ...
# EnvironmentSatisfaction   0.022812        -0.010098      -0.046849  ...
# HourlyRate               -0.046816        -0.085110      -0.020359  ...
# JobInvolvement           -0.025360        -0.019122      -0.008752  ...
# JobLevel                  1.000000        -0.005741       0.006889  ...
# JobSatisfaction          -0.005741         1.000000       0.007257  ...
# MonthlyIncome             0.006889         0.007257       1.000000  ...
# MonthlyRate               0.073622         0.013416       0.015708  ...
# NumCompaniesWorked        0.180044        -0.058121       0.003889  ...
# PercentSalaryHike        -0.034250         0.016096       0.005545  ...
# PerformanceRating         0.045386         0.008342      -0.064016  ...
# RelationshipSatisfaction -0.018697        -0.026042      -0.005960  ...
# StandardHours                  NaN              NaN            NaN  ...
# StockOptionLevel          0.041550        -0.009334      -0.057848  ...
# TotalWorkingYears         0.728532        -0.019580       0.007956  ...
# TrainingTimesLastYear     0.007078         0.036754      -0.005433  ...
# WorkLifeBalance           0.033761        -0.040886       0.027256  ...
# YearsAtCompany            0.010556        -0.027073       0.466998  ...
# YearsInCurrentRole        0.405445         0.011332      -0.003083  ...
# YearsSinceLastPromotion   0.269422         0.013585      -0.017960  ...
# YearsWithCurrManager      0.382773        -0.014596      -0.019043  ...
#
#                           RelationshipSatisfaction  StandardHours  \
# Age                                       0.022757            NaN
# DailyRate                                 0.005834            NaN
# DistanceFromHome                          0.013857            NaN
# Education                                -0.003219            NaN
# EnvironmentSatisfaction                   0.014275            NaN
# HourlyRate                                0.003246            NaN
# JobInvolvement                            0.054147            NaN
# JobLevel                                 -0.018697            NaN
# JobSatisfaction                          -0.026042            NaN
# MonthlyIncome                            -0.005960            NaN
# MonthlyRate                               0.023125            NaN
# NumCompaniesWorked                        0.043583            NaN
# PercentSalaryHike                        -0.013221            NaN
# PerformanceRating                        -0.030028            NaN
# RelationshipSatisfaction                  1.000000            NaN
# StandardHours                                  NaN            NaN
# StockOptionLevel                         -0.080280            NaN
# TotalWorkingYears                        -0.017664            NaN
# TrainingTimesLastYear                     0.031663            NaN
# WorkLifeBalance                           0.035620            NaN
# YearsAtCompany                            0.035217            NaN
# YearsInCurrentRole                       -0.036190            NaN
# YearsSinceLastPromotion                   0.018911            NaN
# YearsWithCurrManager                     -0.018854            NaN
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.015047           0.042117
# DailyRate                         0.031334           0.027126
# DistanceFromHome                  0.059409          -0.002116
# Education                        -0.006269           0.152730
# EnvironmentSatisfaction           0.026173           0.010198
# HourlyRate                        0.020598          -0.021129
# JobInvolvement                    0.053401          -0.004387
# JobLevel                          0.041550           0.728532
# JobSatisfaction                  -0.009334          -0.019580
# MonthlyIncome                    -0.057848           0.007956
# MonthlyRate                      -0.051963           0.019522
# NumCompaniesWorked                0.006538           0.319244
# PercentSalaryHike                 0.057716          -0.024650
# PerformanceRating                 0.002706           0.005827
# RelationshipSatisfaction         -0.080280          -0.017664
# StandardHours                          NaN                NaN
# StockOptionLevel                  1.000000           0.048038
# TotalWorkingYears                 0.048038           1.000000
# TrainingTimesLastYear             0.016423          -0.035404
# WorkLifeBalance                  -0.020353          -0.022850
# YearsAtCompany                   -0.013664           0.009551
# YearsInCurrentRole                0.078206           0.516868
# YearsSinceLastPromotion           0.038800           0.346319
# YearsWithCurrManager              0.063353           0.526703
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                    0.005793         0.014900
# DailyRate                             -0.020247        -0.051521
# DistanceFromHome                      -0.028747        -0.012463
# Education                             -0.003441         0.032127
# EnvironmentSatisfaction               -0.002576         0.037566
# HourlyRate                            -0.030178        -0.023704
# JobInvolvement                        -0.023579        -0.033537
# JobLevel                               0.007078         0.033761
# JobSatisfaction                        0.036754        -0.040886
# MonthlyIncome                         -0.005433         0.027256
# MonthlyRate                           -0.024394         0.004205
# NumCompaniesWorked                    -0.009624         0.002247
# PercentSalaryHike                      0.043748        -0.006245
# PerformanceRating                     -0.031620        -0.016152
# RelationshipSatisfaction               0.031663         0.035620
# StandardHours                               NaN              NaN
# StockOptionLevel                       0.016423        -0.020353
# TotalWorkingYears                     -0.035404        -0.022850
# TrainingTimesLastYear                  1.000000         0.039077
# WorkLifeBalance                        0.039077         1.000000
# YearsAtCompany                        -0.022424        -0.040892
# YearsInCurrentRole                     0.008306         0.023464
# YearsSinceLastPromotion               -0.012581         0.007596
# YearsWithCurrManager                   0.009897        -0.001588
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.262058            0.052693
# DailyRate                      -0.017722            0.002314
# DistanceFromHome               -0.007060            0.005639
# Education                       0.009163            0.055080
# EnvironmentSatisfaction        -0.013881            0.023721
# HourlyRate                      0.024465           -0.041148
# JobInvolvement                 -0.031360            0.015284
# JobLevel                        0.010556            0.405445
# JobSatisfaction                -0.027073            0.011332
# MonthlyIncome                   0.466998           -0.003083
# MonthlyRate                    -0.027381           -0.002457
# NumCompaniesWorked              0.006693           -0.110343
# PercentSalaryHike               0.003345           -0.054034
# PerformanceRating               0.005138           -0.003889
# RelationshipSatisfaction        0.035217           -0.036190
# StandardHours                        NaN                 NaN
# StockOptionLevel               -0.013664            0.078206
# TotalWorkingYears               0.009551            0.516868
# TrainingTimesLastYear          -0.022424            0.008306
# WorkLifeBalance                -0.040892            0.023464
# YearsAtCompany                  1.000000            0.010744
# YearsInCurrentRole              0.010744            1.000000
# YearsSinceLastPromotion         0.003146            0.522932
# YearsWithCurrManager            0.004849            0.715861
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                     -0.006190              0.025985
# DailyRate                               -0.039053              0.003623
# DistanceFromHome                        -0.016885             -0.007520
# Education                                0.016847              0.054961
# EnvironmentSatisfaction                  0.032848              0.015152
# HourlyRate                              -0.066429             -0.024488
# JobInvolvement                          -0.007876              0.034067
# JobLevel                                 0.269422              0.382773
# JobSatisfaction                          0.013585             -0.014596
# MonthlyIncome                           -0.017960             -0.019043
# MonthlyRate                             -0.010762             -0.029730
# NumCompaniesWorked                      -0.075876             -0.126131
# PercentSalaryHike                       -0.072966             -0.050315
# PerformanceRating                        0.015748             -0.001684
# RelationshipSatisfaction                 0.018911             -0.018854
# StandardHours                                 NaN                   NaN
# StockOptionLevel                         0.038800              0.063353
# TotalWorkingYears                        0.346319              0.526703
# TrainingTimesLastYear                   -0.012581              0.009897
# WorkLifeBalance                          0.007596             -0.001588
# YearsAtCompany                           0.003146              0.004849
# YearsInCurrentRole                       0.522932              0.715861
# YearsSinceLastPromotion                  1.000000              0.477166
# YearsWithCurrManager                     0.477166              1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# <h6> Kendall correlation coefficient </h6> <br>
# $\tau_{xy} = \dfrac{n_{c} - n_{d}}{n(n - 1) / 2}$ <br>
# where: <br>
# - $n_{c}$ and $n_{d}$ are the number of concordan or discordant pairs $(x_{i}, y_{i})$, i=1,...,n; <br>
# - $n(n - 1) / 2$ is the total number of pairings. <br>
#
# Values always range between -1 (strong negative relationship) and +1 (strong positive relationship). Values at or close to zero imply weak or no relationship.

# %%
df.corr("kendall")  # kendall correlation
# Out:
#                                Age  DailyRate  DistanceFromHome  Education  \
# Age                       1.000000  -0.024706         -0.000710   0.003510
# DailyRate                -0.024706   1.000000          0.010136  -0.008690
# DistanceFromHome         -0.000710   0.010136          1.000000   0.009847
# Education                 0.003510  -0.008690          0.009847   1.000000
# EnvironmentSatisfaction   0.019627   0.035774          0.005731  -0.047294
# HourlyRate                0.024958   0.005659          0.024087   0.004969
# JobInvolvement           -0.000446   0.036792          0.008202   0.028904
# JobLevel                  0.037787   0.001469          0.022821   0.077564
# JobSatisfaction          -0.043486   0.031775         -0.004455  -0.025655
# MonthlyIncome             0.346631  -0.000978         -0.036369  -0.000562
# MonthlyRate               0.021285  -0.021275          0.016399  -0.010602
# NumCompaniesWorked       -0.006517   0.031222          0.001629   0.128057
# PercentSalaryHike        -0.024296   0.040719         -0.005897   0.004945
# PerformanceRating        -0.003232  -0.022845          0.002068   0.049136
# RelationshipSatisfaction  0.016985   0.004106          0.010615  -0.002615
# StandardHours                  NaN        NaN               NaN        NaN
# StockOptionLevel          0.011376   0.024293          0.047007  -0.005555
# TotalWorkingYears         0.029634   0.018779         -0.000817   0.117324
# TrainingTimesLastYear     0.005047  -0.015870         -0.022331  -0.003054
# WorkLifeBalance           0.011110  -0.040005         -0.009914   0.027906
# YearsAtCompany            0.192403  -0.011894         -0.004695   0.007023
# YearsInCurrentRole        0.038305   0.001373          0.004236   0.043763
# YearsSinceLastPromotion  -0.004435  -0.028271         -0.012630   0.013680
# YearsWithCurrManager      0.018457   0.002252         -0.005538   0.043425
#
#                           EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# Age                                      0.019627    0.024958       -0.000446
# DailyRate                                0.035774    0.005659        0.036792
# DistanceFromHome                         0.005731    0.024087        0.008202
# Education                               -0.047294    0.004969        0.028904
# EnvironmentSatisfaction                  1.000000   -0.036222       -0.013634
# HourlyRate                              -0.036222    1.000000        0.027000
# JobInvolvement                          -0.013634    0.027000        1.000000
# JobLevel                                 0.019585   -0.035630       -0.022341
# JobSatisfaction                         -0.008692   -0.064327       -0.016605
# MonthlyIncome                           -0.035201   -0.013624       -0.006530
# MonthlyRate                              0.034612   -0.005619       -0.012454
# NumCompaniesWorked                       0.006503    0.017935        0.009707
# PercentSalaryHike                       -0.028889    0.003824       -0.004252
# PerformanceRating                       -0.022471    0.016312        0.005899
# RelationshipSatisfaction                 0.012021    0.002740        0.047279
# StandardHours                                 NaN         NaN             NaN
# StockOptionLevel                         0.022721    0.016399        0.048398
# TotalWorkingYears                        0.008412   -0.014251       -0.003555
# TrainingTimesLastYear                   -0.002165   -0.022608       -0.020289
# WorkLifeBalance                          0.032852   -0.018703       -0.030123
# YearsAtCompany                          -0.010448    0.016906       -0.025510
# YearsInCurrentRole                       0.018718   -0.028387        0.012539
# YearsSinceLastPromotion                  0.026963   -0.049362       -0.006771
# YearsWithCurrManager                     0.011901   -0.017392        0.028365
#
#                           JobLevel  JobSatisfaction  MonthlyIncome  ...  \
# Age                       0.037787        -0.043486       0.346631  ...
# DailyRate                 0.001469         0.031775      -0.000978  ...
# DistanceFromHome          0.022821        -0.004455      -0.036369  ...
# Education                 0.077564        -0.025655      -0.000562  ...
# EnvironmentSatisfaction   0.019585        -0.008692      -0.035201  ...
# HourlyRate               -0.035630        -0.064327      -0.013624  ...
# JobInvolvement           -0.022341        -0.016605      -0.006530  ...
# JobLevel                  1.000000        -0.004797       0.005160  ...
# JobSatisfaction          -0.004797         1.000000       0.005291  ...
# MonthlyIncome             0.005160         0.005291       1.000000  ...
# MonthlyRate               0.055627         0.009728       0.010925  ...
# NumCompaniesWorked        0.146353        -0.046880       0.002624  ...
# PercentSalaryHike        -0.027331         0.012723       0.003748  ...
# PerformanceRating         0.042006         0.007638      -0.052303  ...
# RelationshipSatisfaction -0.015713        -0.021624      -0.004098  ...
# StandardHours                  NaN              NaN            NaN  ...
# StockOptionLevel          0.035435        -0.008080      -0.045054  ...
# TotalWorkingYears         0.610382        -0.014959       0.006028  ...
# TrainingTimesLastYear     0.005904         0.030681      -0.003703  ...
# WorkLifeBalance           0.029556        -0.035664       0.021279  ...
# YearsAtCompany            0.008112        -0.021249       0.341888  ...
# YearsInCurrentRole        0.334771         0.009030      -0.001825  ...
# YearsSinceLastPromotion   0.225035         0.011371      -0.013216  ...
# YearsWithCurrManager      0.315104        -0.011525      -0.012057  ...
#
#                           RelationshipSatisfaction  StandardHours  \
# Age                                       0.016985            NaN
# DailyRate                                 0.004106            NaN
# DistanceFromHome                          0.010615            NaN
# Education                                -0.002615            NaN
# EnvironmentSatisfaction                   0.012021            NaN
# HourlyRate                                0.002740            NaN
# JobInvolvement                            0.047279            NaN
# JobLevel                                 -0.015713            NaN
# JobSatisfaction                          -0.021624            NaN
# MonthlyIncome                            -0.004098            NaN
# MonthlyRate                               0.017072            NaN
# NumCompaniesWorked                        0.035253            NaN
# PercentSalaryHike                        -0.010147            NaN
# PerformanceRating                        -0.027478            NaN
# RelationshipSatisfaction                  1.000000            NaN
# StandardHours                                  NaN            1.0
# StockOptionLevel                         -0.069609            NaN
# TotalWorkingYears                        -0.013140            NaN
# TrainingTimesLastYear                     0.026471            NaN
# WorkLifeBalance                           0.031004            NaN
# YearsAtCompany                            0.027077            NaN
# YearsInCurrentRole                       -0.028492            NaN
# YearsSinceLastPromotion                   0.015467            NaN
# YearsWithCurrManager                     -0.014741            NaN
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.011376           0.029634
# DailyRate                         0.024293           0.018779
# DistanceFromHome                  0.047007          -0.000817
# Education                        -0.005555           0.117324
# EnvironmentSatisfaction           0.022721           0.008412
# HourlyRate                        0.016399          -0.014251
# JobInvolvement                    0.048398          -0.003555
# JobLevel                          0.035435           0.610382
# JobSatisfaction                  -0.008080          -0.014959
# MonthlyIncome                    -0.045054           0.006028
# MonthlyRate                      -0.040358           0.012714
# NumCompaniesWorked                0.005461           0.231026
# PercentSalaryHike                 0.046317          -0.017754
# PerformanceRating                 0.002562           0.004886
# RelationshipSatisfaction         -0.069609          -0.013140
# StandardHours                          NaN                NaN
# StockOptionLevel                  1.000000           0.037214
# TotalWorkingYears                 0.037214           1.000000
# TrainingTimesLastYear             0.014163          -0.027276
# WorkLifeBalance                  -0.018080          -0.018255
# YearsAtCompany                   -0.010526           0.007577
# YearsInCurrentRole                0.064145           0.414699
# YearsSinceLastPromotion           0.032827           0.263732
# YearsWithCurrManager              0.051879           0.420347
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                    0.005047         0.011110
# DailyRate                             -0.015870        -0.040005
# DistanceFromHome                      -0.022331        -0.009914
# Education                             -0.003054         0.027906
# EnvironmentSatisfaction               -0.002165         0.032852
# HourlyRate                            -0.022608        -0.018703
# JobInvolvement                        -0.020289        -0.030123
# JobLevel                               0.005904         0.029556
# JobSatisfaction                        0.030681        -0.035664
# MonthlyIncome                         -0.003703         0.021279
# MonthlyRate                           -0.017932         0.003114
# NumCompaniesWorked                    -0.008058         0.002160
# PercentSalaryHike                      0.034293        -0.005069
# PerformanceRating                     -0.028774        -0.015361
# RelationshipSatisfaction               0.026471         0.031004
# StandardHours                               NaN              NaN
# StockOptionLevel                       0.014163        -0.018080
# TotalWorkingYears                     -0.027276        -0.018255
# TrainingTimesLastYear                  1.000000         0.034131
# WorkLifeBalance                        0.034131         1.000000
# YearsAtCompany                        -0.016765        -0.033057
# YearsInCurrentRole                     0.006374         0.019377
# YearsSinceLastPromotion               -0.010513         0.006398
# YearsWithCurrManager                   0.007397        -0.001436
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.192403            0.038305
# DailyRate                      -0.011894            0.001373
# DistanceFromHome               -0.004695            0.004236
# Education                       0.007023            0.043763
# EnvironmentSatisfaction        -0.010448            0.018718
# HourlyRate                      0.016906           -0.028387
# JobInvolvement                 -0.025510            0.012539
# JobLevel                        0.008112            0.334771
# JobSatisfaction                -0.021249            0.009030
# MonthlyIncome                   0.341888           -0.001825
# MonthlyRate                    -0.018468           -0.001645
# NumCompaniesWorked              0.005748           -0.082539
# PercentSalaryHike               0.002011           -0.040334
# PerformanceRating               0.004347           -0.003372
# RelationshipSatisfaction        0.027077           -0.028492
# StandardHours                        NaN                 NaN
# StockOptionLevel               -0.010526            0.064145
# TotalWorkingYears               0.007577            0.414699
# TrainingTimesLastYear          -0.016765            0.006374
# WorkLifeBalance                -0.033057            0.019377
# YearsAtCompany                  1.000000            0.007968
# YearsInCurrentRole              0.007968            1.000000
# YearsSinceLastPromotion         0.002425            0.417855
# YearsWithCurrManager            0.003343            0.607339
#
#                           YearsSinceLastPromotion  YearsWithCurrManager
# Age                                     -0.004435              0.018457
# DailyRate                               -0.028271              0.002252
# DistanceFromHome                        -0.012630             -0.005538
# Education                                0.013680              0.043425
# EnvironmentSatisfaction                  0.026963              0.011901
# HourlyRate                              -0.049362             -0.017392
# JobInvolvement                          -0.006771              0.028365
# JobLevel                                 0.225035              0.315104
# JobSatisfaction                          0.011371             -0.011525
# MonthlyIncome                           -0.013216             -0.012057
# MonthlyRate                             -0.007856             -0.021213
# NumCompaniesWorked                      -0.059410             -0.095022
# PercentSalaryHike                       -0.056570             -0.037540
# PerformanceRating                        0.014124             -0.001459
# RelationshipSatisfaction                 0.015467             -0.014741
# StandardHours                                 NaN                   NaN
# StockOptionLevel                         0.032827              0.051879
# TotalWorkingYears                        0.263732              0.420347
# TrainingTimesLastYear                   -0.010513              0.007397
# WorkLifeBalance                          0.006398             -0.001436
# YearsAtCompany                           0.002425              0.003343
# YearsInCurrentRole                       0.417855              0.607339
# YearsSinceLastPromotion                  1.000000              0.380809
# YearsWithCurrManager                     0.380809              1.000000
#
# [24 rows x 24 columns]
